# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import pandas as pd
from math import pi
 
# Set data
df = pd.DataFrame({
'group': ['S','A','B','O'],
'cacti1': [11, 1, 2, 4],
'cacti2': [22, 1, 2, 4],
'cacti3': [33, 1, 2, 4],
'cacti4': [16, 1, 3, 1],
'cacti5': [28, 1, 2, 4],
'cacti6': [14, 1, 2, 4]
})
 
# number of variable
categories=list(df)[1:] 
#['cacti1', 'cacti2', 'cacti3', 'cacti4', 'cacti5','cacti6']
N = len(categories)
#6

# We are going to plot the first line of the data frame.
# But we need to repeat the first value to close the circular graph:
values=df.loc[0].drop('group').values.flatten().tolist()
values += values[:1]
values
# Out:
# [11, 22, 33, 16, 28, 14, 11]

# %%
 # What will be the angle of each axis in the plot? (we divide the plot / number of variable)
angles = [n / float(N) * 2 * pi for n in range(N)]
angles += angles[:1]
angles,N
# Out:
# ([0.0,
#   1.0471975511965976,
#   2.0943951023931953,
#   3.141592653589793,
#   4.1887902047863905,
#   5.235987755982989,
#   0.0],
#  6)

# %%
# Initialise the spider plot
ax = plt.subplot(111, polar=True)
 
# Draw one axe per variable + add labels labels yet
plt.xticks(angles[:-1], categories, color='grey', size=12)
 
# Draw ylabels
ax.set_rlabel_position(180)
plt.yticks([10,20,30], ["10","20","30"], color="grey", size=7)
plt.ylim(0,40)
 
# Plot data
ax.plot(angles, values, linewidth=1,c='m', linestyle='solid')
 
# Fill area
ax.fill(angles, values,'r', alpha=0.2)
plt.savefig('radar_cacti.jpg',dpi=150)

# %%
N
# Out:
# 6

# %%
df
# Out:
#   group  cacti1  cacti2  cacti3  cacti4  cacti5  cacti6
# 0     S      11      22      33      16      28      14
# 1     A       1       1       1       1       1       1
# 2     B       2       2       2       3       2       2
# 3     O       4       4       4       1       4       4
