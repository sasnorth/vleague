# %%
import time
import numpy as np
import pandas as pd
 
from bs4 import BeautifulSoup
import urllib.request as req

import requests
import os
import datetime
import re

# %%
import sys
sys.path.append("../")

# %%
from product_csv.create_df import game_df

# %%
# ディビジョンを選択してください:{v1_m, v2_m, v3_m, v1_w, v2_w}
division = 'v1_m'
# '年度を選択してください:{2019-20, 2018-19, 2017-18...}'
season = '2020-21'
# シーズンを選択してください:{regular, 2019-20(game1, game2, semi_final, final), 2014-15~2018-19(final6, final3, final),
# ~2013-14(semi_final, final)}
s_round = 'regular'
season += '_' + s_round
season
# Out:
# '2020-21_regular'

# %%
def create_csv():
    daily_all = game_all[game_all['名前'] != 'チーム合計']
    daily_all = daily_all.drop(columns=['被アタック打数', '被アタック得点', '被アタック失点', '被アタック決定率', '被ブロック得点', '被ブロックセット平均', '被サーブ効果率','被サーブレシーブ成功率'])

    year_month = daily_all['試合日'].str[0:7]
    # data = daily_all
    print(daily_all)
    daily_all.insert(1, '年月', year_month)
    daily_all.set_index('試合日')
    monthly_all = daily_all.groupby(['名前','年月','チーム','背番号']).sum().reset_index()
    monthly_all['アタック決定率'] = ((monthly_all['アタック得点'] / monthly_all['アタック打数']) * 100).round(1)
    monthly_all['アタック効果率'] = (((monthly_all['アタック得点']-monthly_all['アタック失点']) / monthly_all['アタック打数']) * 100).round(1)
    monthly_all['バックアタック決定率'] = ((monthly_all['バックアタック得点'] / monthly_all['バックアタック打数']) * 100).round(1)
    monthly_all['アタックセット平均'] = (monthly_all['アタック得点'] / monthly_all['出場数']).round(2)
    monthly_all['ブロックセット平均'] = (monthly_all['ブロック得点'] / monthly_all['出場数']).round(2)
    monthly_all['サーブ効果率'] = ((monthly_all['サーブ得点'] * 100 + monthly_all['サーブ効果'] * 25 - monthly_all['サーブ失点'] * 25) / monthly_all['サーブ打数']).round(1)
    monthly_all['サーブレシーブ成功率'] = ((monthly_all['サーブレシーブ成功・優'] * 100 + monthly_all['サーブレシーブ成功・良'] * 50) / monthly_all['受数']).round(1)
    print(monthly_all)

    yearly_all = daily_all.groupby(['名前','チーム','背番号']).sum().reset_index()
    yearly_all['アタック決定率'] = ((yearly_all['アタック得点'] / yearly_all['アタック打数']) * 100).round(1)
    yearly_all['アタック効果率'] = (((yearly_all['アタック得点']-yearly_all['アタック失点']) / yearly_all['アタック打数']) * 100).round(1)
    yearly_all['バックアタック決定率'] = ((yearly_all['バックアタック得点'] / yearly_all['バックアタック打数']) * 100).round(1)
    yearly_all['アタックセット平均'] = (yearly_all['アタック得点'] / yearly_all['出場数']).round(2)
    yearly_all['ブロックセット平均'] = (yearly_all['ブロック得点'] / yearly_all['出場数']).round(2)
    yearly_all['サーブ効果率'] = ((yearly_all['サーブ得点'] * 100 + yearly_all['サーブ効果'] * 25 - yearly_all['サーブ失点'] * 25) / yearly_all['サーブ打数']).round(1)
    yearly_all['サーブレシーブ成功率'] = ((yearly_all['サーブレシーブ成功・優'] * 100 + yearly_all['サーブレシーブ成功・良'] * 50) / yearly_all['受数']).round(1)
    print(yearly_all)

    game_all.to_csv('all/{}/game_all.csv'.format(s_round), index=False, encoding='cp932')
    daily_all.to_csv('all/{}/daily_all.csv'.format(s_round), index=False, encoding='cp932')
    monthly_all.to_csv('all/{}/monthly_all.csv'.format(s_round), index=False, encoding='cp932')
    yearly_all.to_csv('all/{}/yearly_all.csv'.format(s_round), index=False, encoding='cp932')
    print('csv作成成功')

# %%
# 2020-21の更新
os.chdir('/Users/sasno/Desktop/MyPandas/vleague') 
headers = {"User-Agent": "Mozilla/5.0"}
 
# seasons = get_seasons(division)

# division = "v1_m"
# s_id = "283" # 2019-20
# s_id = "301"
# division = "v1_w"
# s_id = "303"
division = "v2_m"
s_id = "299"
# division = "v2_w"
# s_id = "302"
# division = "v3_m"
# s_id = "300"
# division = "v3_w"
# s_id = "268" 
s_round = "2020-21_regular"
 
if not os.path.isdir(division):
            os.makedirs(division)
        
os.chdir(division)
print(os.getcwd())
 
sets = ['1','2','3','4','5']
game_all = None
 
# ページ数を取得
url = 'https://www.vleague.jp/round/list/{}'.format(s_id)
print(url)
request = req.Request(url, headers=headers)
response = req.urlopen(request)
parse_html = BeautifulSoup(response, 'html.parser')
hrefs = parse_html.find_all('a', href=re.compile("pg"))
 
# for i in hrefs:
#     print(i.text)
print(len(hrefs))
if len(hrefs) > 0:
    pages = int(hrefs[-2].text)
    print(pages)
 
    all_list = []
    url_list = []
    for pg in range(1,pages+1):
        url = 'https://www.vleague.jp/round/list/{0}?pg={1}'.format(s_id,pg)
        print(url)
        request = req.Request(url, headers=headers)
        response = req.urlopen(request)
        parse_html = BeautifulSoup(response, 'html.parser')
        tables = parse_html.find_all('table')
 
        
        trs = tables[0].find_all('a', href=re.compile("/form/b"))
        for tr in trs:
            game_url = 'https://www.vleague.jp/'+ tr.attrs['href']
            url_list.append(game_url)
    print(url_list)

    for url in url_list:
        # print(url)
        html = requests.get(url, headers=headers)
        check = html.text
        if '試合データがありません' not in check and '試合データの集計中です。しばらくお待ちください。' not in check:
            # try:
                data = pd.read_html(check, header=[2])

                for j in range(2):
                    stats = pd.DataFrame(data[j+4])
                    o_stats = pd.DataFrame(data[-(j+1)])
                    stats = stats.rename(columns=str)
                    o_stats = o_stats.rename(columns=str)
                    col = stats.columns.values
                    data_item = []
                    for i in col:
                        l = i
                        data_item.append(l)
                    for i in range(1,len(data_item)-2):
                        data_item[-i] = data_item[-i-3]
                #     print(data_item)
                    for i in range(3):
                    #     print(data_item[i])
                        if data_item[i] == '出場数':
                            data_item[i] = '背番号'
                        elif data_item[i] == '1':
                            data_item[i] = 'リベロ'
                        else:
                            data_item[i] = '名前'
                        # print(i, data_item[i])

                    new_stats = stats.rename(columns={col[i]:data_item[i] for i in range(len(data_item))})
                    stats_columns = {
                        '打数':'アタック打数', '得点':'アタック得点', '失点':'アタック失点', '決定率':'アタック決定率',
                        'セ平ット均':'アタックセット平均','打数.1':'バックアタック打数', '得点.1':'バックアタック得点',
                        '失点.1':'バックアタック失点', '決定率.1':'バックアタック決定率', '得点.2':'ブロック得点',
                        'セ平ット均.1':'ブロックセット平均', '打数.2':'サーブ打数', '得点.3':'サーブ得点', '失点.2':'サーブ失点',
                        '効果':'サーブ効果', '効果率':'サーブ効果率', '成功・優':'サーブレシーブ成功・優', 
                        '成功・良':'サーブレシーブ成功・良', '成功率':'サーブレシーブ成功率'
                        }
                    new_o_stats = o_stats.rename(columns={col[i]:data_item[i] for i in range(len(data_item))})
                    new_stats = new_stats.rename(columns=stats_columns)
                    new_o_stats = new_o_stats.rename(columns=stats_columns)
                    new_o_stats = new_o_stats.rename(columns={'アタック打数':'相手アタック打数', 'アタック得点':'相手アタック得点', 'アタック失点':'相手アタック失点', 
                                                        'アタック決定率':'相手アタック決定率', 'ブロック得点':'相手ブロック得点', 'ブロックセット平均':'相手ブロックセット平均',
                                                        'サーブ効果率':'相手サーブ効果率', 'サーブレシーブ成功率':'相手サーブレシーブ成功率'})
                    new_o_stats_p = new_o_stats.iloc[-1][['背番号','相手アタック打数', '相手アタック得点', '相手アタック失点', '相手アタック決定率', '相手ブロック得点', '相手ブロックセット平均', 
                                                    '相手サーブ効果率','相手サーブレシーブ成功率']]
                    new_o_stats_p = pd.DataFrame(new_o_stats_p).T
                #     new_o_stats_p

                    request = req.Request(url, headers=headers)
                    response = req.urlopen(request)
                    parse_html = BeautifulSoup(response, 'html.parser')
                    table_ha = parse_html.find_all('table')[0]
                    td_ha = table_ha.find_all('td', class_='team')
                    # print(td_ha)
                    team = td_ha[j].text
                    # print('team={}'.format(team))
                    new_stats['アタック決定率'] = new_stats['アタック得点'] / new_stats['アタック打数']
                    new_stats.insert(13, 'アタック効果率',
                        (new_stats['アタック得点'] - new_stats['アタック失点']) / new_stats['アタック打数'])
                    span = parse_html.find_all('span')
                    date = span[1].text.replace('/','-')
                    new_stats.insert(0, '試合日', date)
                    new_stats.insert(1, 'チーム', team)
                    new_stats['名前'] = new_stats['名前'].str.replace('\u3000','')
                    for by_set in sets:
                        new_stats[by_set] = new_stats[by_set].astype(str)
                    team_dir = '{0}/{1}'.format(team, s_round)

                    stats_m = pd.merge(new_stats, new_o_stats_p, on='背番号', how='outer')
                #     stats_m
                    if not os.path.isdir(team_dir):
                        os.makedirs(team_dir)
                    stats_m.to_csv('{0}/{1}/{2}.csv'.format(team,s_round,date), index=False, encoding='cp932')
                    all_list.append(stats_m)
            # except:
            #     pass
#     print(all_list)
    game_all = pd.concat(all_list, ignore_index=True)

all_dir = 'all/{}'.format(s_round)
if not os.path.isdir(all_dir):
    os.makedirs(all_dir)

print(os.getcwd())
try:
    create_csv()
except:
    pass
# Out:
# C:\Users\sasno\Desktop\MyPandas\vleague\v2_m
# https://www.vleague.jp/round/list/299
# 7
# 5
# https://www.vleague.jp/round/list/299?pg=1
# https://www.vleague.jp/round/list/299?pg=2
# https://www.vleague.jp/round/list/299?pg=3
# https://www.vleague.jp/round/list/299?pg=4
# https://www.vleague.jp/round/list/299?pg=5
# ['https://www.vleague.jp//form/b/26519', 'https://www.vleague.jp//form/b/26520', 'https://www.vleague.jp//form/b/26521', 'https://www.vleague.jp//form/b/26522', 'https://www.vleague.jp//form/b/26523', 'https://www.vleague.jp//form/b/26524', 'https://www.vleague.jp//form/b/26525', 'https://www.vleague.jp//form/b/26526', 'https://www.vleague.jp//form/b/26527', 'https://www.vleague.jp//form/b/26528', 'https://www.vleague.jp//form/b/26529', 'https://www.vleague.jp//form/b/26530', 'https://www.vleague.jp//form/b/26531', 'https://www.vleague.jp//form/b/26532', 'https://www.vleague.jp//form/b/26533', 'https://www.vleague.jp//form/b/26534', 'https://www.vleague.jp//form/b/26535', 'https://www.vleague.jp//form/b/26536', 'https://www.vleague.jp//form/b/26537', 'https://www.vleague.jp//form/b/26538', 'https://www.vleague.jp//form/b/26543', 'https://www.vleague.jp//form/b/26539', 'https://www.vleague.jp//form/b/26544', 'https://www.vleague.jp//form/b/26540', 'https://www.vleague.jp//form/b/26541', 'https://www.vleague.jp//form/b/26545', 'https://www.vleague.jp//form/b/26546', 'https://www.vleague.jp//form/b/26542', 'https://www.vleague.jp//form/b/26551', 'https://www.vleague.jp//form/b/26549', 'https://www.vleague.jp//form/b/26552', 'https://www.vleague.jp//form/b/26547', 'https://www.vleague.jp//form/b/26553', 'https://www.vleague.jp//form/b/26550', 'https://www.vleague.jp//form/b/26554', 'https://www.vleague.jp//form/b/26548', 'https://www.vleague.jp//form/b/26555', 'https://www.vleague.jp//form/b/26559', 'https://www.vleague.jp//form/b/26556', 'https://www.vleague.jp//form/b/26560', 'https://www.vleague.jp//form/b/26557', 'https://www.vleague.jp//form/b/26561', 'https://www.vleague.jp//form/b/26558', 'https://www.vleague.jp//form/b/26562', 'https://www.vleague.jp//form/b/26565', 'https://www.vleague.jp//form/b/26563', 'https://www.vleague.jp//form/b/26566', 'https://www.vleague.jp//form/b/26567', 'https://www.vleague.jp//form/b/26568', 'https://www.vleague.jp//form/b/26564', 'https://www.vleague.jp//form/b/26575', 'https://www.vleague.jp//form/b/26578', 'https://www.vleague.jp//form/b/26576', 'https://www.vleague.jp//form/b/26577', 'https://www.vleague.jp//form/b/26588', 'https://www.vleague.jp//form/b/26584', 'https://www.vleague.jp//form/b/26586', 'https://www.vleague.jp//form/b/26589', 'https://www.vleague.jp//form/b/26642', 'https://www.vleague.jp//form/b/26593', 'https://www.vleague.jp//form/b/26597', 'https://www.vleague.jp//form/b/26594', 'https://www.vleague.jp//form/b/26641', 'https://www.vleague.jp//form/b/26598', 'https://www.vleague.jp//form/b/26595', 'https://www.vleague.jp//form/b/26605', 'https://www.vleague.jp//form/b/26599', 'https://www.vleague.jp//form/b/26606', 'https://www.vleague.jp//form/b/26607', 'https://www.vleague.jp//form/b/26608', 'https://www.vleague.jp//form/b/26609', 'https://www.vleague.jp//form/b/26613', 'https://www.vleague.jp//form/b/26610', 'https://www.vleague.jp//form/b/26611', 'https://www.vleague.jp//form/b/26614', 'https://www.vleague.jp//form/b/26612', 'https://www.vleague.jp//form/b/26619', 'https://www.vleague.jp//form/b/26623', 'https://www.vleague.jp//form/b/26618', 'https://www.vleague.jp//form/b/26572', 'https://www.vleague.jp//form/b/26622', 'https://www.vleague.jp//form/b/26625', 'https://www.vleague.jp//form/b/26626', 'https://www.vleague.jp//form/b/26627', 'https://www.vleague.jp//form/b/26628']
# [           試合日               チーム    背番号    リベロ     名前  出場数    1    2    3  \
# 0   2020-10-17  つくばユナイテッドSunGAIA      1    NaN   上場雄也    4    ■    ■    ■
# 1   2020-10-17  つくばユナイテッドSunGAIA      2    NaN   浜崎勇矢    4    ■    ■    ■
# 2   2020-10-17  つくばユナイテッドSunGAIA      4    NaN   阿部航平    4    ■    ■    ■
# 3   2020-10-17  つくばユナイテッドSunGAIA      5    NaN   廣瀬優希    4    ■    ■    ■
# 4   2020-10-17  つくばユナイテッドSunGAIA      6    NaN   瀧澤陽紀    2  nan    □  nan
# 5   2020-10-17  つくばユナイテッドSunGAIA      8    NaN    曹海倫    0  nan  nan  nan
# 6   2020-10-17  つくばユナイテッドSunGAIA     10    NaN   鎌田敏弥    1  nan  nan  nan
# 7   2020-10-17  つくばユナイテッドSunGAIA     12    NaN   土井友登    2  nan  nan    □
# 8   2020-10-17  つくばユナイテッドSunGAIA     13      L   新垣東麻    0  nan  nan  nan
# 9   2020-10-17  つくばユナイテッドSunGAIA     14    NaN  勝本真太郎    3    □    □  nan
# 10  2020-10-17  つくばユナイテッドSunGAIA     20    NaN   満生大輝    4    ■    ■    ■
# 11  2020-10-17  つくばユナイテッドSunGAIA     22      L   関谷拓巳    4    ●    ●    ●
# 12  2020-10-17  つくばユナイテッドSunGAIA     23    NaN   曽田一也    4    ■    ■    ■
# 13  2020-10-17  つくばユナイテッドSunGAIA     26    NaN   鈴木匡教    3    □    □    □
# 14  2020-10-17  つくばユナイテッドSunGAIA  チーム合計  チーム合計  チーム合計    4  nan  nan  nan
#
#       4  ... サーブレシーブ成功・良  サーブレシーブ成功率  相手アタック打数  相手アタック得点  相手アタック失点  相手アタック決定率  \
# 0     ■  ...           0           -       NaN       NaN       NaN        NaN
# 1     ■  ...           0           -       NaN       NaN       NaN        NaN
# 2     ■  ...           0       100.0       NaN       NaN       NaN        NaN
# 3     ■  ...           0           -       NaN       NaN       NaN        NaN
# 4     □  ...           3        75.0       NaN       NaN       NaN        NaN
# 5   nan  ...           0           -       NaN       NaN       NaN        NaN
# 6     □  ...           0        50.0       NaN       NaN       NaN        NaN
# 7     □  ...           0           -       NaN       NaN       NaN        NaN
# 8   nan  ...           0           -       NaN       NaN       NaN        NaN
# 9     □  ...           0           -       NaN       NaN       NaN        NaN
# 10    ■  ...           3        84.8       NaN       NaN       NaN        NaN
# 11    ●  ...           4        60.0       NaN       NaN       NaN        NaN
# 12    ■  ...           9        62.2       NaN       NaN       NaN        NaN
# 13  nan  ...           0           -       NaN       NaN       NaN        NaN
# 14  nan  ...          19        69.0       103        54         8       52.4
#
#    相手ブロック得点  相手ブロックセット平均  相手サーブ効果率  相手サーブレシーブ成功率
# 0       NaN          NaN       NaN           NaN
# 1       NaN          NaN       NaN           NaN
# 2       NaN          NaN       NaN           NaN
# 3       NaN          NaN       NaN           NaN
# 4       NaN          NaN       NaN           NaN
# 5       NaN          NaN       NaN           NaN
# 6       NaN          NaN       NaN           NaN
# 7       NaN          NaN       NaN           NaN
# 8       NaN          NaN       NaN           NaN
# 9       NaN          NaN       NaN           NaN
# 10      NaN          NaN       NaN           NaN
# 11      NaN          NaN       NaN           NaN
# 12      NaN          NaN       NaN           NaN
# 13      NaN          NaN       NaN           NaN
# 14        9         2.25       5.1          63.8
#
# [15 rows x 40 columns],            試合日     チーム    背番号    リベロ     名前  出場数    1    2    3    4  ...  \
# 0   2020-10-17  埼玉アザレア      1      L   川崎翔太    4    ●    ●    ●    ●  ...
# 1   2020-10-17  埼玉アザレア      2    NaN   加藤克貴    4    ■    ■    ■    ■  ...
# 2   2020-10-17  埼玉アザレア      3    NaN   石井和希    4    ■    ■    ■    ■  ...
# 3   2020-10-17  埼玉アザレア      5    NaN    佐藤匠    4    ■    ■    ■    ■  ...
# 4   2020-10-17  埼玉アザレア      6    NaN   浜田翔太    4    ■    ■    ■    ■  ...
# 5   2020-10-17  埼玉アザレア      7    NaN   笠原啓太    4    ■    ■    ■    ■  ...
# 6   2020-10-17  埼玉アザレア      8    NaN    筒井匠    3    □  nan    □    □  ...
# 7   2020-10-17  埼玉アザレア      9    NaN   前田将武    4    □    □    □    □  ...
# 8   2020-10-17  埼玉アザレア     10    NaN   川畑貴裕    0  nan  nan  nan  nan  ...
# 9   2020-10-17  埼玉アザレア     12    NaN   川副大海    0  nan  nan  nan  nan  ...
# 10  2020-10-17  埼玉アザレア     16    NaN    小堀優    0  nan  nan  nan  nan  ...
# 11  2020-10-17  埼玉アザレア     17    NaN   茂木祐太    4    ■    ■    ■    ■  ...
# 12  2020-10-17  埼玉アザレア     18    NaN   三浦一真    0  nan  nan  nan  nan  ...
# 13  2020-10-17  埼玉アザレア     19    NaN   堀内雄斗    1  nan  nan  nan    □  ...
# 14  2020-10-17  埼玉アザレア  チーム合計  チーム合計  チーム合計    4  nan  nan  nan  nan  ...
#
#    サーブレシーブ成功・良  サーブレシーブ成功率  相手アタック打数  相手アタック得点  相手アタック失点  相手アタック決定率 相手ブロック得点  \
# 0            3        53.1       NaN       NaN       NaN        NaN      NaN
# 1            7        66.1       NaN       NaN       NaN        NaN      NaN
# 2            0           -       NaN       NaN       NaN        NaN      NaN
# 3            0           -       NaN       NaN       NaN        NaN      NaN
# 4            2        50.0       NaN       NaN       NaN        NaN      NaN
# 5            0           -       NaN       NaN       NaN        NaN      NaN
# 6            0           -       NaN       NaN       NaN        NaN      NaN
# 7            0           -       NaN       NaN       NaN        NaN      NaN
# 8            0           -       NaN       NaN       NaN        NaN      NaN
# 9            0           -       NaN       NaN       NaN        NaN      NaN
# 10           0           -       NaN       NaN       NaN        NaN      NaN
# 11           2        68.4       NaN       NaN       NaN        NaN      NaN
# 12           0           -       NaN       NaN       NaN        NaN      NaN
# 13           0       100.0       NaN       NaN       NaN        NaN      NaN
# 14          14        63.8       129        53        14       41.1       11
#
#     相手ブロックセット平均  相手サーブ効果率  相手サーブレシーブ成功率
# 0           NaN       NaN           NaN
# 1           NaN       NaN           NaN
# 2           NaN       NaN           NaN
# 3           NaN       NaN           NaN
# 4           NaN       NaN           NaN
# 5           NaN       NaN           NaN
# 6           NaN       NaN           NaN
# 7           NaN       NaN           NaN
# 8           NaN       NaN           NaN
# 9           NaN       NaN           NaN
# 10          NaN       NaN           NaN
# 11          NaN       NaN           NaN
# 12          NaN       NaN           NaN
# 13          NaN       NaN           NaN
# 14         2.75       4.9          69.0
#
# [15 rows x 40 columns],            試合日               チーム    背番号    リベロ     名前  出場数    1    2    3  \
# 0   2020-10-18  つくばユナイテッドSunGAIA      1    NaN   上場雄也    4    ■    ■    ■
# 1   2020-10-18  つくばユナイテッドSunGAIA      2    NaN   浜崎勇矢    4    ■    ■    ■
# 2   2020-10-18  つくばユナイテッドSunGAIA      4    NaN   阿部航平    4    ■    ■    ■
# 3   2020-10-18  つくばユナイテッドSunGAIA      5    NaN   廣瀬優希    0  nan  nan  nan
# 4   2020-10-18  つくばユナイテッドSunGAIA      6    NaN   瀧澤陽紀    3  nan    □    □
# 5   2020-10-18  つくばユナイテッドSunGAIA      8    NaN    曹海倫    4    ■    ■    ■
# 6   2020-10-18  つくばユナイテッドSunGAIA     10    NaN   鎌田敏弥    2  nan  nan    □
# 7   2020-10-18  つくばユナイテッドSunGAIA     12    NaN   土井友登    1  nan    □  nan
# 8   2020-10-18  つくばユナイテッドSunGAIA     13      L   新垣東麻    1  nan  nan  nan
# 9   2020-10-18  つくばユナイテッドSunGAIA     14    NaN  勝本真太郎    3    □  nan    □
# 10  2020-10-18  つくばユナイテッドSunGAIA     20    NaN   満生大輝    4    ■    ■    ■
# 11  2020-10-18  つくばユナイテッドSunGAIA     22      L   関谷拓巳    4    ●    ●    ●
# 12  2020-10-18  つくばユナイテッドSunGAIA     23    NaN   曽田一也    4    ■    ■    ■
# 13  2020-10-18  つくばユナイテッドSunGAIA     26    NaN   鈴木匡教    2    □    □  nan
# 14  2020-10-18  つくばユナイテッドSunGAIA  チーム合計  チーム合計  チーム合計    4  nan  nan  nan
#
#       4  ... サーブレシーブ成功・良  サーブレシーブ成功率  相手アタック打数  相手アタック得点  相手アタック失点  相手アタック決定率  \
# 0     ■  ...           0           -       NaN       NaN       NaN        NaN
# 1     ■  ...           0           -       NaN       NaN       NaN        NaN
# 2     ■  ...           0       100.0       NaN       NaN       NaN        NaN
# 3   nan  ...           0           -       NaN       NaN       NaN        NaN
# 4     □  ...           0         0.0       NaN       NaN       NaN        NaN
# 5     ■  ...           0       100.0       NaN       NaN       NaN        NaN
# 6     □  ...           0       100.0       NaN       NaN       NaN        NaN
# 7   nan  ...           0           -       NaN       NaN       NaN        NaN
# 8     〇  ...           0           -       NaN       NaN       NaN        NaN
# 9     □  ...           0           -       NaN       NaN       NaN        NaN
# 10    ■  ...           1        59.5       NaN       NaN       NaN        NaN
# 11    ●  ...           1        46.9       NaN       NaN       NaN        NaN
# 12    ■  ...           4        78.9       NaN       NaN       NaN        NaN
# 13  nan  ...           0           -       NaN       NaN       NaN        NaN
# 14  nan  ...           6        63.3       117        41        11       35.0
#
#    相手ブロック得点  相手ブロックセット平均  相手サーブ効果率  相手サーブレシーブ成功率
# 0       NaN          NaN       NaN           NaN
# 1       NaN          NaN       NaN           NaN
# 2       NaN          NaN       NaN           NaN
# 3       NaN          NaN       NaN           NaN
# 4       NaN          NaN       NaN           NaN
# 5       NaN          NaN       NaN           NaN
# 6       NaN          NaN       NaN           NaN
# 7       NaN          NaN       NaN           NaN
# 8       NaN          NaN       NaN           NaN
# 9       NaN          NaN       NaN           NaN
# 10      NaN          NaN       NaN           NaN
# 11      NaN          NaN       NaN           NaN
# 12      NaN          NaN       NaN           NaN
# 13      NaN          NaN       NaN           NaN
# 14        3         0.75       8.2          61.3
#
# [15 rows x 40 columns],            試合日             チーム    背番号    リベロ     名前  出場数    1    2    3    4  \
# 0   2020-10-18  きんでんトリニティーブリッツ      1    NaN    岡本侑    4    ■    ■    ■    ■
# 1   2020-10-18  きんでんトリニティーブリッツ      3      L    長濱裕    4    ●    ●    ●    ●
# 2   2020-10-18  きんでんトリニティーブリッツ      5      L   大賀惠介    0  nan  nan  nan  nan
# 3   2020-10-18  きんでんトリニティーブリッツ      6    NaN    庄司練    1    ■  nan  nan  nan
# 4   2020-10-18  きんでんトリニティーブリッツ      7    NaN   田畑翔伍    3  nan    □    □    ■
# 5   2020-10-18  きんでんトリニティーブリッツ      9    NaN    内園徹    4    □    □    □    □
# 6   2020-10-18  きんでんトリニティーブリッツ     11    NaN   毛利光生    4    ■    ■    ■    ■
# 7   2020-10-18  きんでんトリニティーブリッツ     12    NaN   新谷俊揮    1  nan  nan    □  nan
# 8   2020-10-18  きんでんトリニティーブリッツ     14    NaN   谷川結人    4    ■    ■    ■    ■
# 9   2020-10-18  きんでんトリニティーブリッツ     15    NaN   古川一輝    1  nan  nan  nan    □
# 10  2020-10-18  きんでんトリニティーブリッツ     17    NaN   和治裕太    4    ■    ■    ■    ■
# 11  2020-10-18  きんでんトリニティーブリッツ     18    NaN   三木裕人    1  nan  nan  nan    □
# 12  2020-10-18  きんでんトリニティーブリッツ     21    NaN    小林空    3    ■    ■    ■  nan
# 13  2020-10-18  きんでんトリニティーブリッツ     23    NaN   福井裕貴    3  nan    ■    ■    ■
# 14  2020-10-18  きんでんトリニティーブリッツ  チーム合計  チーム合計  チーム合計    4  nan  nan  nan  nan
#
#     ... サーブレシーブ成功・良  サーブレシーブ成功率  相手アタック打数  相手アタック得点  相手アタック失点  相手アタック決定率  \
# 0   ...           4        70.0       NaN       NaN       NaN        NaN
# 1   ...           9        52.5       NaN       NaN       NaN        NaN
# 2   ...           0           -       NaN       NaN       NaN        NaN
# 3   ...           0         0.0       NaN       NaN       NaN        NaN
# 4   ...           1        56.2       NaN       NaN       NaN        NaN
# 5   ...           1        50.0       NaN       NaN       NaN        NaN
# 6   ...           0           -       NaN       NaN       NaN        NaN
# 7   ...           0         0.0       NaN       NaN       NaN        NaN
# 8   ...           1        68.8       NaN       NaN       NaN        NaN
# 9   ...           0           -       NaN       NaN       NaN        NaN
# 10  ...           0           -       NaN       NaN       NaN        NaN
# 11  ...           2        71.4       NaN       NaN       NaN        NaN
# 12  ...           0           -       NaN       NaN       NaN        NaN
# 13  ...           0           -       NaN       NaN       NaN        NaN
# 14  ...          18        61.3       106        54         7       50.9
#
#    相手ブロック得点  相手ブロックセット平均  相手サーブ効果率  相手サーブレシーブ成功率
# 0       NaN          NaN       NaN           NaN
# 1       NaN          NaN       NaN           NaN
# 2       NaN          NaN       NaN           NaN
# 3       NaN          NaN       NaN           NaN
# 4       NaN          NaN       NaN           NaN
# 5       NaN          NaN       NaN           NaN
# 6       NaN          NaN       NaN           NaN
# 7       NaN          NaN       NaN           NaN
# 8       NaN          NaN       NaN           NaN
# 9       NaN          NaN       NaN           NaN
# 10      NaN          NaN       NaN           NaN
# 11      NaN          NaN       NaN           NaN
# 12      NaN          NaN       NaN           NaN
# 13      NaN          NaN       NaN           NaN
# 14       13         3.25       1.3          63.3
#
# [15 rows x 40 columns],            試合日       チーム    背番号    リベロ      名前  出場数    1    2    3    4  ...  \
# 0   2020-10-24  長野GaRons      1    NaN     酒井駿    4    ■    ■    ■    ■  ...
# 1   2020-10-24  長野GaRons      2    NaN    鰐川怜児    4    ■    ■    ■    ■  ...
# 2   2020-10-24  長野GaRons      3      L    三角尚久    4    ●    ●    ●    ●  ...
# 3   2020-10-24  長野GaRons      4    NaN    渡部勇人    4    ■    ■    ■    □  ...
# 4   2020-10-24  長野GaRons      5    NaN     浅田潮    4    ■    ■    ■    ■  ...
# 5   2020-10-24  長野GaRons      6    NaN    松下祐太    4    □    □    □    □  ...
# 6   2020-10-24  長野GaRons      7    NaN  石坂ハスナヌ    4    ■    ■    ■    ■  ...
# 7   2020-10-24  長野GaRons      8    NaN    笹岡凪斗    2    □    □  nan  nan  ...
# 8   2020-10-24  長野GaRons      9    NaN    高瀬太一    4    ■    ■    ■    ■  ...
# 9   2020-10-24  長野GaRons     10    NaN    柳生大成    0  nan  nan  nan  nan  ...
# 10  2020-10-24  長野GaRons     12      L    山田広大    4    〇    〇    〇    〇  ...
# 11  2020-10-24  長野GaRons     14    NaN    高井大輝    3    □  nan    □    ■  ...
# 12  2020-10-24  長野GaRons     15    NaN    曾根裕也    1  nan  nan    □  nan  ...
# 13  2020-10-24  長野GaRons  チーム合計  チーム合計   チーム合計    4  nan  nan  nan  nan  ...
#
#    サーブレシーブ成功・良  サーブレシーブ成功率  相手アタック打数  相手アタック得点  相手アタック失点  相手アタック決定率 相手ブロック得点  \
# 0            6        52.4       NaN       NaN       NaN        NaN      NaN
# 1            1        50.0       NaN       NaN       NaN        NaN      NaN
# 2            0           -       NaN       NaN       NaN        NaN      NaN
# 3            0         0.0       NaN       NaN       NaN        NaN      NaN
# 4            3        42.6       NaN       NaN       NaN        NaN      NaN
# 5            1        75.0       NaN       NaN       NaN        NaN      NaN
# 6            0           -       NaN       NaN       NaN        NaN      NaN
# 7            0           -       NaN       NaN       NaN        NaN      NaN
# 8            0           -       NaN       NaN       NaN        NaN      NaN
# 9            0           -       NaN       NaN       NaN        NaN      NaN
# 10           6        62.5       NaN       NaN       NaN        NaN      NaN
# 11           0           -       NaN       NaN       NaN        NaN      NaN
# 12           0           -       NaN       NaN       NaN        NaN      NaN
# 13          17        52.1       136        60         9       44.1        8
#
#     相手ブロックセット平均  相手サーブ効果率  相手サーブレシーブ成功率
# 0           NaN       NaN           NaN
# 1           NaN       NaN           NaN
# 2           NaN       NaN           NaN
# 3           NaN       NaN           NaN
# 4           NaN       NaN           NaN
# 5           NaN       NaN           NaN
# 6           NaN       NaN           NaN
# 7           NaN       NaN           NaN
# 8           NaN       NaN           NaN
# 9           NaN       NaN           NaN
# 10          NaN       NaN           NaN
# 11          NaN       NaN           NaN
# 12          NaN       NaN           NaN
# 13         2.00       1.9          67.3
#
# [14 rows x 40 columns],            試合日        チーム    背番号    リベロ     名前  出場数    1    2    3    4  ...  \
# 0   2020-10-24  サフィルヴァ北海道      1    NaN   青島賢司    1    □  nan  nan  nan  ...
# 1   2020-10-24  サフィルヴァ北海道      2      L    神園時    4    ●    ●    ●    ●  ...
# 2   2020-10-24  サフィルヴァ北海道      3    NaN   河西智洋    3    □    □  nan    □  ...
# 3   2020-10-24  サフィルヴァ北海道      4    NaN   奥田基嗣    4    ■    ■    ■    ■  ...
# 4   2020-10-24  サフィルヴァ北海道      5    NaN   吉田康祐    1  nan  nan    □  nan  ...
# 5   2020-10-24  サフィルヴァ北海道      6    NaN   阿部誠樹    4    ■    ■    ■    ■  ...
# 6   2020-10-24  サフィルヴァ北海道      9    NaN    小林洸    3  nan    □    □    □  ...
# 7   2020-10-24  サフィルヴァ北海道     10    NaN    三浦拓    0  nan  nan  nan  nan  ...
# 8   2020-10-24  サフィルヴァ北海道     11    NaN  十良澤太一    0  nan  nan  nan  nan  ...
# 9   2020-10-24  サフィルヴァ北海道     14    NaN   山口拓馬    4    ■    ■    ■    ■  ...
# 10  2020-10-24  サフィルヴァ北海道     16      L   桝谷周呈    4    〇    〇    〇    〇  ...
# 11  2020-10-24  サフィルヴァ北海道     17    NaN   森元貴哉    4    ■    ■    ■    ■  ...
# 12  2020-10-24  サフィルヴァ北海道     20    NaN   佐藤陸善    4    ■    ■    ■    ■  ...
# 13  2020-10-24  サフィルヴァ北海道     22    NaN    柏田樹    4    ■    ■    ■    ■  ...
# 14  2020-10-24  サフィルヴァ北海道  チーム合計  チーム合計  チーム合計    4  nan  nan  nan  nan  ...
#
#    サーブレシーブ成功・良  サーブレシーブ成功率  相手アタック打数  相手アタック得点  相手アタック失点  相手アタック決定率 相手ブロック得点  \
# 0            0           -       NaN       NaN       NaN        NaN      NaN
# 1            2        65.0       NaN       NaN       NaN        NaN      NaN
# 2            3        64.3       NaN       NaN       NaN        NaN      NaN
# 3            0           -       NaN       NaN       NaN        NaN      NaN
# 4            0           -       NaN       NaN       NaN        NaN      NaN
# 5            7        69.1       NaN       NaN       NaN        NaN      NaN
# 6            0           -       NaN       NaN       NaN        NaN      NaN
# 7            0           -       NaN       NaN       NaN        NaN      NaN
# 8            0           -       NaN       NaN       NaN        NaN      NaN
# 9            0           -       NaN       NaN       NaN        NaN      NaN
# 10           0           -       NaN       NaN       NaN        NaN      NaN
# 11           7        67.5       NaN       NaN       NaN        NaN      NaN
# 12           0           -       NaN       NaN       NaN        NaN      NaN
# 13           0           -       NaN       NaN       NaN        NaN      NaN
# 14          19        67.3       103        45        16       43.7        9
#
#     相手ブロックセット平均  相手サーブ効果率  相手サーブレシーブ成功率
# 0           NaN       NaN           NaN
# 1           NaN       NaN           NaN
# 2           NaN       NaN           NaN
# 3           NaN       NaN           NaN
# 4           NaN       NaN           NaN
# 5           NaN       NaN           NaN
# 6           NaN       NaN           NaN
# 7           NaN       NaN           NaN
# 8           NaN       NaN           NaN
# 9           NaN       NaN           NaN
# 10          NaN       NaN           NaN
# 11          NaN       NaN           NaN
# 12          NaN       NaN           NaN
# 13          NaN       NaN           NaN
# 14         2.25       3.7          52.1
#
# [15 rows x 40 columns],            試合日       チーム    背番号    リベロ     名前  出場数    1    2    3    4  ...  \
# 0   2020-10-24  ヴォレアス北海道      0    NaN    越川優    4    ■    ■    ■    ■  ...
# 1   2020-10-24  ヴォレアス北海道      3    NaN   田城貴之    0  nan  nan  nan  nan  ...
# 2   2020-10-24  ヴォレアス北海道      5    NaN   家近滉一    0  nan  nan  nan  nan  ...
# 3   2020-10-24  ヴォレアス北海道      6    NaN   本澤凌斗    0  nan  nan  nan  nan  ...
# 4   2020-10-24  ヴォレアス北海道      7    NaN   関根俊哉    0  nan  nan  nan  nan  ...
# 5   2020-10-24  ヴォレアス北海道      9    NaN   加藤伊織    0  nan  nan  nan  nan  ...
# 6   2020-10-24  ヴォレアス北海道     10      L   白石啓丈    4    ●    ●    ●    ●  ...
# 7   2020-10-24  ヴォレアス北海道     11      L   藤村昇太    0  nan  nan  nan  nan  ...
# 8   2020-10-24  ヴォレアス北海道     13    NaN  佐々木博秋    0  nan  nan  nan  nan  ...
# 9   2020-10-24  ヴォレアス北海道     14    NaN    張育陞    4    ■    ■    ■    ■  ...
# 10  2020-10-24  ヴォレアス北海道     17    NaN    辰巳遼    4    ■    ■    ■    ■  ...
# 11  2020-10-24  ヴォレアス北海道     18    NaN   後藤万澄    4    ■    ■    ■    ■  ...
# 12  2020-10-24  ヴォレアス北海道     20    NaN   戸田拓也    4    ■    ■    ■    ■  ...
# 13  2020-10-24  ヴォレアス北海道     23    NaN   田城広光    4    ■    ■    ■    ■  ...
# 14  2020-10-24  ヴォレアス北海道  チーム合計  チーム合計  チーム合計    4  nan  nan  nan  nan  ...
#
#    サーブレシーブ成功・良  サーブレシーブ成功率  相手アタック打数  相手アタック得点  相手アタック失点  相手アタック決定率 相手ブロック得点  \
# 0            5        56.8       NaN       NaN       NaN        NaN      NaN
# 1            0           -       NaN       NaN       NaN        NaN      NaN
# 2            0           -       NaN       NaN       NaN        NaN      NaN
# 3            0           -       NaN       NaN       NaN        NaN      NaN
# 4            0           -       NaN       NaN       NaN        NaN      NaN
# 5            0           -       NaN       NaN       NaN        NaN      NaN
# 6            1        73.1       NaN       NaN       NaN        NaN      NaN
# 7            0           -       NaN       NaN       NaN        NaN      NaN
# 8            0           -       NaN       NaN       NaN        NaN      NaN
# 9            0           -       NaN       NaN       NaN        NaN      NaN
# 10           0           -       NaN       NaN       NaN        NaN      NaN
# 11           0           -       NaN       NaN       NaN        NaN      NaN
# 12           5        63.0       NaN       NaN       NaN        NaN      NaN
# 13           0       100.0       NaN       NaN       NaN        NaN      NaN
# 14          11        63.6       113        48        15       42.5        5
#
#     相手ブロックセット平均  相手サーブ効果率  相手サーブレシーブ成功率
# 0           NaN       NaN           NaN
# 1           NaN       NaN           NaN
# 2           NaN       NaN           NaN
# 3           NaN       NaN           NaN
# 4           NaN       NaN           NaN
# 5           NaN       NaN           NaN
# 6           NaN       NaN           NaN
# 7           NaN       NaN           NaN
# 8           NaN       NaN           NaN
# 9           NaN       NaN           NaN
# 10          NaN       NaN           NaN
# 11          NaN       NaN           NaN
# 12          NaN       NaN           NaN
# 13          NaN       NaN           NaN
# 14         1.25       5.8          66.2
#
# [15 rows x 40 columns],            試合日       チーム    背番号    リベロ     名前  出場数    1    2    3    4  ...  \
# 0   2020-10-24  ヴィアティン三重      1    NaN   落合一輝    4    □    □    □    □  ...
# 1   2020-10-24  ヴィアティン三重      2    NaN   中村有登    4    ■    ■    ■    ■  ...
# 2   2020-10-24  ヴィアティン三重      3    NaN   野垣昂大    4    ■    ■    ■    ■  ...
# 3   2020-10-24  ヴィアティン三重      4    NaN   石川和樹    3  nan    □    □    ■  ...
# 4   2020-10-24  ヴィアティン三重      6    NaN    米村尊    1  nan    □  nan  nan  ...
# 5   2020-10-24  ヴィアティン三重      8    NaN  長谷川博紀    4    ■    ■    ■    ■  ...
# 6   2020-10-24  ヴィアティン三重     10      L   外崎航平    4    〇    〇    〇    〇  ...
# 7   2020-10-24  ヴィアティン三重     11    NaN   前川将太    2  nan    ■    □  nan  ...
# 8   2020-10-24  ヴィアティン三重     12      L  大浦坂健太    4    ●    ●    ●    ●  ...
# 9   2020-10-24  ヴィアティン三重     15    NaN  茶屋道康輔    4    ■    ■    ■    ■  ...
# 10  2020-10-24  ヴィアティン三重     16    NaN   安田瑛亮    4    ■    ■    ■    ■  ...
# 11  2020-10-24  ヴィアティン三重     21    NaN   上出哲也    0  nan  nan  nan  nan  ...
# 12  2020-10-24  ヴィアティン三重     23    NaN   北田陽季    3    ■    □    ■  nan  ...
# 13  2020-10-24  ヴィアティン三重     39    NaN   諏訪晃大    1  nan  nan  nan    □  ...
# 14  2020-10-24  ヴィアティン三重  チーム合計  チーム合計  チーム合計    4  nan  nan  nan  nan  ...
#
#    サーブレシーブ成功・良  サーブレシーブ成功率  相手アタック打数  相手アタック得点  相手アタック失点  相手アタック決定率 相手ブロック得点  \
# 0            0           -       NaN       NaN       NaN        NaN      NaN
# 1            1        12.5       NaN       NaN       NaN        NaN      NaN
# 2            0         0.0       NaN       NaN       NaN        NaN      NaN
# 3            1        75.0       NaN       NaN       NaN        NaN      NaN
# 4            0       100.0       NaN       NaN       NaN        NaN      NaN
# 5            0           -       NaN       NaN       NaN        NaN      NaN
# 6            0           -       NaN       NaN       NaN        NaN      NaN
# 7            2        50.0       NaN       NaN       NaN        NaN      NaN
# 8            3        59.4       NaN       NaN       NaN        NaN      NaN
# 9            0           -       NaN       NaN       NaN        NaN      NaN
# 10           5        73.9       NaN       NaN       NaN        NaN      NaN
# 11           0           -       NaN       NaN       NaN        NaN      NaN
# 12           0           -       NaN       NaN       NaN        NaN      NaN
# 13           0           -       NaN       NaN       NaN        NaN      NaN
# 14          12        66.2        91        42         4       46.2       11
#
#     相手ブロックセット平均  相手サーブ効果率  相手サーブレシーブ成功率
# 0           NaN       NaN           NaN
# 1           NaN       NaN           NaN
# 2           NaN       NaN           NaN
# 3           NaN       NaN           NaN
# 4           NaN       NaN           NaN
# 5           NaN       NaN           NaN
# 6           NaN       NaN           NaN
# 7           NaN       NaN           NaN
# 8           NaN       NaN           NaN
# 9           NaN       NaN           NaN
# 10          NaN       NaN           NaN
# 11          NaN       NaN           NaN
# 12          NaN       NaN           NaN
# 13          NaN       NaN           NaN
# 14         2.75       4.1          63.6
#
# [15 rows x 40 columns],            試合日       チーム    背番号    リベロ      名前  出場数    1    2    3    4  ...  \
# 0   2020-10-25  長野GaRons      1    NaN     酒井駿    3    ■    ■    ■  nan  ...
# 1   2020-10-25  長野GaRons      2    NaN    鰐川怜児    3    ■    ■    ■  nan  ...
# 2   2020-10-25  長野GaRons      3      L    三角尚久    3    ●    ●    ●  nan  ...
# 3   2020-10-25  長野GaRons      4    NaN    渡部勇人    3    □    □    □  nan  ...
# 4   2020-10-25  長野GaRons      5    NaN     浅田潮    3    ■    ■    ■  nan  ...
# 5   2020-10-25  長野GaRons      6    NaN    松下祐太    3    □    □    □  nan  ...
# 6   2020-10-25  長野GaRons      7    NaN  石坂ハスナヌ    3    ■    ■    ■  nan  ...
# 7   2020-10-25  長野GaRons      8    NaN    笹岡凪斗    0  nan  nan  nan  nan  ...
# 8   2020-10-25  長野GaRons      9    NaN    高瀬太一    3    ■    ■    ■  nan  ...
# 9   2020-10-25  長野GaRons     10    NaN    柳生大成    0  nan  nan  nan  nan  ...
# 10  2020-10-25  長野GaRons     12      L    山田広大    3    〇    〇    〇  nan  ...
# 11  2020-10-25  長野GaRons     14    NaN    高井大輝    3    ■    ■    ■  nan  ...
# 12  2020-10-25  長野GaRons     15    NaN    曾根裕也    3    □    □    □  nan  ...
# 13  2020-10-25  長野GaRons  チーム合計  チーム合計   チーム合計    3  nan  nan  nan  nan  ...
#
#    サーブレシーブ成功・良  サーブレシーブ成功率  相手アタック打数  相手アタック得点  相手アタック失点  相手アタック決定率 相手ブロック得点  \
# 0            6        62.5       NaN       NaN       NaN        NaN      NaN
# 1            0           -       NaN       NaN       NaN        NaN      NaN
# 2            0           -       NaN       NaN       NaN        NaN      NaN
# 3            0           -       NaN       NaN       NaN        NaN      NaN
# 4            2        33.3       NaN       NaN       NaN        NaN      NaN
# 5            2        72.7       NaN       NaN       NaN        NaN      NaN
# 6            0           -       NaN       NaN       NaN        NaN      NaN
# 7            0           -       NaN       NaN       NaN        NaN      NaN
# 8            0           -       NaN       NaN       NaN        NaN      NaN
# 9            0           -       NaN       NaN       NaN        NaN      NaN
# 10           1        73.1       NaN       NaN       NaN        NaN      NaN
# 11           0           -       NaN       NaN       NaN        NaN      NaN
# 12           0           -       NaN       NaN       NaN        NaN      NaN
# 13          11        63.9       102        35         9       34.3        7
#
#     相手ブロックセット平均  相手サーブ効果率  相手サーブレシーブ成功率
# 0           NaN       NaN           NaN
# 1           NaN       NaN           NaN
# 2           NaN       NaN           NaN
# 3           NaN       NaN           NaN
# 4           NaN       NaN           NaN
# 5           NaN       NaN           NaN
# 6           NaN       NaN           NaN
# 7           NaN       NaN           NaN
# 8           NaN       NaN           NaN
# 9           NaN       NaN           NaN
# 10          NaN       NaN           NaN
# 11          NaN       NaN           NaN
# 12          NaN       NaN           NaN
# 13         2.33       3.6          61.4
#
# [14 rows x 40 columns],            試合日        チーム    背番号    リベロ     名前  出場数    1    2    3    4  ...  \
# 0   2020-10-25  サフィルヴァ北海道      1    NaN   青島賢司    0  nan  nan  nan  nan  ...
# 1   2020-10-25  サフィルヴァ北海道      2      L    神園時    3    ●    ●    ●  nan  ...
# 2   2020-10-25  サフィルヴァ北海道      3    NaN   河西智洋    3    □    □    □  nan  ...
# 3   2020-10-25  サフィルヴァ北海道      4    NaN   奥田基嗣    3    ■    ■    ■  nan  ...
# 4   2020-10-25  サフィルヴァ北海道      5    NaN   吉田康祐    0  nan  nan  nan  nan  ...
# 5   2020-10-25  サフィルヴァ北海道      6    NaN   阿部誠樹    3    ■    ■    ■  nan  ...
# 6   2020-10-25  サフィルヴァ北海道     10    NaN    三浦拓    0  nan  nan  nan  nan  ...
# 7   2020-10-25  サフィルヴァ北海道     11    NaN  十良澤太一    1  nan    □  nan  nan  ...
# 8   2020-10-25  サフィルヴァ北海道     14    NaN   山口拓馬    3    ■    ■    ■  nan  ...
# 9   2020-10-25  サフィルヴァ北海道     15    NaN   河西孔明    1    □  nan  nan  nan  ...
# 10  2020-10-25  サフィルヴァ北海道     16      L   桝谷周呈    3    〇    〇    〇  nan  ...
# 11  2020-10-25  サフィルヴァ北海道     17    NaN   森元貴哉    3    ■    ■    ■  nan  ...
# 12  2020-10-25  サフィルヴァ北海道     20    NaN   佐藤陸善    3    ■    ■    ■  nan  ...
# 13  2020-10-25  サフィルヴァ北海道     22    NaN    柏田樹    3    ■    ■    ■  nan  ...
# 14  2020-10-25  サフィルヴァ北海道  チーム合計  チーム合計  チーム合計    3  nan  nan  nan  nan  ...
#
#    サーブレシーブ成功・良  サーブレシーブ成功率  相手アタック打数  相手アタック得点  相手アタック失点  相手アタック決定率 相手ブロック得点  \
# 0            0           -       NaN       NaN       NaN        NaN      NaN
# 1            4        77.3       NaN       NaN       NaN        NaN      NaN
# 2            0         0.0       NaN       NaN       NaN        NaN      NaN
# 3            0           -       NaN       NaN       NaN        NaN      NaN
# 4            0           -       NaN       NaN       NaN        NaN      NaN
# 5            5        71.1       NaN       NaN       NaN        NaN      NaN
# 6            0           -       NaN       NaN       NaN        NaN      NaN
# 7            0           -       NaN       NaN       NaN        NaN      NaN
# 8            0           -       NaN       NaN       NaN        NaN      NaN
# 9            0           -       NaN       NaN       NaN        NaN      NaN
# 10           0           -       NaN       NaN       NaN        NaN      NaN
# 11           6        47.6       NaN       NaN       NaN        NaN      NaN
# 12           0           -       NaN       NaN       NaN        NaN      NaN
# 13           0           -       NaN       NaN       NaN        NaN      NaN
# 14          15        61.4        93        42         9       45.2       12
#
#     相手ブロックセット平均  相手サーブ効果率  相手サーブレシーブ成功率
# 0           NaN       NaN           NaN
# 1           NaN       NaN           NaN
# 2           NaN       NaN           NaN
# 3           NaN       NaN           NaN
# 4           NaN       NaN           NaN
# 5           NaN       NaN           NaN
# 6           NaN       NaN           NaN
# 7           NaN       NaN           NaN
# 8           NaN       NaN           NaN
# 9           NaN       NaN           NaN
# 10          NaN       NaN           NaN
# 11          NaN       NaN           NaN
# 12          NaN       NaN           NaN
# 13          NaN       NaN           NaN
# 14         4.00       5.1          63.9
#
# [15 rows x 40 columns],            試合日       チーム    背番号    リベロ     名前  出場数    1    2    3    4  ...  \
# 0   2020-10-25  ヴォレアス北海道      0    NaN    越川優    0  nan  nan  nan  nan  ...
# 1   2020-10-25  ヴォレアス北海道      3    NaN   田城貴之    3    ■    ■    ■  nan  ...
# 2   2020-10-25  ヴォレアス北海道      5    NaN   家近滉一    3    ■    ■    ■  nan  ...
# 3   2020-10-25  ヴォレアス北海道      6    NaN   本澤凌斗    3    ■    ■    ■  nan  ...
# 4   2020-10-25  ヴォレアス北海道      7    NaN   関根俊哉    1  nan  nan    ■  nan  ...
# 5   2020-10-25  ヴォレアス北海道      9    NaN   加藤伊織    0  nan  nan  nan  nan  ...
# 6   2020-10-25  ヴォレアス北海道     10      L   白石啓丈    3    ●    ●    ●  nan  ...
# 7   2020-10-25  ヴォレアス北海道     11      L   藤村昇太    1  nan  nan    〇  nan  ...
# 8   2020-10-25  ヴォレアス北海道     13    NaN  佐々木博秋    3    ■    ■    ■  nan  ...
# 9   2020-10-25  ヴォレアス北海道     14    NaN    張育陞    3    ■    ■    ■  nan  ...
# 10  2020-10-25  ヴォレアス北海道     17    NaN    辰巳遼    0  nan  nan  nan  nan  ...
# 11  2020-10-25  ヴォレアス北海道     18    NaN   後藤万澄    0  nan  nan  nan  nan  ...
# 12  2020-10-25  ヴォレアス北海道     20    NaN   戸田拓也    0  nan  nan  nan  nan  ...
# 13  2020-10-25  ヴォレアス北海道     23    NaN   田城広光    2    ■    ■  nan  nan  ...
# 14  2020-10-25  ヴォレアス北海道  チーム合計  チーム合計  チーム合計    3  nan  nan  nan  nan  ...
#
#    サーブレシーブ成功・良  サーブレシーブ成功率  相手アタック打数  相手アタック得点  相手アタック失点  相手アタック決定率 相手ブロック得点  \
# 0            0           -       NaN       NaN       NaN        NaN      NaN
# 1            0         0.0       NaN       NaN       NaN        NaN      NaN
# 2            7        60.3       NaN       NaN       NaN        NaN      NaN
# 3            0           -       NaN       NaN       NaN        NaN      NaN
# 4            1        25.0       NaN       NaN       NaN        NaN      NaN
# 5            0           -       NaN       NaN       NaN        NaN      NaN
# 6            1        87.5       NaN       NaN       NaN        NaN      NaN
# 7            0           -       NaN       NaN       NaN        NaN      NaN
# 8            3        65.0       NaN       NaN       NaN        NaN      NaN
# 9            0           -       NaN       NaN       NaN        NaN      NaN
# 10           0           -       NaN       NaN       NaN        NaN      NaN
# 11           0           -       NaN       NaN       NaN        NaN      NaN
# 12           0           -       NaN       NaN       NaN        NaN      NaN
# 13           2        50.0       NaN       NaN       NaN        NaN      NaN
# 14          14        60.4        76        29        10       38.2        3
#
#     相手ブロックセット平均  相手サーブ効果率  相手サーブレシーブ成功率
# 0           NaN       NaN           NaN
# 1           NaN       NaN           NaN
# 2           NaN       NaN           NaN
# 3           NaN       NaN           NaN
# 4           NaN       NaN           NaN
# 5           NaN       NaN           NaN
# 6           NaN       NaN           NaN
# 7           NaN       NaN           NaN
# 8           NaN       NaN           NaN
# 9           NaN       NaN           NaN
# 10          NaN       NaN           NaN
# 11          NaN       NaN           NaN
# 12          NaN       NaN           NaN
# 13          NaN       NaN           NaN
# 14         1.00       6.4          60.3
#
# [15 rows x 40 columns],            試合日       チーム    背番号    リベロ     名前  出場数    1    2    3    4  ...  \
# 0   2020-10-25  ヴィアティン三重      1    NaN   落合一輝    2    □    □  nan  nan  ...
# 1   2020-10-25  ヴィアティン三重      2    NaN   中村有登    1    ■  nan  nan  nan  ...
# 2   2020-10-25  ヴィアティン三重      3    NaN   野垣昂大    3    ■    ■    ■  nan  ...
# 3   2020-10-25  ヴィアティン三重      4    NaN   石川和樹    1    ■  nan  nan  nan  ...
# 4   2020-10-25  ヴィアティン三重      6    NaN    米村尊    1  nan  nan    □  nan  ...
# 5   2020-10-25  ヴィアティン三重      8    NaN  長谷川博紀    1    ■  nan  nan  nan  ...
# 6   2020-10-25  ヴィアティン三重     10      L   外崎航平    3    ●    ●    ●  nan  ...
# 7   2020-10-25  ヴィアティン三重     11    NaN   前川将太    1  nan    ■  nan  nan  ...
# 8   2020-10-25  ヴィアティン三重     12      L  大浦坂健太    3    〇    〇    〇  nan  ...
# 9   2020-10-25  ヴィアティン三重     15    NaN  茶屋道康輔    3    ■    ■    ■  nan  ...
# 10  2020-10-25  ヴィアティン三重     16    NaN   安田瑛亮    3    ■    ■    ■  nan  ...
# 11  2020-10-25  ヴィアティン三重     21    NaN   上出哲也    2  nan    ■    ■  nan  ...
# 12  2020-10-25  ヴィアティン三重     23    NaN   北田陽季    1  nan  nan    ■  nan  ...
# 13  2020-10-25  ヴィアティン三重     39    NaN   諏訪晃大    2  nan    ■    ■  nan  ...
# 14  2020-10-25  ヴィアティン三重  チーム合計  チーム合計  チーム合計    3  nan  nan  nan  nan  ...
#
#    サーブレシーブ成功・良  サーブレシーブ成功率  相手アタック打数  相手アタック得点  相手アタック失点  相手アタック決定率 相手ブロック得点  \
# 0            0           -       NaN       NaN       NaN        NaN      NaN
# 1            0           -       NaN       NaN       NaN        NaN      NaN
# 2            0           -       NaN       NaN       NaN        NaN      NaN
# 3            1        35.7       NaN       NaN       NaN        NaN      NaN
# 4            0           -       NaN       NaN       NaN        NaN      NaN
# 5            0           -       NaN       NaN       NaN        NaN      NaN
# 6            0           -       NaN       NaN       NaN        NaN      NaN
# 7            3        62.5       NaN       NaN       NaN        NaN      NaN
# 8            3        67.6       NaN       NaN       NaN        NaN      NaN
# 9            0           -       NaN       NaN       NaN        NaN      NaN
# 10           6        69.2       NaN       NaN       NaN        NaN      NaN
# 11           0           -       NaN       NaN       NaN        NaN      NaN
# 12           1        12.5       NaN       NaN       NaN        NaN      NaN
# 13           0           -       NaN       NaN       NaN        NaN      NaN
# 14          14        60.3        70        41         4       58.6       11
#
#     相手ブロックセット平均  相手サーブ効果率  相手サーブレシーブ成功率
# 0           NaN       NaN           NaN
# 1           NaN       NaN           NaN
# 2           NaN       NaN           NaN
# 3           NaN       NaN           NaN
# 4           NaN       NaN           NaN
# 5           NaN       NaN           NaN
# 6           NaN       NaN           NaN
# 7           NaN       NaN           NaN
# 8           NaN       NaN           NaN
# 9           NaN       NaN           NaN
# 10          NaN       NaN           NaN
# 11          NaN       NaN           NaN
# 12          NaN       NaN           NaN
# 13          NaN       NaN           NaN
# 14         3.67      10.1          60.4
#
# [15 rows x 40 columns],            試合日              チーム    背番号    リベロ            名前  出場数    1    2  \
# 0   2020-10-31  富士通カワサキレッドスピリッツ      1    NaN  エバデダンジェフリー宇意    2    ■    ■
# 1   2020-10-31  富士通カワサキレッドスピリッツ      2    NaN          松坂洸汰    1  nan  nan
# 2   2020-10-31  富士通カワサキレッドスピリッツ      4    NaN          柳田百織    3    ■    ■
# 3   2020-10-31  富士通カワサキレッドスピリッツ      5    NaN          吉田綜眞    2  nan    □
# 4   2020-10-31  富士通カワサキレッドスピリッツ      6      L          小林慎平    3    ●    ●
# 5   2020-10-31  富士通カワサキレッドスピリッツ      7    NaN          加藤大雄    2    ■    ■
# 6   2020-10-31  富士通カワサキレッドスピリッツ      9    NaN           手塚奨    2    □  nan
# 7   2020-10-31  富士通カワサキレッドスピリッツ     10    NaN          岡村義郎    1  nan  nan
# 8   2020-10-31  富士通カワサキレッドスピリッツ     11    NaN          浅野卓雅    2    ■    ■
# 9   2020-10-31  富士通カワサキレッドスピリッツ     13    NaN          兵頭佳樹    3    ■    ■
# 10  2020-10-31  富士通カワサキレッドスピリッツ     17    NaN           角大樹    1  nan  nan
# 11  2020-10-31  富士通カワサキレッドスピリッツ     18    NaN          長谷山拓    3    ■    ■
# 12  2020-10-31  富士通カワサキレッドスピリッツ     19      L           尾木将    1  nan  nan
# 13  2020-10-31  富士通カワサキレッドスピリッツ     20    NaN          志波京介    2  nan    □
# 14  2020-10-31  富士通カワサキレッドスピリッツ  チーム合計  チーム合計         チーム合計    3  nan  nan
#
#       3    4  ... サーブレシーブ成功・良  サーブレシーブ成功率  相手アタック打数  相手アタック得点  相手アタック失点  \
# 0   nan  nan  ...           1        50.0       NaN       NaN       NaN
# 1     ■  nan  ...           0           -       NaN       NaN       NaN
# 2     ■  nan  ...           0       100.0       NaN       NaN       NaN
# 3     □  nan  ...           0           -       NaN       NaN       NaN
# 4     ●  nan  ...           1        94.4       NaN       NaN       NaN
# 5   nan  nan  ...           0           -       NaN       NaN       NaN
# 6     □  nan  ...           0           -       NaN       NaN       NaN
# 7     ■  nan  ...           0           -       NaN       NaN       NaN
# 8   nan  nan  ...           3        83.3       NaN       NaN       NaN
# 9     ■  nan  ...           2        50.0       NaN       NaN       NaN
# 10    ■  nan  ...           0        66.7       NaN       NaN       NaN
# 11    ■  nan  ...           0           -       NaN       NaN       NaN
# 12    〇  nan  ...           1        75.0       NaN       NaN       NaN
# 13    □  nan  ...           0           -       NaN       NaN       NaN
# 14  nan  nan  ...           8        73.7        70        18        11
#
#     相手アタック決定率 相手ブロック得点  相手ブロックセット平均  相手サーブ効果率  相手サーブレシーブ成功率
# 0         NaN      NaN          NaN       NaN           NaN
# 1         NaN      NaN          NaN       NaN           NaN
# 2         NaN      NaN          NaN       NaN           NaN
# 3         NaN      NaN          NaN       NaN           NaN
# 4         NaN      NaN          NaN       NaN           NaN
# 5         NaN      NaN          NaN       NaN           NaN
# 6         NaN      NaN          NaN       NaN           NaN
# 7         NaN      NaN          NaN       NaN           NaN
# 8         NaN      NaN          NaN       NaN           NaN
# 9         NaN      NaN          NaN       NaN           NaN
# 10        NaN      NaN          NaN       NaN           NaN
# 11        NaN      NaN          NaN       NaN           NaN
# 12        NaN      NaN          NaN       NaN           NaN
# 13        NaN      NaN          NaN       NaN           NaN
# 14       25.7        5         1.67      -1.5          50.0
#
# [15 rows x 40 columns],            試合日       チーム    背番号    リベロ        名前  出場数    1    2    3    4  \
# 0   2020-10-31  兵庫デルフィーノ      1    NaN       西澤岳    3    ■    ■    ■  nan
# 1   2020-10-31  兵庫デルフィーノ      2    NaN      白川佑樹    0  nan  nan  nan  nan
# 2   2020-10-31  兵庫デルフィーノ      3    NaN       逢沢亘    3    ■    ■    ■  nan
# 3   2020-10-31  兵庫デルフィーノ      5      L      中野将太    3    ●    ●    ●  nan
# 4   2020-10-31  兵庫デルフィーノ      6    NaN      浅草大燿    3    ■    ■    ■  nan
# 5   2020-10-31  兵庫デルフィーノ      7    NaN      田中寛人    3    ■    ■    ■  nan
# 6   2020-10-31  兵庫デルフィーノ      8    NaN      加藤遼太    0  nan  nan  nan  nan
# 7   2020-10-31  兵庫デルフィーノ      9    NaN      玉嶋佑樹    0  nan  nan  nan  nan
# 8   2020-10-31  兵庫デルフィーノ     11    NaN      澁谷杜斗    3    ■    ■    ■  nan
# 9   2020-10-31  兵庫デルフィーノ     12      L      猪岡恭平    2    〇    〇  nan  nan
# 10  2020-10-31  兵庫デルフィーノ     13    NaN      仲村鴻輝    1    □  nan  nan  nan
# 11  2020-10-31  兵庫デルフィーノ     14    NaN       林優作    0  nan  nan  nan  nan
# 12  2020-10-31  兵庫デルフィーノ     21    NaN  マシューパロット    3    ■    ■    ■  nan
# 13  2020-10-31  兵庫デルフィーノ     22    NaN       奥田晃    3    □    □    □  nan
# 14  2020-10-31  兵庫デルフィーノ  チーム合計  チーム合計     チーム合計    3  nan  nan  nan  nan
#
#     ... サーブレシーブ成功・良  サーブレシーブ成功率  相手アタック打数  相手アタック得点  相手アタック失点  相手アタック決定率  \
# 0   ...           0           -       NaN       NaN       NaN        NaN
# 1   ...           0           -       NaN       NaN       NaN        NaN
# 2   ...           1        50.0       NaN       NaN       NaN        NaN
# 3   ...           0        50.0       NaN       NaN       NaN        NaN
# 4   ...           0           -       NaN       NaN       NaN        NaN
# 5   ...           0           -       NaN       NaN       NaN        NaN
# 6   ...           0           -       NaN       NaN       NaN        NaN
# 7   ...           0           -       NaN       NaN       NaN        NaN
# ...
# 0   2021-03-06  埼玉アザレア      1      L   川崎翔太    3    ●    ●    ●  nan  ...
# 1   2021-03-06  埼玉アザレア      2    NaN   加藤克貴    1  nan  nan    □  nan  ...
# 2   2021-03-06  埼玉アザレア      3    NaN   石井和希    3    ■    ■    ■  nan  ...
# 3   2021-03-06  埼玉アザレア      4    NaN    中野竜    3    ■    ■    ■  nan  ...
# 4   2021-03-06  埼玉アザレア      5    NaN    佐藤匠    3    ■    ■    ■  nan  ...
# 5   2021-03-06  埼玉アザレア      6    NaN   浜田翔太    3    ■    ■    ■  nan  ...
# 6   2021-03-06  埼玉アザレア      7    NaN   笠原啓太    3    ■    ■    ■  nan  ...
# 7   2021-03-06  埼玉アザレア      8    NaN    筒井匠    3    □    □    □  nan  ...
# 8   2021-03-06  埼玉アザレア      9    NaN   前田将武    0  nan  nan  nan  nan  ...
# 9   2021-03-06  埼玉アザレア     10    NaN   川畑貴裕    3    ■    ■    ■  nan  ...
# 10  2021-03-06  埼玉アザレア     13    NaN   小島大輝    0  nan  nan  nan  nan  ...
# 11  2021-03-06  埼玉アザレア     16    NaN    小堀優    0  nan  nan  nan  nan  ...
# 12  2021-03-06  埼玉アザレア     17    NaN   茂木祐太    0  nan  nan  nan  nan  ...
# 13  2021-03-06  埼玉アザレア  チーム合計  チーム合計  チーム合計    3  nan  nan  nan  nan  ...
#
#    サーブレシーブ成功・良  サーブレシーブ成功率  相手アタック打数  相手アタック得点  相手アタック失点  相手アタック決定率 相手ブロック得点  \
# 0            2        56.0       NaN       NaN       NaN        NaN      NaN
# 1            0         0.0       NaN       NaN       NaN        NaN      NaN
# 2            0           -       NaN       NaN       NaN        NaN      NaN
# 3            5        47.7       NaN       NaN       NaN        NaN      NaN
# 4            0           -       NaN       NaN       NaN        NaN      NaN
# 5            0           -       NaN       NaN       NaN        NaN      NaN
# 6            0           -       NaN       NaN       NaN        NaN      NaN
# 7            0           -       NaN       NaN       NaN        NaN      NaN
# 8            0           -       NaN       NaN       NaN        NaN      NaN
# 9            1        86.4       NaN       NaN       NaN        NaN      NaN
# 10           0           -       NaN       NaN       NaN        NaN      NaN
# 11           0           -       NaN       NaN       NaN        NaN      NaN
# 12           0           -       NaN       NaN       NaN        NaN      NaN
# 13           8        57.6        93        43         8       46.2       13
#
#     相手ブロックセット平均  相手サーブ効果率  相手サーブレシーブ成功率
# 0           NaN       NaN           NaN
# 1           NaN       NaN           NaN
# 2           NaN       NaN           NaN
# 3           NaN       NaN           NaN
# 4           NaN       NaN           NaN
# 5           NaN       NaN           NaN
# 6           NaN       NaN           NaN
# 7           NaN       NaN           NaN
# 8           NaN       NaN           NaN
# 9           NaN       NaN           NaN
# 10          NaN       NaN           NaN
# 11          NaN       NaN           NaN
# 12          NaN       NaN           NaN
# 13         4.33       6.0          75.9
#
# [14 rows x 40 columns],            試合日     チーム    背番号    リベロ     名前  出場数    1    2    3    4  ...  \
# 0   2021-03-07  埼玉アザレア      1      L   川崎翔太    3    ●    ●    ●  nan  ...
# 1   2021-03-07  埼玉アザレア      2    NaN   加藤克貴    3    ■    ■    ■  nan  ...
# 2   2021-03-07  埼玉アザレア      3    NaN   石井和希    0  nan  nan  nan  nan  ...
# 3   2021-03-07  埼玉アザレア      4    NaN    中野竜    2  nan    ■    ■  nan  ...
# 4   2021-03-07  埼玉アザレア      5    NaN    佐藤匠    3    ■    ■    ■  nan  ...
# 5   2021-03-07  埼玉アザレア      6    NaN   浜田翔太    3    ■    ■    ■  nan  ...
# 6   2021-03-07  埼玉アザレア      7    NaN   笠原啓太    3    ■    ■    □  nan  ...
# 7   2021-03-07  埼玉アザレア      8    NaN    筒井匠    2    □  nan    ■  nan  ...
# 8   2021-03-07  埼玉アザレア      9    NaN   前田将武    2  nan    □    □  nan  ...
# 9   2021-03-07  埼玉アザレア     10    NaN   川畑貴裕    1    ■  nan  nan  nan  ...
# 10  2021-03-07  埼玉アザレア     13    NaN   小島大輝    0  nan  nan  nan  nan  ...
# 11  2021-03-07  埼玉アザレア     16    NaN    小堀優    1  nan    □  nan  nan  ...
# 12  2021-03-07  埼玉アザレア     17    NaN   茂木祐太    3    ■    ■    ■  nan  ...
# 13  2021-03-07  埼玉アザレア  チーム合計  チーム合計  チーム合計    3  nan  nan  nan  nan  ...
#
#    サーブレシーブ成功・良  サーブレシーブ成功率  相手アタック打数  相手アタック得点  相手アタック失点  相手アタック決定率 相手ブロック得点  \
# 0            6        70.0       NaN       NaN       NaN        NaN      NaN
# 1            5        53.1       NaN       NaN       NaN        NaN      NaN
# 2            0           -       NaN       NaN       NaN        NaN      NaN
# 3            3        50.0       NaN       NaN       NaN        NaN      NaN
# 4            0       100.0       NaN       NaN       NaN        NaN      NaN
# 5            0           -       NaN       NaN       NaN        NaN      NaN
# 6            0           -       NaN       NaN       NaN        NaN      NaN
# 7            0           -       NaN       NaN       NaN        NaN      NaN
# 8            0           -       NaN       NaN       NaN        NaN      NaN
# 9            1        56.2       NaN       NaN       NaN        NaN      NaN
# 10           0           -       NaN       NaN       NaN        NaN      NaN
# 11           0           -       NaN       NaN       NaN        NaN      NaN
# 12           0           -       NaN       NaN       NaN        NaN      NaN
# 13          15        59.2       126        54         9       42.9       11
#
#     相手ブロックセット平均  相手サーブ効果率  相手サーブレシーブ成功率
# 0           NaN       NaN           NaN
# 1           NaN       NaN           NaN
# 2           NaN       NaN           NaN
# 3           NaN       NaN           NaN
# 4           NaN       NaN           NaN
# 5           NaN       NaN           NaN
# 6           NaN       NaN           NaN
# 7           NaN       NaN           NaN
# 8           NaN       NaN           NaN
# 9           NaN       NaN           NaN
# 10          NaN       NaN           NaN
# 11          NaN       NaN           NaN
# 12          NaN       NaN           NaN
# 13         3.67       2.6          59.6
#
# [14 rows x 40 columns],            試合日        チーム    背番号    リベロ     名前  出場数    1    2    3    4  ...  \
# 0   2021-03-07  サフィルヴァ北海道      1    NaN   青島賢司    1  nan  nan    □  nan  ...
# 1   2021-03-07  サフィルヴァ北海道      2      L    神園時    3    ●    ●    ●  nan  ...
# 2   2021-03-07  サフィルヴァ北海道      3    NaN   河西智洋    0  nan  nan  nan  nan  ...
# 3   2021-03-07  サフィルヴァ北海道      4    NaN   奥田基嗣    3    ■    ■    ■  nan  ...
# 4   2021-03-07  サフィルヴァ北海道      6    NaN   阿部誠樹    3    ■    ■    ■  nan  ...
# 5   2021-03-07  サフィルヴァ北海道      7    NaN   笠原佑斗    0  nan  nan  nan  nan  ...
# 6   2021-03-07  サフィルヴァ北海道     10    NaN    三浦拓    0  nan  nan  nan  nan  ...
# 7   2021-03-07  サフィルヴァ北海道     14    NaN   山口拓馬    2    □  nan    □  nan  ...
# 8   2021-03-07  サフィルヴァ北海道     18      L    藤村稜    3    〇    〇    〇  nan  ...
# 9   2021-03-07  サフィルヴァ北海道     20    NaN   佐藤陸善    2    ■    ■  nan  nan  ...
# 10  2021-03-07  サフィルヴァ北海道     21    NaN    柿崎充    3    ■    ■    ■  nan  ...
# 11  2021-03-07  サフィルヴァ北海道     22    NaN    柏田樹    3    ■    ■    ■  nan  ...
# 12  2021-03-07  サフィルヴァ北海道     23    NaN   谷越陽介    3    □    □    ■  nan  ...
# 13  2021-03-07  サフィルヴァ北海道     27    NaN   工藤泰我    3    ■    ■    ■  nan  ...
# 14  2021-03-07  サフィルヴァ北海道  チーム合計  チーム合計  チーム合計    3  nan  nan  nan  nan  ...
#
#    サーブレシーブ成功・良  サーブレシーブ成功率  相手アタック打数  相手アタック得点  相手アタック失点  相手アタック決定率 相手ブロック得点  \
# 0            0           -       NaN       NaN       NaN        NaN      NaN
# 1            1        29.2       NaN       NaN       NaN        NaN      NaN
# 2            0           -       NaN       NaN       NaN        NaN      NaN
# 3            0           -       NaN       NaN       NaN        NaN      NaN
# 4           23        65.1       NaN       NaN       NaN        NaN      NaN
# 5            0           -       NaN       NaN       NaN        NaN      NaN
# 6            0           -       NaN       NaN       NaN        NaN      NaN
# 7            0           -       NaN       NaN       NaN        NaN      NaN
# 8            0           -       NaN       NaN       NaN        NaN      NaN
# 9            0           -       NaN       NaN       NaN        NaN      NaN
# 10           0           -       NaN       NaN       NaN        NaN      NaN
# 11           1        75.0       NaN       NaN       NaN        NaN      NaN
# 12           0           -       NaN       NaN       NaN        NaN      NaN
# 13           4        63.6       NaN       NaN       NaN        NaN      NaN
# 14          29        59.6       115        47         4       40.9        6
#
#     相手ブロックセット平均  相手サーブ効果率  相手サーブレシーブ成功率
# 0           NaN       NaN           NaN
# 1           NaN       NaN           NaN
# 2           NaN       NaN           NaN
# 3           NaN       NaN           NaN
# 4           NaN       NaN           NaN
# 5           NaN       NaN           NaN
# 6           NaN       NaN           NaN
# 7           NaN       NaN           NaN
# 8           NaN       NaN           NaN
# 9           NaN       NaN           NaN
# 10          NaN       NaN           NaN
# 11          NaN       NaN           NaN
# 12          NaN       NaN           NaN
# 13          NaN       NaN           NaN
# 14         2.00       8.7          59.2
#
# [15 rows x 40 columns],            試合日       チーム    背番号    リベロ     名前  出場数    1    2    3    4  ...  \
# 0   2021-03-07  ヴォレアス北海道      0    NaN    越川優    3    ■    ■    ■  nan  ...
# 1   2021-03-07  ヴォレアス北海道      2    NaN  山口功太郎    3    ■    ■    ■  nan  ...
# 2   2021-03-07  ヴォレアス北海道      3    NaN   田城貴之    0  nan  nan  nan  nan  ...
# 3   2021-03-07  ヴォレアス北海道      4    NaN   古田史郎    3    ■    ■    ■  nan  ...
# 4   2021-03-07  ヴォレアス北海道      5    NaN   家近滉一    3    ■    ■    ■  nan  ...
# 5   2021-03-07  ヴォレアス北海道      6    NaN   本澤凌斗    3    □    □    □  nan  ...
# 6   2021-03-07  ヴォレアス北海道      7    NaN   関根俊哉    3    ■    ■    ■  nan  ...
# 7   2021-03-07  ヴォレアス北海道      8      L   渡辺俊介    3    ●    ●    ●  nan  ...
# 8   2021-03-07  ヴォレアス北海道      9    NaN   加藤伊織    1  nan  nan    □  nan  ...
# 9   2021-03-07  ヴォレアス北海道     10    NaN   白石啓丈    2    □    □  nan  nan  ...
# 10  2021-03-07  ヴォレアス北海道     13    NaN  佐々木博秋    1  nan  nan    □  nan  ...
# 11  2021-03-07  ヴォレアス北海道     14    NaN    張育陞    3    □    □    □  nan  ...
# 12  2021-03-07  ヴォレアス北海道     20    NaN   戸田拓也    1  nan  nan    □  nan  ...
# 13  2021-03-07  ヴォレアス北海道     23    NaN   田城広光    3    ■    ■    ■  nan  ...
# 14  2021-03-07  ヴォレアス北海道  チーム合計  チーム合計  チーム合計    3  nan  nan  nan  nan  ...
#
#    サーブレシーブ成功・良  サーブレシーブ成功率  相手アタック打数  相手アタック得点  相手アタック失点  相手アタック決定率 相手ブロック得点  \
# 0            3        55.3       NaN       NaN       NaN        NaN      NaN
# 1            0           -       NaN       NaN       NaN        NaN      NaN
# 2            0           -       NaN       NaN       NaN        NaN      NaN
# 3            0           -       NaN       NaN       NaN        NaN      NaN
# 4            7        52.1       NaN       NaN       NaN        NaN      NaN
# 5            0           -       NaN       NaN       NaN        NaN      NaN
# 6            1        41.7       NaN       NaN       NaN        NaN      NaN
# 7            3        79.4       NaN       NaN       NaN        NaN      NaN
# 8            0           -       NaN       NaN       NaN        NaN      NaN
# 9            1        50.0       NaN       NaN       NaN        NaN      NaN
# 10           0           -       NaN       NaN       NaN        NaN      NaN
# 11           0           -       NaN       NaN       NaN        NaN      NaN
# 12           0           -       NaN       NaN       NaN        NaN      NaN
# 13           0           -       NaN       NaN       NaN        NaN      NaN
# 14          15        59.0        91        47         5       51.6        6
#
#     相手ブロックセット平均  相手サーブ効果率  相手サーブレシーブ成功率
# 0           NaN       NaN           NaN
# 1           NaN       NaN           NaN
# 2           NaN       NaN           NaN
# 3           NaN       NaN           NaN
# 4           NaN       NaN           NaN
# 5           NaN       NaN           NaN
# 6           NaN       NaN           NaN
# 7           NaN       NaN           NaN
# 8           NaN       NaN           NaN
# 9           NaN       NaN           NaN
# 10          NaN       NaN           NaN
# 11          NaN       NaN           NaN
# 12          NaN       NaN           NaN
# 13          NaN       NaN           NaN
# 14         2.00       2.5          51.8
#
# [15 rows x 40 columns],            試合日              チーム    背番号    リベロ            名前  出場数    1    2  \
# 0   2021-03-07  富士通カワサキレッドスピリッツ      1    NaN  エバデダンジェフリー宇意    3    ■    ■
# 1   2021-03-07  富士通カワサキレッドスピリッツ      4    NaN          柳田百織    3    ■    ■
# 2   2021-03-07  富士通カワサキレッドスピリッツ      6      L          小林慎平    3    ●    ●
# 3   2021-03-07  富士通カワサキレッドスピリッツ      7    NaN          加藤大雄    3    ■    ■
# 4   2021-03-07  富士通カワサキレッドスピリッツ      8    NaN          後藤滉貴    1    □  nan
# 5   2021-03-07  富士通カワサキレッドスピリッツ      9    NaN           手塚奨    1  nan    □
# 6   2021-03-07  富士通カワサキレッドスピリッツ     10    NaN          岡村義郎    0  nan  nan
# 7   2021-03-07  富士通カワサキレッドスピリッツ     11    NaN          浅野卓雅    3    ■    ■
# 8   2021-03-07  富士通カワサキレッドスピリッツ     13    NaN          兵頭佳樹    2    ■    ■
# 9   2021-03-07  富士通カワサキレッドスピリッツ     14    NaN          谷平拓海    2  nan    □
# 10  2021-03-07  富士通カワサキレッドスピリッツ     17    NaN           角大樹    0  nan  nan
# 11  2021-03-07  富士通カワサキレッドスピリッツ     18    NaN          長谷山拓    3    ■    ■
# 12  2021-03-07  富士通カワサキレッドスピリッツ     19    NaN           尾木将    3    □    □
# 13  2021-03-07  富士通カワサキレッドスピリッツ     20    NaN          志波京介    1  nan    □
# 14  2021-03-07  富士通カワサキレッドスピリッツ  チーム合計  チーム合計         チーム合計    3  nan  nan
#
#       3    4  ... サーブレシーブ成功・良  サーブレシーブ成功率  相手アタック打数  相手アタック得点  相手アタック失点  \
# 0     ■  nan  ...           0           -       NaN       NaN       NaN
# 1     ■  nan  ...           0           -       NaN       NaN       NaN
# 2     ●  nan  ...           2        58.3       NaN       NaN       NaN
# 3     ■  nan  ...           0        66.7       NaN       NaN       NaN
# 4   nan  nan  ...           0           -       NaN       NaN       NaN
# 5   nan  nan  ...           0           -       NaN       NaN       NaN
# 6   nan  nan  ...           0           -       NaN       NaN       NaN
# 7     ■  nan  ...           5        41.7       NaN       NaN       NaN
# 8   nan  nan  ...           3        61.1       NaN       NaN       NaN
# 9     ■  nan  ...           3        54.2       NaN       NaN       NaN
# 10  nan  nan  ...           0           -       NaN       NaN       NaN
# 11    ■  nan  ...           0           -       NaN       NaN       NaN
# 12    □  nan  ...           1        25.0       NaN       NaN       NaN
# 13  nan  nan  ...           0           -       NaN       NaN       NaN
# 14  nan  nan  ...          14        51.8        99        45         8
#
#     相手アタック決定率 相手ブロック得点  相手ブロックセット平均  相手サーブ効果率  相手サーブレシーブ成功率
# 0         NaN      NaN          NaN       NaN           NaN
# 1         NaN      NaN          NaN       NaN           NaN
# 2         NaN      NaN          NaN       NaN           NaN
# 3         NaN      NaN          NaN       NaN           NaN
# 4         NaN      NaN          NaN       NaN           NaN
# 5         NaN      NaN          NaN       NaN           NaN
# 6         NaN      NaN          NaN       NaN           NaN
# 7         NaN      NaN          NaN       NaN           NaN
# 8         NaN      NaN          NaN       NaN           NaN
# 9         NaN      NaN          NaN       NaN           NaN
# 10        NaN      NaN          NaN       NaN           NaN
# 11        NaN      NaN          NaN       NaN           NaN
# 12        NaN      NaN          NaN       NaN           NaN
# 13        NaN      NaN          NaN       NaN           NaN
# 14       45.5        6         2.00       2.8          59.0
#
# [15 rows x 40 columns]]
# C:\Users\sasno\Desktop\MyPandas\vleague\v2_m

# %%
import tweepy
import os
import glob
import time
import numpy as np
import pandas as pd
import re
 
# key
consumer_key = 'D4OAzhqT7NNeeCa9R7h0Hxzx3'
consumer_secret = 'Py8P1k5jxdPEvNOb64WUXh8b10sfDL5qr60krVLNOOLEXauZti'
access_token = '1309887734555668481-NNvdk0MCxK4WwKZCKZrOqflU9bwPfG'
access_secret = 'CmkMLM4eiOq4MLP3TE6FfUobThOElR5OAfuVSv3GRnXrJ'
 
# Twitterオブジェクト
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_secret)
api = tweepy.API(auth, wait_on_rate_limit = True)

# %%
daily_all = pd.read_csv('all/{}/daily_all.csv'.format(s_round),encoding='cp932')
# daily_all
day = '2021-03-07'
today_data = daily_all[daily_all['試合日']==day]
# today_data.head()
stats_list = ['total', 'at_attack','attack_k', 'b_attack_k', 'block', 'surve_k', 'surve_eff', 'cut']
# stats = np.random.choice(stats_list)
for stats in stats_list:
    print(stats)
    if stats == 'total':
        reg_judge = today_data['出場数']>=1
        column = '総得点'
        pattern = ['出場数1セット', 2]
    elif stats == 'at_attack':
        reg_judge = today_data['出場数']>=1
        column ='アタック打数'
        pattern = ['出場数1セット', 0]
    elif stats == 'attack_k':
        reg_judge = today_data['アタック打数']>=10
        column = 'アタック決定率'
        pattern = ['打数10本', 1]
    elif stats == 'b_attack_k':
        reg_judge = today_data['バックアタック打数']>=5
        column = 'バックアタック決定率'
        pattern = ['打数5本', 1]
    elif stats == 'block':
        reg_judge = today_data['出場数']>=2
        column = 'ブロックセット平均'
        pattern = ['出場数2セット', 0]
    elif stats == 'surve_k':
        reg_judge = today_data['サーブ打数']>=5
        column = 'サーブ得点'
        pattern = ['サーブ打数5本', 2]
    elif stats == 'surve_eff':
        reg_judge = today_data['サーブ打数']>=5
        column = 'サーブ効果率'
        pattern = ['サーブ打数5本', 1]
    else:
        reg_judge = today_data['受数']>=5
        column = 'サーブレシーブ成功率'
        pattern = ['受数5本', 1]
    print(column)

    for i in range(3):
        stats_df = today_data[reg_judge][['名前', 'チーム', '背番号', '出場数', column]]
        stats_df = stats_df.sort_values(column, ascending=False).head()
        print(stats_df)
        if len(stats_df) >= 3:
            break
    # try:
    # stats_df = stats_df.to_dict()
    print(stats_df)
    if division == 'v1_m':
        division_j = 'V1男子'
    elif division == 'v1_w':
        division_j = 'V1女子'
    elif division == 'v2_m':
        division_j = 'V2男子'
    elif division == 'v2_w':
        division_j = 'V2女子'
    elif division == 'v3_m':
        division_j = 'V3男子'
    else:
        division_j = 'V3女子'
    
    p = re.compile('[\u0000-\u007F]+')
    messages = '本日({})の成績\n'.format(day)
    messages += 'シーズン: {}\n'.format(season)
    messages += '【{0}】ランキング({1}以上)\n'.format(column, pattern[0])
    messages += 'ディビジョン: {}\n'.format(division_j)
    print(len(stats_df))
    for i in range(len(stats_df)):
        if pattern[1]==1:
            message = '{0}位 #{1} ({2}, {3}%)\n'.format(i+1, stats_df['名前'].iloc[i], stats_df['チーム'].iloc[i], stats_df[column].iloc[i])
        elif pattern[1]==2:
            message = '{0}位 #{1} ({2}, {3}点)\n'.format(i+1, stats_df['名前'].iloc[i], stats_df['チーム'].iloc[i], stats_df[column].iloc[i])
        else:
            message = '{0}位 #{1} ({2}, {3}本)\n'.format(i+1, stats_df['名前'].iloc[i], stats_df['チーム'].iloc[i], stats_df[column].iloc[i])
        m_len = messages + message
        m_len = messages + message
        e_len = len(''.join(p.findall(m_len)))
        tweet_len = len(m_len) - (e_len/2)
        # print(tweet_len)
        if tweet_len <= 140:
            messages += message
        else:
            break
    print(messages)
    # api.update_status(messages)
    # except:
    #     pass
# Out:
# total
# 総得点
#               名前          チーム  背番号  出場数  総得点
# 586     クレクバルトシュ   ウルフドッグス名古屋    3    3   24
# 684   パダルクリスティアン       東レアローズ    4    3   24
# 634  ムセルスキードミトリー   サントリーサンバーズ   13    3   23
# 567   プレモビッチピーター         FC東京   20    3   22
# 653         清水邦広  パナソニックパンサーズ    1    4   21
#               名前          チーム  背番号  出場数  総得点
# 586     クレクバルトシュ   ウルフドッグス名古屋    3    3   24
# 684   パダルクリスティアン       東レアローズ    4    3   24
# 634  ムセルスキードミトリー   サントリーサンバーズ   13    3   23
# 567   プレモビッチピーター         FC東京   20    3   22
# 653         清水邦広  パナソニックパンサーズ    1    4   21
# 5
# 本日(2020-10-31)の成績
# シーズン: 2020-21_regular
# 【総得点】ランキング(出場数1セット以上)
# ディビジョン: V1男子
# 1位 #クレクバルトシュ (ウルフドッグス名古屋, 24点)
# 2位 #パダルクリスティアン (東レアローズ, 24点)
# 3位 #ムセルスキードミトリー (サントリーサンバーズ, 23点)
#
# at_attack
# アタック打数
#               名前           チーム  背番号  出場数  アタック打数
# 648         袴谷亮介  ジェイテクトSTINGS   11    4      45
# 684   パダルクリスティアン        東レアローズ    4    3      45
# 586     クレクバルトシュ    ウルフドッグス名古屋    3    3      42
# 577  ストックトンカーティス  大分三好ヴァイセアドラー   11    3      38
# 567   プレモビッチピーター          FC東京   20    3      35
#               名前           チーム  背番号  出場数  アタック打数
# 648         袴谷亮介  ジェイテクトSTINGS   11    4      45
# 684   パダルクリスティアン        東レアローズ    4    3      45
# 586     クレクバルトシュ    ウルフドッグス名古屋    3    3      42
# 577  ストックトンカーティス  大分三好ヴァイセアドラー   11    3      38
# 567   プレモビッチピーター          FC東京   20    3      35
# 5
# 本日(2020-10-31)の成績
# シーズン: 2020-21_regular
# 【アタック打数】ランキング(出場数1セット以上)
# ディビジョン: V1男子
# 1位 #袴谷亮介 (ジェイテクトSTINGS, 45本)
# 2位 #パダルクリスティアン (東レアローズ, 45本)
# 3位 #クレクバルトシュ (ウルフドッグス名古屋, 42本)
#
# attack_k
# アタック決定率
#               名前          チーム  背番号  出場数  アタック決定率
# 660         山内晶大  パナソニックパンサーズ   10    4     80.0
# 667         安永拓弥    JTサンダーズ広島    1    3     70.0
# 634  ムセルスキードミトリー   サントリーサンバーズ   13    3     68.8
# 629         柳田将洋   サントリーサンバーズ    8    3     68.8
# 603         出耒田敬      堺ブレイザーズ    7    3     66.7
#               名前          チーム  背番号  出場数  アタック決定率
# 660         山内晶大  パナソニックパンサーズ   10    4     80.0
# 667         安永拓弥    JTサンダーズ広島    1    3     70.0
# 634  ムセルスキードミトリー   サントリーサンバーズ   13    3     68.8
# 629         柳田将洋   サントリーサンバーズ    8    3     68.8
# 603         出耒田敬      堺ブレイザーズ    7    3     66.7
# 5
# 本日(2020-10-31)の成績
# シーズン: 2020-21_regular
# 【アタック決定率】ランキング(打数10本以上)
# ディビジョン: V1男子
# 1位 #山内晶大 (パナソニックパンサーズ, 80.0%)
# 2位 #安永拓弥 (JTサンダーズ広島, 70.0%)
# 3位 #ムセルスキードミトリー (サントリーサンバーズ, 68.8%)
#
# b_attack_k
# バックアタック決定率
#               名前         チーム  背番号  出場数 バックアタック決定率
# 595         高梨健太  ウルフドッグス名古屋   22    3       80.0
# 634  ムセルスキードミトリー  サントリーサンバーズ   13    3       77.8
# 567   プレモビッチピーター        FC東京   20    3       69.2
# 586     クレクバルトシュ  ウルフドッグス名古屋    3    3       58.3
# 671     エドガートーマス   JTサンダーズ広島    6    3       58.3
#               名前         チーム  背番号  出場数 バックアタック決定率
# 595         高梨健太  ウルフドッグス名古屋   22    3       80.0
# 634  ムセルスキードミトリー  サントリーサンバーズ   13    3       77.8
# 567   プレモビッチピーター        FC東京   20    3       69.2
# 586     クレクバルトシュ  ウルフドッグス名古屋    3    3       58.3
# 671     エドガートーマス   JTサンダーズ広島    6    3       58.3
# 5
# 本日(2020-10-31)の成績
# シーズン: 2020-21_regular
# 【バックアタック決定率】ランキング(打数5本以上)
# ディビジョン: V1男子
# 1位 #高梨健太 (ウルフドッグス名古屋, 80.0%)
# 2位 #ムセルスキードミトリー (サントリーサンバーズ, 77.8%)
# 3位 #プレモビッチピーター (FC東京, 69.2%)
#
# block
# ブロックセット平均
#           名前           チーム  背番号  出場数 ブロックセット平均
# 643     福山汰一  ジェイテクトSTINGS    4    4      1.25
# 668    小野寺太志     JTサンダーズ広島    2    3      1.00
# 661  クビアクミハウ   パナソニックパンサーズ   13    4      1.00
# 606     関田誠大       堺ブレイザーズ   11    3      1.00
# 565     武藤鉄也          FC東京   18    3      1.00
#           名前           チーム  背番号  出場数 ブロックセット平均
# 643     福山汰一  ジェイテクトSTINGS    4    4      1.25
# 668    小野寺太志     JTサンダーズ広島    2    3      1.00
# 661  クビアクミハウ   パナソニックパンサーズ   13    4      1.00
# 606     関田誠大       堺ブレイザーズ   11    3      1.00
# 565     武藤鉄也          FC東京   18    3      1.00
# 5
# 本日(2020-10-31)の成績
# シーズン: 2020-21_regular
# 【ブロックセット平均】ランキング(出場数2セット以上)
# ディビジョン: V1男子
# 1位 #福山汰一 (ジェイテクトSTINGS, 1.25本)
# 2位 #小野寺太志 (JTサンダーズ広島, 1.00本)
# 3位 #クビアクミハウ (パナソニックパンサーズ, 1.00本)
#
# surve_k
# サーブ得点
#              名前           チーム  背番号  出場数  サーブ得点
# 599        樋口裕希       堺ブレイザーズ    2    3      3
# 627        小野遥輝    サントリーサンバーズ    3    3      2
# 567  プレモビッチピーター          FC東京   20    3      2
# 648        袴谷亮介  ジェイテクトSTINGS   11    4      2
# 622        森崎健史    VC長野トライデンツ   16    3      1
#              名前           チーム  背番号  出場数  サーブ得点
# 599        樋口裕希       堺ブレイザーズ    2    3      3
# 627        小野遥輝    サントリーサンバーズ    3    3      2
# 567  プレモビッチピーター          FC東京   20    3      2
# 648        袴谷亮介  ジェイテクトSTINGS   11    4      2
# 622        森崎健史    VC長野トライデンツ   16    3      1
# 5
# 本日(2020-10-31)の成績
# シーズン: 2020-21_regular
# 【サーブ得点】ランキング(サーブ打数5本以上)
# ディビジョン: V1男子
# 1位 #樋口裕希 (堺ブレイザーズ, 3点)
# 2位 #小野遥輝 (サントリーサンバーズ, 2点)
# 3位 #プレモビッチピーター (FC東京, 2点)
# 4位 #袴谷亮介 (ジェイテクトSTINGS, 2点)
#
# surve_eff
# サーブ効果率
#        名前           チーム  背番号  出場数 サーブ効果率
# 585   山近哲    ウルフドッグス名古屋    2    3    9.4
# 581  井口直紀  大分三好ヴァイセアドラー   21    3    8.3
# 584  山田脩造    ウルフドッグス名古屋    1    3    8.3
# 648  袴谷亮介  ジェイテクトSTINGS   11    4    7.7
# 635  加藤久典    サントリーサンバーズ   14    2    7.1
#        名前           チーム  背番号  出場数 サーブ効果率
# 585   山近哲    ウルフドッグス名古屋    2    3    9.4
# 581  井口直紀  大分三好ヴァイセアドラー   21    3    8.3
# 584  山田脩造    ウルフドッグス名古屋    1    3    8.3
# 648  袴谷亮介  ジェイテクトSTINGS   11    4    7.7
# 635  加藤久典    サントリーサンバーズ   14    2    7.1
# 5
# 本日(2020-10-31)の成績
# シーズン: 2020-21_regular
# 【サーブ効果率】ランキング(サーブ打数5本以上)
# ディビジョン: V1男子
# 1位 #山近哲 (ウルフドッグス名古屋, 9.4%)
# 2位 #井口直紀 (大分三好ヴァイセアドラー, 8.3%)
# 3位 #山田脩造 (ウルフドッグス名古屋, 8.3%)
#
# cut
# サーブレシーブ成功率
#         名前          チーム  背番号  出場数 サーブレシーブ成功率
# 596   小川智大   ウルフドッグス名古屋   24    3       86.4
# 662   伊賀亮平  パナソニックパンサーズ   16    4       81.2
# 562  古賀太一郎         FC東京   10    3       75.0
# 673   武智洸史    JTサンダーズ広島    8    3       72.2
# 615   戸嵜嵩大   VC長野トライデンツ    7    3       67.4
#         名前          チーム  背番号  出場数 サーブレシーブ成功率
# 596   小川智大   ウルフドッグス名古屋   24    3       86.4
# 662   伊賀亮平  パナソニックパンサーズ   16    4       81.2
# 562  古賀太一郎         FC東京   10    3       75.0
# 673   武智洸史    JTサンダーズ広島    8    3       72.2
# 615   戸嵜嵩大   VC長野トライデンツ    7    3       67.4
# 5
# 本日(2020-10-31)の成績
# シーズン: 2020-21_regular
# 【サーブレシーブ成功率】ランキング(受数5本以上)
# ディビジョン: V1男子
# 1位 #小川智大 (ウルフドッグス名古屋, 86.4%)
# 2位 #伊賀亮平 (パナソニックパンサーズ, 81.2%)
# 3位 #古賀太一郎 (FC東京, 75.0%)
# 4位 #武智洸史 (JTサンダーズ広島, 72.2%)

# %%
daily_all = pd.read_csv('all/2020-21_regular/daily_all.csv',encoding='cp932')
daily_all.sort_values('総得点', ascending=False).head()
# Out:
#             試合日   月              チーム        相手チーム  背番号  リベロ          名前  出場数  \
# 150  2020-10-18  10          日立リヴァーレ  トヨタ車体クインシーズ   17  NaN  オクム大庭冬美ハウィ    5
# 189  2020-10-18  10         JTマーヴェラス     久光スプリングス   10  NaN   ドルーズアンドレア    4
# 267  2020-10-18  10  KUROBEアクアフェアリーズ   埼玉上尾メディックス    9  NaN        舛田紗淑    4
# 246  2020-10-18  10       NECレッドロケッツ      岡山シーガルズ   12  NaN        山内美咲    4
# 312  2020-10-24  10       埼玉上尾メディックス    ヴィクトリーナ姫路    9  NaN       内瀬戸真実    5
#
#      1  2  ... サーブ打数 サーブ得点 サーブ失点  サーブ効果  サーブ効果率  受数  サーブレシーブ成功・優  サーブレシーブ成功・良  \
# 150  ■  ■  ...    10     0     0      3     7.5   0            0            0
# 189  ■  ■  ...     8     1     1      4    21.9   0            0            0
# 267  ■  ■  ...    21     3     1      7    21.4  31           11           12
# 246  □  ■  ...    16     3     0      2    21.9  27           16            5
# 312  ■  ■  ...    17     0     0      5     7.4  31           10            7
#
#     サーブレシーブ成功率  総得点
# 150          -   40
# 189          -   27
# 267       54.8   25
# 246       68.5   25
# 312       43.5   23
#
# [5 rows x 35 columns]

# %%
yearly_all = pd.read_csv('all/{}/yearly_all.csv'.format(s_round),encoding='cp932')
n = 5
stats_list = ['total', 'at_attack','attack_k', 'b_attack_k', 'block', 'surve_k', 'surve_eff', 'cut']
# stats = np.random.choice(stats_list)
for stats in stats_list:
    print(stats)
    if stats == 'total':
        reg_judge = yearly_all['出場数']>=n
        column = '総得点'
        pattern = ['出場数{}セット'.format(n), 2]
    elif stats == 'at_attack':
        reg_judge = yearly_all['出場数']>=n
        column ='アタック打数'
        pattern = ['出場数{}セット'.format(n), 0]
    elif stats == 'attack_k':
        reg_judge = yearly_all['アタック打数']>=n*10
        column = 'アタック決定率'
        pattern = ['打数{}本'.format(n*10), 1]
    elif stats == 'b_attack_k':
        reg_judge = yearly_all['バックアタック打数']>=n*4
        column = 'バックアタック決定率'
        pattern = ['打数{}本'.format(n*4), 1]
    elif stats == 'block':
        reg_judge = yearly_all['出場数']>=n
        column = 'ブロックセット平均'
        pattern = ['出場数{}セット'.format(n), 0]
    elif stats == 'surve_k':
        reg_judge = yearly_all['サーブ打数']>=n*5
        column = 'サーブ得点'
        pattern = ['サーブ打数{}本'.format(n*5), 2]
    elif stats == 'surve_eff':
        reg_judge = yearly_all['サーブ打数']>=n*5
        column = 'サーブ効果率'
        pattern = ['サーブ打数{}本'.format(n*5), 1]
    else:
        reg_judge = yearly_all['受数']>=n*10
        column = 'サーブレシーブ成功率'
        pattern = ['受数{}本'.format(n*10), 1]
    print(column)

    for i in range(3):
        stats_df = yearly_all[reg_judge][['名前', 'チーム', '背番号', '出場数', column]]
        stats_df = stats_df.sort_values(column, ascending=False).head()
        print(stats_df)
        if len(stats_df) >= 3:
            break
    # try:
    # stats_df = stats_df.to_dict()
    print(stats_df)
    p = re.compile('[\u0000-\u007F]+')
    messages = '今シーズン({})通算成績\n'.format(season)
    messages += '【{0}】ランキング({1}以上)\n'.format(column, pattern[0])
    messages += 'ディビジョン: {}\n'.format(division)
    print(len(stats_df))
    for i in range(len(stats_df)):
        if pattern[1]==1:
            message = '{0}位 #{1} ({2}, {3}%)\n'.format(i+1, stats_df['名前'].iloc[i], stats_df['チーム'].iloc[i], stats_df[column].iloc[i])
        elif pattern[1]==2:
            message = '{0}位 #{1} ({2}, {3}点)\n'.format(i+1, stats_df['名前'].iloc[i], stats_df['チーム'].iloc[i], stats_df[column].iloc[i])
        else:
            message = '{0}位 #{1} ({2}, {3}本)\n'.format(i+1, stats_df['名前'].iloc[i], stats_df['チーム'].iloc[i], stats_df[column].iloc[i])
        m_len = messages + message
        m_len = messages + message
        e_len = len(''.join(p.findall(m_len)))
        tweet_len = len(m_len) - (e_len/2)
        # print(tweet_len)
        if tweet_len <= 140:
            messages += message
        else:
            break
    print(messages)
    api.update_status(messages)
    # except:
    #     pass
# Out:
# total
# 総得点
#            名前           チーム  背番号  出場数  総得点
# 131      西田有志  ジェイテクトSTINGS   14   17  136
# 2    クレクバルトシュ    ウルフドッグス名古屋    3   18  129
# 107      清水邦広   パナソニックパンサーズ    1   19   92
# 87       柳田将洋    サントリーサンバーズ    8   20   92
# 3     ジョンウェント       堺ブレイザーズ   24   19   82
#            名前           チーム  背番号  出場数  総得点
# 131      西田有志  ジェイテクトSTINGS   14   17  136
# 2    クレクバルトシュ    ウルフドッグス名古屋    3   18  129
# 107      清水邦広   パナソニックパンサーズ    1   19   92
# 87       柳田将洋    サントリーサンバーズ    8   20   92
# 3     ジョンウェント       堺ブレイザーズ   24   19   82
# 5
# 今シーズン(2020-21_regular)通算成績
# 【総得点】ランキング(出場数5セット以上)
# ディビジョン: v1_m
# 1位 #西田有志 (ジェイテクトSTINGS, 136点)
# 2位 #クレクバルトシュ (ウルフドッグス名古屋, 129点)
# 3位 #清水邦広 (パナソニックパンサーズ, 92点)
# 4位 #柳田将洋 (サントリーサンバーズ, 92点)
#
# at_attack
# アタック打数
#            名前           チーム  背番号  出場数  アタック打数
# 2    クレクバルトシュ    ウルフドッグス名古屋    3   18     220
# 131      西田有志  ジェイテクトSTINGS   14   17     202
# 3     ジョンウェント       堺ブレイザーズ   24   19     163
# 87       柳田将洋    サントリーサンバーズ    8   20     155
# 101      池田幸太    VC長野トライデンツ    9   18     152
#            名前           チーム  背番号  出場数  アタック打数
# 2    クレクバルトシュ    ウルフドッグス名古屋    3   18     220
# 131      西田有志  ジェイテクトSTINGS   14   17     202
# 3     ジョンウェント       堺ブレイザーズ   24   19     163
# 87       柳田将洋    サントリーサンバーズ    8   20     155
# 101      池田幸太    VC長野トライデンツ    9   18     152
# 5
# 今シーズン(2020-21_regular)通算成績
# 【アタック打数】ランキング(出場数5セット以上)
# ディビジョン: v1_m
# 1位 #クレクバルトシュ (ウルフドッグス名古屋, 220本)
# 2位 #西田有志 (ジェイテクトSTINGS, 202本)
# 3位 #ジョンウェント (堺ブレイザーズ, 163本)
#
# attack_k
# アタック決定率
#         名前           チーム  背番号  出場数  アタック決定率
# 89    栗山英之          FC東京    8   17     62.5
# 83    松本慶彦       堺ブレイザーズ    1   16     61.8
# 33    出耒田敬       堺ブレイザーズ    7   19     58.3
# 57   小野寺太志     JTサンダーズ広島    2   15     57.5
# 131   西田有志  ジェイテクトSTINGS   14   17     57.4
#         名前           チーム  背番号  出場数  アタック決定率
# 89    栗山英之          FC東京    8   17     62.5
# 83    松本慶彦       堺ブレイザーズ    1   16     61.8
# 33    出耒田敬       堺ブレイザーズ    7   19     58.3
# 57   小野寺太志     JTサンダーズ広島    2   15     57.5
# 131   西田有志  ジェイテクトSTINGS   14   17     57.4
# 5
# 今シーズン(2020-21_regular)通算成績
# 【アタック決定率】ランキング(打数50本以上)
# ディビジョン: v1_m
# 1位 #栗山英之 (FC東京, 62.5%)
# 2位 #松本慶彦 (堺ブレイザーズ, 61.8%)
# 3位 #出耒田敬 (堺ブレイザーズ, 58.3%)
# 4位 #小野寺太志 (JTサンダーズ広島, 57.5%)
#
# b_attack_k
# バックアタック決定率
#              名前           チーム  背番号  出場数  バックアタック決定率
# 87         柳田将洋    サントリーサンバーズ    8   20        66.7
# 9    プレモビッチピーター          FC東京   20    9        63.9
# 131        西田有志  ジェイテクトSTINGS   14   17        62.6
# 142        長友優磨          FC東京   14   14        57.8
# 90         栗山雅史    サントリーサンバーズ   19   19        55.0
#              名前           チーム  背番号  出場数  バックアタック決定率
# 87         柳田将洋    サントリーサンバーズ    8   20        66.7
# 9    プレモビッチピーター          FC東京   20    9        63.9
# 131        西田有志  ジェイテクトSTINGS   14   17        62.6
# 142        長友優磨          FC東京   14   14        57.8
# 90         栗山雅史    サントリーサンバーズ   19   19        55.0
# 5
# 今シーズン(2020-21_regular)通算成績
# 【バックアタック決定率】ランキング(打数20本以上)
# ディビジョン: v1_m
# 1位 #柳田将洋 (サントリーサンバーズ, 66.7%)
# 2位 #プレモビッチピーター (FC東京, 63.9%)
# 3位 #西田有志 (ジェイテクトSTINGS, 62.6%)
# 4位 #長友優磨 (FC東京, 57.8%)
#
# block
# ブロックセット平均
#         名前           チーム  背番号  出場数  ブロックセット平均
# 57   小野寺太志     JTサンダーズ広島    2   15       1.27
# 33    出耒田敬       堺ブレイザーズ    7   19       0.79
# 50    富松崇彰        東レアローズ    1   12       0.75
# 117   福山汰一  ジェイテクトSTINGS    4   21       0.71
# 131   西田有志  ジェイテクトSTINGS   14   17       0.71
#         名前           チーム  背番号  出場数  ブロックセット平均
# 57   小野寺太志     JTサンダーズ広島    2   15       1.27
# 33    出耒田敬       堺ブレイザーズ    7   19       0.79
# 50    富松崇彰        東レアローズ    1   12       0.75
# 117   福山汰一  ジェイテクトSTINGS    4   21       0.71
# 131   西田有志  ジェイテクトSTINGS   14   17       0.71
# 5
# 今シーズン(2020-21_regular)通算成績
# 【ブロックセット平均】ランキング(出場数5セット以上)
# ディビジョン: v1_m
# 1位 #小野寺太志 (JTサンダーズ広島, 1.27本)
# 2位 #出耒田敬 (堺ブレイザーズ, 0.79本)
# 3位 #富松崇彰 (東レアローズ, 0.75本)
# 4位 #福山汰一 (ジェイテクトSTINGS, 0.71本)
#
# surve_k
# サーブ得点
#            名前           チーム  背番号  出場数  サーブ得点
# 2    クレクバルトシュ    ウルフドッグス名古屋    3   18     11
# 58       小野遥輝    サントリーサンバーズ    3   20      8
# 87       柳田将洋    サントリーサンバーズ    8   20      8
# 131      西田有志  ジェイテクトSTINGS   14   17      8
# 1     クビアクミハウ   パナソニックパンサーズ   13   19      8
#            名前           チーム  背番号  出場数  サーブ得点
# 2    クレクバルトシュ    ウルフドッグス名古屋    3   18     11
# 58       小野遥輝    サントリーサンバーズ    3   20      8
# 87       柳田将洋    サントリーサンバーズ    8   20      8
# 131      西田有志  ジェイテクトSTINGS   14   17      8
# 1     クビアクミハウ   パナソニックパンサーズ   13   19      8
# 5
# 今シーズン(2020-21_regular)通算成績
# 【サーブ得点】ランキング(サーブ打数25本以上)
# ディビジョン: v1_m
# 1位 #クレクバルトシュ (ウルフドッグス名古屋, 11点)
# 2位 #小野遥輝 (サントリーサンバーズ, 8点)
# 3位 #柳田将洋 (サントリーサンバーズ, 8点)
# 4位 #西田有志 (ジェイテクトSTINGS, 8点)
#
# surve_eff
# サーブ効果率
#             名前          チーム  背番号  出場数  サーブ効果率
# 2     クレクバルトシュ   ウルフドッグス名古屋    3   18    16.2
# 9   プレモビッチピーター         FC東京   20    9    15.7
# 95        樋口裕希      堺ブレイザーズ    2   12    15.2
# 1      クビアクミハウ  パナソニックパンサーズ   13   19    14.3
# 57       小野寺太志    JTサンダーズ広島    2   15    14.1
#             名前          チーム  背番号  出場数  サーブ効果率
# 2     クレクバルトシュ   ウルフドッグス名古屋    3   18    16.2
# 9   プレモビッチピーター         FC東京   20    9    15.7
# 95        樋口裕希      堺ブレイザーズ    2   12    15.2
# 1      クビアクミハウ  パナソニックパンサーズ   13   19    14.3
# 57       小野寺太志    JTサンダーズ広島    2   15    14.1
# 5
# 今シーズン(2020-21_regular)通算成績
# 【サーブ効果率】ランキング(サーブ打数25本以上)
# ディビジョン: v1_m
# 1位 #クレクバルトシュ (ウルフドッグス名古屋, 16.2%)
# 2位 #プレモビッチピーター (FC東京, 15.7%)
# 3位 #樋口裕希 (堺ブレイザーズ, 15.2%)
#
# cut
# サーブレシーブ成功率
#         名前           チーム  背番号  出場数  サーブレシーブ成功率
# 53    小川智大    ウルフドッグス名古屋   24   18        78.0
# 39   古賀太一郎          FC東京   10   17        69.2
# 25    伊賀亮平   パナソニックパンサーズ   16   18        66.7
# 125   藤中優斗  ジェイテクトSTINGS    1   21        65.9
# 51    富田将馬        東レアローズ    9   19        64.0
#         名前           チーム  背番号  出場数  サーブレシーブ成功率
# 53    小川智大    ウルフドッグス名古屋   24   18        78.0
# 39   古賀太一郎          FC東京   10   17        69.2
# 25    伊賀亮平   パナソニックパンサーズ   16   18        66.7
# 125   藤中優斗  ジェイテクトSTINGS    1   21        65.9
# 51    富田将馬        東レアローズ    9   19        64.0
# 5
# 今シーズン(2020-21_regular)通算成績
# 【サーブレシーブ成功率】ランキング(受数50本以上)
# ディビジョン: v1_m
# 1位 #小川智大 (ウルフドッグス名古屋, 78.0%)
# 2位 #古賀太一郎 (FC東京, 69.2%)
# 3位 #伊賀亮平 (パナソニックパンサーズ, 66.7%)
# 4位 #藤中優斗 (ジェイテクトSTINGS, 65.9%)
