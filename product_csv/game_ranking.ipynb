# %%
import time
import numpy as np
import pandas as pd
 
from bs4 import BeautifulSoup
import urllib.request as req

import requests
import os
import datetime
import re

# %%
import sys
sys.path.append("../")

# %%
from product_csv.create_df import game_df

# %%
# ディビジョンを選択してください:{v1_m, v2_m, v3_m, v1_w, v2_w}
division = 'v1_m'
# '年度を選択してください:{2019-20, 2018-19, 2017-18...}'
season = '2020-21'
# シーズンを選択してください:{regular, 2019-20(game1, game2, semi_final, final), 2014-15~2018-19(final6, final3, final),
# ~2013-14(semi_final, final)}
s_round = 'regular'
season += '_' + s_round
season
# Out:
# '2020-21_regular'

# %%
def create_csv():
    daily_all = game_all[game_all['名前'] != 'チーム合計']
#     daily_all = daily_all.drop(columns=['相手アタック打数', '相手アタック得点', '相手アタック失点', '相手アタック決定率',
#                                         '相手ブロック得点', '相手ブロックセット平均' ,"相手サーブ効果率", "相手サーブレシーブ成功率"])
    year_month = daily_all['試合日'].str[0:7]
    # data = daily_all
    print(daily_all)
    daily_all.insert(1, '年月', year_month)
    daily_all.set_index('試合日')
    monthly_all = daily_all.groupby(['名前','年月','チーム','背番号']).sum().reset_index()
    monthly_all['アタック決定率'] = ((monthly_all['アタック得点'] / monthly_all['アタック打数']) * 100).round(1)
    monthly_all['アタック効果率'] = (((monthly_all['アタック得点']-monthly_all['アタック失点']) / monthly_all['アタック打数']) * 100).round(1)
    monthly_all['バックアタック決定率'] = ((monthly_all['バックアタック得点'] / monthly_all['バックアタック打数']) * 100).round(1)
    monthly_all['アタックセット平均'] = (monthly_all['アタック得点'] / monthly_all['出場数']).round(2)
    monthly_all['ブロックセット平均'] = (monthly_all['ブロック得点'] / monthly_all['出場数']).round(2)
    monthly_all['サーブ効果率'] = ((monthly_all['サーブ得点'] * 100 + monthly_all['サーブ効果'] * 25 - monthly_all['サーブ失点'] * 25) / monthly_all['サーブ打数']).round(1)
    monthly_all['サーブレシーブ成功率'] = ((monthly_all['サーブレシーブ成功・優'] * 100 + monthly_all['サーブレシーブ成功・良'] * 50) / monthly_all['受数']).round(1)
    print(monthly_all)

    yearly_all = daily_all.groupby(['名前','チーム','背番号']).sum().reset_index()
    yearly_all['アタック決定率'] = ((yearly_all['アタック得点'] / yearly_all['アタック打数']) * 100).round(1)
    yearly_all['アタック効果率'] = (((yearly_all['アタック得点']-yearly_all['アタック失点']) / yearly_all['アタック打数']) * 100).round(1)
    yearly_all['バックアタック決定率'] = ((yearly_all['バックアタック得点'] / yearly_all['バックアタック打数']) * 100).round(1)
    yearly_all['アタックセット平均'] = (yearly_all['アタック得点'] / yearly_all['出場数']).round(2)
    yearly_all['ブロックセット平均'] = (yearly_all['ブロック得点'] / yearly_all['出場数']).round(2)
    yearly_all['サーブ効果率'] = ((yearly_all['サーブ得点'] * 100 + yearly_all['サーブ効果'] * 25 - yearly_all['サーブ失点'] * 25) / yearly_all['サーブ打数']).round(1)
    yearly_all['サーブレシーブ成功率'] = ((yearly_all['サーブレシーブ成功・優'] * 100 + yearly_all['サーブレシーブ成功・良'] * 50) / yearly_all['受数']).round(1)
    print(yearly_all)

    game_all.to_csv('all/{}/game_all.csv'.format(s_round), index=False, encoding='cp932')
    daily_all.to_csv('all/{}/daily_all.csv'.format(s_round), index=False, encoding='cp932')
    monthly_all.to_csv('all/{}/monthly_all.csv'.format(s_round), index=False, encoding='cp932')
    yearly_all.to_csv('all/{}/yearly_all.csv'.format(s_round), index=False, encoding='cp932')
    print('csv作成成功')

# %%
# 2020-21の更新
os.chdir('/Users/sasno/Desktop/MyPandas/vleague') 
headers = {"User-Agent": "Mozilla/5.0"}
 
# seasons = get_seasons(division)

division = "v1_m"
# s_id = "283" # 2019-20
# s_id = "301"
# division = "v1_w"
# s_id = "303"
# division = "v2_m"
# s_id = "299"
# division = "v2_w"
# s_id = "302"
# division = "v3_m"
# s_id = "300"
# division = "v3_w"
# s_id = "268" 
s_round = "2020-21_regular"
# s_round = "2021_Vcup" 

if not os.path.isdir(division):
            os.makedirs(division)
        
os.chdir(division)
print(os.getcwd())
 
sets = ['1','2','3','4','5']
game_all = None
 
# ページ数を取得
url = 'https://www.vleague.jp/round/list/{}'.format(s_id)
print(url)
request = req.Request(url, headers=headers)
response = req.urlopen(request)
parse_html = BeautifulSoup(response, 'html.parser')
hrefs = parse_html.find_all('a', href=re.compile("pg"))
 
# for i in hrefs:
#     print(i.text)
print(len(hrefs))
if len(hrefs) > 0:
    pages = int(hrefs[-2].text)
    print(pages)
 
    all_list = []
    url_list = []
    for pg in range(1,pages+1):
        url = 'https://www.vleague.jp/round/list/{0}?pg={1}'.format(s_id,pg)
        print(url)
        request = req.Request(url, headers=headers)
        response = req.urlopen(request)
        parse_html = BeautifulSoup(response, 'html.parser')
        tables = parse_html.find_all('table')
 
        
        trs = tables[0].find_all('a', href=re.compile("/form/b"))
        for tr in trs:
            game_url = 'https://www.vleague.jp/'+ tr.attrs['href']
            url_list.append(game_url)
    print(url_list)

    for url in url_list:
        # print(url)
        html = requests.get(url, headers=headers)
        check = html.text
        if '試合データがありません' not in check and '試合データの集計中です。しばらくお待ちください。' not in check:
            # try:
                data = pd.read_html(check, header=[2])

                for j in range(2):
                    stats = pd.DataFrame(data[j+4])
                    o_stats = pd.DataFrame(data[-(j+1)])
                    stats = stats.rename(columns=str)
                    o_stats = o_stats.rename(columns=str)
                    col = stats.columns.values
                    data_item = []
                    for i in col:
                        l = i
                        data_item.append(l)
                    for i in range(1,len(data_item)-2):
                        data_item[-i] = data_item[-i-3]
                #     print(data_item)
                    for i in range(3):
                    #     print(data_item[i])
                        if data_item[i] == '出場数':
                            data_item[i] = '背番号'
                        elif data_item[i] == '1':
                            data_item[i] = 'リベロ'
                        else:
                            data_item[i] = '名前'
                        # print(i, data_item[i])

                    new_stats = stats.rename(columns={col[i]:data_item[i] for i in range(len(data_item))})
                    stats_columns = {
                        '打数':'アタック打数', '得点':'アタック得点', '失点':'アタック失点', '決定率':'アタック決定率',
                        'セ平ット均':'アタックセット平均','打数.1':'バックアタック打数', '得点.1':'バックアタック得点',
                        '失点.1':'バックアタック失点', '決定率.1':'バックアタック決定率', '得点.2':'ブロック得点',
                        'セ平ット均.1':'ブロックセット平均', '打数.2':'サーブ打数', '得点.3':'サーブ得点', '失点.2':'サーブ失点',
                        '効果':'サーブ効果', '効果率':'サーブ効果率', '成功・優':'サーブレシーブ成功・優', 
                        '成功・良':'サーブレシーブ成功・良', '成功率':'サーブレシーブ成功率'
                        }
                    new_o_stats = o_stats.rename(columns={col[i]:data_item[i] for i in range(len(data_item))})
                    new_stats = new_stats.rename(columns=stats_columns)
                    new_o_stats = new_o_stats.rename(columns=stats_columns)
                    new_o_stats = new_o_stats.rename(columns={'アタック打数':'相手アタック打数', 'アタック得点':'相手アタック得点', 'アタック失点':'相手アタック失点', 
                                                        'アタック決定率':'相手アタック決定率', 'ブロック得点':'相手ブロック得点', 'ブロックセット平均':'相手ブロックセット平均',
                                                        'サーブ効果率':'相手サーブ効果率', 'サーブレシーブ成功率':'相手サーブレシーブ成功率'})
                    new_o_stats_p = new_o_stats.iloc[-1][['背番号','相手アタック打数', '相手アタック得点', '相手アタック失点', '相手アタック決定率', '相手ブロック得点', '相手ブロックセット平均', 
                                                    '相手サーブ効果率','相手サーブレシーブ成功率']]
                    new_o_stats_p = pd.DataFrame(new_o_stats_p).T
                #     new_o_stats_p

                    request = req.Request(url, headers=headers)
                    response = req.urlopen(request)
                    parse_html = BeautifulSoup(response, 'html.parser')
                    table_ha = parse_html.find_all('table')[0]
                    td_ha = table_ha.find_all('td', class_='team')
                    # print(td_ha)
                    team = td_ha[j].text
                    # print('team={}'.format(team))
                    new_stats['アタック決定率'] = round((new_stats['アタック得点'] * 100) / new_stats['アタック打数'], 1)
                    new_stats.insert(13, 'アタック効果率',
                        round((new_stats['アタック得点'] - new_stats['アタック失点']) * 100 / new_stats['アタック打数'],1))
                    span = parse_html.find_all('span')
                    date = span[1].text.replace('/','-')
                    new_stats.insert(0, '試合日', date)
                    new_stats.insert(1, 'チーム', team)
                    new_stats['名前'] = new_stats['名前'].str.replace('\u3000','')
                    for by_set in sets:
                        new_stats[by_set] = new_stats[by_set].astype(str)
                    team_dir = '{0}/{1}'.format(team, s_round)

                    stats_m = pd.merge(new_stats, new_o_stats_p, on='背番号', how='outer')
                #     stats_m
                    if not os.path.isdir(team_dir):
                        os.makedirs(team_dir)
                    stats_m.to_csv('{0}/{1}/{2}.csv'.format(team,s_round,date), index=False, encoding='cp932')
                    all_list.append(stats_m)
            # except:
            #     pass
#     print(all_list)
    game_all = pd.concat(all_list, ignore_index=True)

all_dir = 'all/{}'.format(s_round)
if not os.path.isdir(all_dir):
    os.makedirs(all_dir)

print(os.getcwd())
# try:
create_csv()
# except:
#     pass
# Out:
# C:\Users\sasno\Desktop\MyPandas\vleague\v1_m
# https://www.vleague.jp/round/list/301
# 11
# 9
# https://www.vleague.jp/round/list/301?pg=1
# https://www.vleague.jp/round/list/301?pg=2
# https://www.vleague.jp/round/list/301?pg=3
# https://www.vleague.jp/round/list/301?pg=4
# https://www.vleague.jp/round/list/301?pg=5
# https://www.vleague.jp/round/list/301?pg=6
# https://www.vleague.jp/round/list/301?pg=7
# https://www.vleague.jp/round/list/301?pg=8
# https://www.vleague.jp/round/list/301?pg=9
# ['https://www.vleague.jp//form/b/25722', 'https://www.vleague.jp//form/b/25724', 'https://www.vleague.jp//form/b/25716', 'https://www.vleague.jp//form/b/25718', 'https://www.vleague.jp//form/b/25720', 'https://www.vleague.jp//form/b/25717', 'https://www.vleague.jp//form/b/25721', 'https://www.vleague.jp//form/b/25723', 'https://www.vleague.jp//form/b/25725', 'https://www.vleague.jp//form/b/25719', 'https://www.vleague.jp//form/b/25726', 'https://www.vleague.jp//form/b/25732', 'https://www.vleague.jp//form/b/25728', 'https://www.vleague.jp//form/b/25734', 'https://www.vleague.jp//form/b/25727', 'https://www.vleague.jp//form/b/25729', 'https://www.vleague.jp//form/b/25733', 'https://www.vleague.jp//form/b/25735', 'https://www.vleague.jp//form/b/25730', 'https://www.vleague.jp//form/b/25731', 'https://www.vleague.jp//form/b/25736', 'https://www.vleague.jp//form/b/25742', 'https://www.vleague.jp//form/b/25740', 'https://www.vleague.jp//form/b/25737', 'https://www.vleague.jp//form/b/25743', 'https://www.vleague.jp//form/b/25738', 'https://www.vleague.jp//form/b/25744', 'https://www.vleague.jp//form/b/25739', 'https://www.vleague.jp//form/b/25741', 'https://www.vleague.jp//form/b/25745', 'https://www.vleague.jp//form/b/25748', 'https://www.vleague.jp//form/b/25752', 'https://www.vleague.jp//form/b/25754', 'https://www.vleague.jp//form/b/25750', 'https://www.vleague.jp//form/b/25746', 'https://www.vleague.jp//form/b/25753', 'https://www.vleague.jp//form/b/25749', 'https://www.vleague.jp//form/b/25755', 'https://www.vleague.jp//form/b/25747', 'https://www.vleague.jp//form/b/25751', 'https://www.vleague.jp//form/b/25762', 'https://www.vleague.jp//form/b/25760', 'https://www.vleague.jp//form/b/25756', 'https://www.vleague.jp//form/b/25764', 'https://www.vleague.jp//form/b/25757', 'https://www.vleague.jp//form/b/25758', 'https://www.vleague.jp//form/b/25763', 'https://www.vleague.jp//form/b/25765', 'https://www.vleague.jp//form/b/25761', 'https://www.vleague.jp//form/b/25759', 'https://www.vleague.jp//form/b/25766', 'https://www.vleague.jp//form/b/25768', 'https://www.vleague.jp//form/b/25774', 'https://www.vleague.jp//form/b/25772', 'https://www.vleague.jp//form/b/25767', 'https://www.vleague.jp//form/b/25769', 'https://www.vleague.jp//form/b/25770', 'https://www.vleague.jp//form/b/25775', 'https://www.vleague.jp//form/b/25773', 'https://www.vleague.jp//form/b/25771', 'https://www.vleague.jp//form/b/25776', 'https://www.vleague.jp//form/b/25784', 'https://www.vleague.jp//form/b/25782', 'https://www.vleague.jp//form/b/25780', 'https://www.vleague.jp//form/b/25777', 'https://www.vleague.jp//form/b/25783', 'https://www.vleague.jp//form/b/25785', 'https://www.vleague.jp//form/b/25781', 'https://www.vleague.jp//form/b/25796', 'https://www.vleague.jp//form/b/25804', 'https://www.vleague.jp//form/b/25798', 'https://www.vleague.jp//form/b/25800', 'https://www.vleague.jp//form/b/25802', 'https://www.vleague.jp//form/b/25797', 'https://www.vleague.jp//form/b/25801', 'https://www.vleague.jp//form/b/25805', 'https://www.vleague.jp//form/b/25799', 'https://www.vleague.jp//form/b/25803', 'https://www.vleague.jp//form/b/25806', 'https://www.vleague.jp//form/b/25808', 'https://www.vleague.jp//form/b/25814', 'https://www.vleague.jp//form/b/25812', 'https://www.vleague.jp//form/b/25807', 'https://www.vleague.jp//form/b/25809', 'https://www.vleague.jp//form/b/25810', 'https://www.vleague.jp//form/b/25815', 'https://www.vleague.jp//form/b/25813', 'https://www.vleague.jp//form/b/25811', 'https://www.vleague.jp//form/b/25816', 'https://www.vleague.jp//form/b/25824', 'https://www.vleague.jp//form/b/25822', 'https://www.vleague.jp//form/b/25819', 'https://www.vleague.jp//form/b/25820', 'https://www.vleague.jp//form/b/25817', 'https://www.vleague.jp//form/b/25823', 'https://www.vleague.jp//form/b/25825', 'https://www.vleague.jp//form/b/25821', 'https://www.vleague.jp//form/b/25828', 'https://www.vleague.jp//form/b/25826', 'https://www.vleague.jp//form/b/25830', ...
# C:\Users\sasno\Desktop\MyPandas\vleague\v1_m
#              試合日         チーム 背番号  リベロ     名前  出場数    1    2    3    4  ...  \
# 0     2020-10-17  サントリーサンバーズ   1    L   鶴田大樹    4    ●    ●    ●    ●  ...
# 1     2020-10-17  サントリーサンバーズ   3  NaN   小野遥輝    4    ■    ■    ■    ■  ...
# 2     2020-10-17  サントリーサンバーズ   4  NaN  鳥飼亜斗夢    0  nan  nan  nan  nan  ...
# 3     2020-10-17  サントリーサンバーズ   5  NaN  松林憲太郎    0  nan  nan  nan  nan  ...
# 4     2020-10-17  サントリーサンバーズ   8  NaN   柳田将洋    4    ■    ■    ■    ■  ...
# ...          ...         ...  ..  ...    ...  ...  ...  ...  ...  ...  ...
# 4517  2021-03-13  VC長野トライデンツ  14  NaN   矢貫龍馬    2    ■    ■  nan  nan  ...
# 4518  2021-03-13  VC長野トライデンツ  15  NaN  波佐間泰平    3    □    □    □  nan  ...
# 4519  2021-03-13  VC長野トライデンツ  16  NaN   森崎健史    2  nan  nan    ■    ■  ...
# 4520  2021-03-13  VC長野トライデンツ  21  NaN   高澤和貴    1  nan  nan  nan    □  ...
# 4521  2021-03-13  VC長野トライデンツ  22    L    角雅也    1  nan  nan  nan    〇  ...
#
#      サーブレシーブ成功・良  サーブレシーブ成功率  相手アタック打数  相手アタック得点  相手アタック失点  相手アタック決定率  \
# 0             11        71.2       NaN       NaN       NaN        NaN
# 1              0           -       NaN       NaN       NaN        NaN
# 2              0           -       NaN       NaN       NaN        NaN
# 3              0           -       NaN       NaN       NaN        NaN
# 4              4        33.3       NaN       NaN       NaN        NaN
# ...          ...         ...       ...       ...       ...        ...
# 4517           1        50.0       NaN       NaN       NaN        NaN
# 4518           0           -       NaN       NaN       NaN        NaN
# 4519           0        50.0       NaN       NaN       NaN        NaN
# 4520           0         0.0       NaN       NaN       NaN        NaN
# 4521           0           -       NaN       NaN       NaN        NaN
#
#      相手ブロック得点  相手ブロックセット平均  相手サーブ効果率  相手サーブレシーブ成功率
# 0         NaN          NaN       NaN           NaN
# 1         NaN          NaN       NaN           NaN
# 2         NaN          NaN       NaN           NaN
# 3         NaN          NaN       NaN           NaN
# 4         NaN          NaN       NaN           NaN
# ...       ...          ...       ...           ...
# 4517      NaN          NaN       NaN           NaN
# 4518      NaN          NaN       NaN           NaN
# 4519      NaN          NaN       NaN           NaN
# 4520      NaN          NaN       NaN           NaN
# 4521      NaN          NaN       NaN           NaN
#
# [4221 rows x 40 columns]
#            名前       年月        チーム 背番号  出場数  アタック打数  アタック得点  アタック失点  アタック決定率  \
# 0    エドガートーマス  2020-10  JTサンダーズ広島   6   15     136      66       3     48.5
# 1    エドガートーマス  2020-11  JTサンダーズ広島   6    9      88      36       9     40.9
# 2    エドガートーマス  2020-12  JTサンダーズ広島   6    5      50      26       5     52.0
# 3    エドガートーマス  2021-01  JTサンダーズ広島   6   24     246     134      15     54.5
# 4    エドガートーマス  2021-02  JTサンダーズ広島   6   29     302     142      15     47.0
# ..        ...      ...        ...  ..  ...     ...     ...     ...      ...
# 882      黒田彪斗  2020-10       FC東京  26    0       0       0       0      NaN
# 883      黒田彪斗  2020-11       FC東京  26    0       0       0       0      NaN
# 884      黒田彪斗  2021-01       FC東京  26    9      55      28       3     50.9
# 885      黒田彪斗  2021-02       FC東京  26    8      30      10       2     33.3
# 886      黒田彪斗  2021-03       FC東京  26    0       0       0       0      NaN
#
#      アタック効果率  ...  サーブ失点  サーブ効果  受数  サーブレシーブ成功・優  サーブレシーブ成功・良  バックアタック決定率  \
# 0       46.3  ...     12     11   0            0            0        48.9
# 1       30.7  ...      7      3   0            0            0        56.0
# 2       42.0  ...      5      1   0            0            0        38.9
# 3       48.4  ...     26     31   0            0            0        58.8
# 4       42.1  ...     34     40   0            0            0        53.5
# ..       ...  ...    ...    ...  ..          ...          ...         ...
# 882      NaN  ...      0      0   0            0            0         NaN
# 883      NaN  ...      0      0   0            0            0         NaN
# 884     45.5  ...      6     10  43           19            8        33.3
# 885     26.7  ...      5      2  20            4           10         0.0
# 886      NaN  ...      0      0   0            0            0         NaN
#
#      アタックセット平均  ブロックセット平均  サーブ効果率  サーブレシーブ成功率
# 0         4.40       0.47     6.9         NaN
# 1         4.00       0.44    -4.3         NaN
# 2         5.20       0.00    -8.3         NaN
# 3         5.58       0.29     5.6         NaN
# 4         4.90       0.21    11.6         NaN
# ..         ...        ...     ...         ...
# 882        NaN        NaN     NaN         NaN
# 883        NaN        NaN     NaN         NaN
# 884       3.11       0.11    15.4        53.5
# 885       1.25       0.38    -3.8        45.0
# 886        NaN        NaN     NaN         NaN
#
# [887 rows x 26 columns]
#               名前           チーム 背番号  出場数  アタック打数  アタック得点  アタック失点  アタック決定率  \
# 0       エドガートーマス     JTサンダーズ広島   6   95     978     479      63     49.0
# 1        クビアクミハウ   パナソニックパンサーズ  13  103     628     316      36     50.3
# 2       クレクバルトシュ    ウルフドッグス名古屋   3  101    1274     702      86     55.1
# 3        ジョンウェント       堺ブレイザーズ  24  106     931     454      99     48.8
# 4    ストックトンカーティス  大分三好ヴァイセアドラー  11  108    1018     453      96     44.5
# ..           ...           ...  ..  ...     ...     ...     ...      ...
# 168         高野直哉       堺ブレイザーズ   4  112     566     282      36     49.8
# 169        鳥飼亜斗夢    サントリーサンバーズ   4    0       0       0       0      NaN
# 170         鵜野幸也       堺ブレイザーズ  23   64     380     172      16     45.3
# 171         鶴田大樹    サントリーサンバーズ   1  109       0       0       0      NaN
# 172         黒田彪斗          FC東京  26   17      85      38       5     44.7
#
#      アタック効果率  バックアタック打数  ...  サーブ失点  サーブ効果   受数  サーブレシーブ成功・優  サーブレシーブ成功・良  \
# 0       42.5        362  ...     94    106    0            0            0
# 1       44.6         84  ...     68    137  611          267          157
# 2       48.4        498  ...    117    123   10            2            2
# 3       38.1        353  ...     94     95    7            0            5
# 4       35.1        416  ...    101    111    4            1            0
# ..       ...        ...  ...    ...    ...  ...          ...          ...
# 168     43.5         82  ...     88    100  775          326          229
# 169      NaN          0  ...      0      0    0            0            0
# 170     41.1         95  ...     32     51  363          153           91
# 171      NaN          0  ...      0      0  580          269          180
# 172     38.8          4  ...     11     12   63           23           18
#
#      バックアタック決定率  アタックセット平均  ブロックセット平均  サーブ効果率  サーブレシーブ成功率
# 0          52.5       5.04       0.31     8.8         NaN
# 1          47.6       3.07       0.42     9.4        56.5
# 2          56.0       6.95       0.45    10.6        30.0
# 3          44.8       4.28       0.47     5.2        35.7
# 4          41.8       4.19       0.31     6.4        25.0
# ..          ...        ...        ...     ...         ...
# 168        58.5       2.52       0.34     3.5        56.8
# 169         NaN        NaN        NaN     NaN         NaN
# 170        46.3       2.69       0.17     6.2        54.7
# 171         NaN       0.00       0.00     NaN        61.9
# 172        25.0       2.24       0.24     7.1        50.8
#
# [173 rows x 25 columns]
# csv作成成功

# %%
# 2020-21の更新
os.chdir('/Users/sasno/Desktop/MyPandas/vleague') 
headers = {"User-Agent": "Mozilla/5.0"}
 
# seasons = get_seasons(division)

# division = "v1_m"
# s_id = "283" # 2019-20
# s_id = "301"
division = "v1_w"
# s_id = "303"
# division = "v2_m"
# s_id = "299"
# division = "v2_w"
# s_id = "302"
# division = "v3_m"
# s_id = "300"
# division = "v3_w"
# s_id = "268" 
# s_round = "2020-21_regular"
s_round = "2021_Vcup"

# %%
create_csv()
# Out:
#              試合日         チーム 背番号  リベロ     名前  出場数    1    2    3    4  ...  \
# 0     2020-10-17  PFUブルーキャッツ   1  NaN  有田妃奈乃    0  nan  nan  nan  nan  ...
# 1     2020-10-17  PFUブルーキャッツ   2  NaN   瀬戸杏華    5    ■    ■    ■    ■  ...
# 2     2020-10-17  PFUブルーキャッツ   3    L   森田茉莉    5    ●    ●    ●    ●  ...
# 3     2020-10-17  PFUブルーキャッツ   6  NaN   村上華澄    5    ■    ■    ■    ■  ...
# 4     2020-10-17  PFUブルーキャッツ   7  NaN   合屋咲希    5    □    □    □    □  ...
# ...          ...         ...  ..  ...    ...  ...  ...  ...  ...  ...  ...
# 3622  2021-02-14    久光スプリングス  17  NaN  濱松明日香    0  nan  nan  nan  nan  ...
# 3623  2021-02-14    久光スプリングス  18    L   戸江真奈    5    ●    ●    ●    ●  ...
# 3624  2021-02-14    久光スプリングス  19  NaN   平山詩嫣    4  nan    □    □    □  ...
# 3625  2021-02-14    久光スプリングス  20  NaN   荒木彩花    5    ■    ■    ■    ■  ...
# 3626  2021-02-14    久光スプリングス  24  NaN   小島絢野    0  nan  nan  nan  nan  ...
#
#      サーブレシーブ成功・良  サーブレシーブ成功率  相手アタック打数  相手アタック得点  相手アタック失点  相手アタック決定率  \
# 0              0           -       NaN       NaN       NaN        NaN
# 1              0           -       NaN       NaN       NaN        NaN
# 2              7        62.5       NaN       NaN       NaN        NaN
# 3              0       100.0       NaN       NaN       NaN        NaN
# 4              1        45.0       NaN       NaN       NaN        NaN
# ...          ...         ...       ...       ...       ...        ...
# 3622           0           -       NaN       NaN       NaN        NaN
# 3623           3        69.4       NaN       NaN       NaN        NaN
# 3624           0           -       NaN       NaN       NaN        NaN
# 3625           1        25.0       NaN       NaN       NaN        NaN
# 3626           0           -       NaN       NaN       NaN        NaN
#
#      相手ブロック得点  相手ブロックセット平均  相手サーブ効果率  相手サーブレシーブ成功率
# 0         NaN          NaN       NaN           NaN
# 1         NaN          NaN       NaN           NaN
# 2         NaN          NaN       NaN           NaN
# 3         NaN          NaN       NaN           NaN
# 4         NaN          NaN       NaN           NaN
# ...       ...          ...       ...           ...
# 3622      NaN          NaN       NaN           NaN
# 3623      NaN          NaN       NaN           NaN
# 3624      NaN          NaN       NaN           NaN
# 3625      NaN          NaN       NaN           NaN
# 3626      NaN          NaN       NaN           NaN
#
# [3386 rows x 40 columns]
#               名前       年月       チーム 背番号  出場数  アタック打数  アタック得点  アタック失点  アタック決定率  \
# 0    アキンラデウォフォルケ  2020-10  久光スプリングス  16   10      52      25       3     48.1
# 1    アキンラデウォフォルケ  2020-11  久光スプリングス  16   24     142      67       3     47.2
# 2    アキンラデウォフォルケ  2020-12  久光スプリングス  16    7      33      17       2     51.5
# 3    アキンラデウォフォルケ  2021-01  久光スプリングス  16   22     104      52       3     50.0
# 4    アキンラデウォフォルケ  2021-02  久光スプリングス  16    9      55      31       1     56.4
# ..           ...      ...       ...  ..  ...     ...     ...     ...      ...
# 899        齋藤加奈子  2020-10   日立リヴァーレ   7    3       0       0       0      NaN
# 900        齋藤加奈子  2020-11   日立リヴァーレ   7   21       0       0       0      NaN
# 901        齋藤加奈子  2020-12   日立リヴァーレ   7    7       0       0       0      NaN
# 902        齋藤加奈子  2021-01   日立リヴァーレ   7   13       0       0       0      NaN
# 903        齋藤加奈子  2021-02   日立リヴァーレ   7   15       0       0       0      NaN
#
#      アタック効果率  ...  サーブ失点  サーブ効果  受数  サーブレシーブ成功・優  サーブレシーブ成功・良  バックアタック決定率  \
# 0       42.3  ...      3     10   0            0            0         0.0
# 1       45.1  ...      8     15  10            3            3         NaN
# 2       45.5  ...      4      4   2            1            0         NaN
# 3       47.1  ...      3     24   1            0            0         NaN
# 4       54.5  ...      1      8   0            0            0         NaN
# ..       ...  ...    ...    ...  ..          ...          ...         ...
# 899      NaN  ...      0      0   7            2            2         NaN
# 900      NaN  ...      0      1  56           33           12         NaN
# 901      NaN  ...      0      0  30           20            7         NaN
# 902      NaN  ...      0      0  55           19           15         NaN
# 903      NaN  ...      0      0  57           29           13         NaN
#
#      アタックセット平均  ブロックセット平均  サーブ効果率  サーブレシーブ成功率
# 0         2.50       0.50     8.6         NaN
# 1         2.79       0.58    11.1        45.0
# 2         2.43       1.00     8.3        50.0
# 3         2.36       1.00    16.0         0.0
# 4         3.44       1.11    11.0         NaN
# ..         ...        ...     ...         ...
# 899       0.00       0.00     NaN        42.9
# 900       0.00       0.00     3.6        69.6
# 901       0.00       0.00     NaN        78.3
# 902       0.00       0.00     NaN        48.2
# 903       0.00       0.00     NaN        62.3
#
# [904 rows x 26 columns]
#               名前          チーム 背番号  出場数  アタック打数  アタック得点  アタック失点  アタック決定率  \
# 0    アキンラデウォフォルケ     久光スプリングス  16   72     386     192      12     49.7
# 1     アコスタロスランディ   PFUブルーキャッツ  18   53     743     272      36     36.6
# 2     オクム大庭冬美ハウィ      日立リヴァーレ  17   39     527     200      38     38.0
# 3       オズソイネリマン   NECレッドロケッツ  23   60     773     288      43     37.3
# 4          クランヤナ       東レアローズ   7   74     890     379      36     42.6
# ..           ...          ...  ..  ...     ...     ...     ...      ...
# 207        高相みな実   PFUブルーキャッツ   8   50     424     135      21     31.8
# 208        高野由里加      岡山シーガルズ  21   11      27       5       2     18.5
# 209        鴫原ひなた  トヨタ車体クインシーズ   1   59     435     137      34     31.5
# 210          黒後愛       東レアローズ   9   71     600     252      22     42.0
# 211        齋藤加奈子      日立リヴァーレ   7   59       0       0       0      NaN
#
#      アタック効果率  バックアタック打数  ...  サーブ失点  サーブ効果   受数  サーブレシーブ成功・優  サーブレシーブ成功・良  \
# 0       46.6          1  ...     19     61   13            4            3
# 1       31.8        116  ...     17     28  317          146           81
# 2       30.7         73  ...      8     26    0            0            0
# 3       31.7        167  ...      9     46    0            0            0
# 4       38.5        134  ...     30     89    3            1            2
# ..       ...        ...  ...    ...    ...  ...          ...          ...
# 207     26.9         47  ...     16     38  391          186           82
# 208     11.1          0  ...      0      6    0            0            0
# 209     23.7         14  ...     15     65  340          159           78
# 210     38.3         66  ...     30     62  443          198          119
# 211      NaN          0  ...      0      1  205          103           49
#
#      バックアタック決定率  アタックセット平均  ブロックセット平均  サーブ効果率  サーブレシーブ成功率
# 0           0.0       2.67       0.81    11.9        42.3
# 1          37.9       5.13       0.28     5.1        58.8
# 2          31.5       5.13       0.28     7.1         NaN
# 3          42.5       4.80       0.47     9.7         NaN
# 4          49.3       5.12       0.49    12.4        66.7
# ..          ...        ...        ...     ...         ...
# 207        14.9       2.70       0.06     8.8        58.1
# 208         NaN       0.45       0.18     6.5         NaN
# 209        21.4       2.32       0.14    13.2        58.2
# 210        24.2       3.55       0.30     9.2        58.1
# 211         NaN       0.00       0.00     3.6        62.2
#
# [212 rows x 25 columns]
# csv作成成功

# %%
import tweepy
import os
import glob
import time
import numpy as np
import pandas as pd
import re
 
# key
consumer_key = 'D4OAzhqT7NNeeCa9R7h0Hxzx3'
consumer_secret = 'Py8P1k5jxdPEvNOb64WUXh8b10sfDL5qr60krVLNOOLEXauZti'
access_token = '1309887734555668481-NNvdk0MCxK4WwKZCKZrOqflU9bwPfG'
access_secret = 'CmkMLM4eiOq4MLP3TE6FfUobThOElR5OAfuVSv3GRnXrJ'
 
# Twitterオブジェクト
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_secret)
api = tweepy.API(auth, wait_on_rate_limit = True)

# %%
daily_all = pd.read_csv('all/{}/daily_all.csv'.format(s_round),encoding='cp932')
# daily_all
day = '2021-03-07'
today_data = daily_all[daily_all['試合日']==day]
# today_data.head()
stats_list = ['total', 'at_attack','attack_k', 'b_attack_k', 'block', 'surve_k', 'surve_eff', 'cut']
# stats = np.random.choice(stats_list)
for stats in stats_list:
    print(stats)
    if stats == 'total':
        reg_judge = today_data['出場数']>=1
        column = '総得点'
        pattern = ['出場数1セット', 2]
    elif stats == 'at_attack':
        reg_judge = today_data['出場数']>=1
        column ='アタック打数'
        pattern = ['出場数1セット', 0]
    elif stats == 'attack_k':
        reg_judge = today_data['アタック打数']>=10
        column = 'アタック決定率'
        pattern = ['打数10本', 1]
    elif stats == 'b_attack_k':
        reg_judge = today_data['バックアタック打数']>=5
        column = 'バックアタック決定率'
        pattern = ['打数5本', 1]
    elif stats == 'block':
        reg_judge = today_data['出場数']>=2
        column = 'ブロックセット平均'
        pattern = ['出場数2セット', 0]
    elif stats == 'surve_k':
        reg_judge = today_data['サーブ打数']>=5
        column = 'サーブ得点'
        pattern = ['サーブ打数5本', 2]
    elif stats == 'surve_eff':
        reg_judge = today_data['サーブ打数']>=5
        column = 'サーブ効果率'
        pattern = ['サーブ打数5本', 1]
    else:
        reg_judge = today_data['受数']>=5
        column = 'サーブレシーブ成功率'
        pattern = ['受数5本', 1]
    print(column)

    for i in range(3):
        stats_df = today_data[reg_judge][['名前', 'チーム', '背番号', '出場数', column]]
        stats_df = stats_df.sort_values(column, ascending=False).head()
        print(stats_df)
        if len(stats_df) >= 3:
            break
    # try:
    # stats_df = stats_df.to_dict()
    print(stats_df)
    if division == 'v1_m':
        division_j = 'V1男子'
    elif division == 'v1_w':
        division_j = 'V1女子'
    elif division == 'v2_m':
        division_j = 'V2男子'
    elif division == 'v2_w':
        division_j = 'V2女子'
    elif division == 'v3_m':
        division_j = 'V3男子'
    else:
        division_j = 'V3女子'
    
    p = re.compile('[\u0000-\u007F]+')
    messages = '本日({})の成績\n'.format(day)
    messages += 'シーズン: {}\n'.format(season)
    messages += '【{0}】ランキング({1}以上)\n'.format(column, pattern[0])
    messages += 'ディビジョン: {}\n'.format(division_j)
    print(len(stats_df))
    for i in range(len(stats_df)):
        if pattern[1]==1:
            message = '{0}位 #{1} ({2}, {3}%)\n'.format(i+1, stats_df['名前'].iloc[i], stats_df['チーム'].iloc[i], stats_df[column].iloc[i])
        elif pattern[1]==2:
            message = '{0}位 #{1} ({2}, {3}点)\n'.format(i+1, stats_df['名前'].iloc[i], stats_df['チーム'].iloc[i], stats_df[column].iloc[i])
        else:
            message = '{0}位 #{1} ({2}, {3}本)\n'.format(i+1, stats_df['名前'].iloc[i], stats_df['チーム'].iloc[i], stats_df[column].iloc[i])
        m_len = messages + message
        m_len = messages + message
        e_len = len(''.join(p.findall(m_len)))
        tweet_len = len(m_len) - (e_len/2)
        # print(tweet_len)
        if tweet_len <= 140:
            messages += message
        else:
            break
    print(messages)
    # api.update_status(messages)
    # except:
    #     pass
# Out:
# total
# 総得点
#               名前          チーム  背番号  出場数  総得点
# 586     クレクバルトシュ   ウルフドッグス名古屋    3    3   24
# 684   パダルクリスティアン       東レアローズ    4    3   24
# 634  ムセルスキードミトリー   サントリーサンバーズ   13    3   23
# 567   プレモビッチピーター         FC東京   20    3   22
# 653         清水邦広  パナソニックパンサーズ    1    4   21
#               名前          チーム  背番号  出場数  総得点
# 586     クレクバルトシュ   ウルフドッグス名古屋    3    3   24
# 684   パダルクリスティアン       東レアローズ    4    3   24
# 634  ムセルスキードミトリー   サントリーサンバーズ   13    3   23
# 567   プレモビッチピーター         FC東京   20    3   22
# 653         清水邦広  パナソニックパンサーズ    1    4   21
# 5
# 本日(2020-10-31)の成績
# シーズン: 2020-21_regular
# 【総得点】ランキング(出場数1セット以上)
# ディビジョン: V1男子
# 1位 #クレクバルトシュ (ウルフドッグス名古屋, 24点)
# 2位 #パダルクリスティアン (東レアローズ, 24点)
# 3位 #ムセルスキードミトリー (サントリーサンバーズ, 23点)
#
# at_attack
# アタック打数
#               名前           チーム  背番号  出場数  アタック打数
# 648         袴谷亮介  ジェイテクトSTINGS   11    4      45
# 684   パダルクリスティアン        東レアローズ    4    3      45
# 586     クレクバルトシュ    ウルフドッグス名古屋    3    3      42
# 577  ストックトンカーティス  大分三好ヴァイセアドラー   11    3      38
# 567   プレモビッチピーター          FC東京   20    3      35
#               名前           チーム  背番号  出場数  アタック打数
# 648         袴谷亮介  ジェイテクトSTINGS   11    4      45
# 684   パダルクリスティアン        東レアローズ    4    3      45
# 586     クレクバルトシュ    ウルフドッグス名古屋    3    3      42
# 577  ストックトンカーティス  大分三好ヴァイセアドラー   11    3      38
# 567   プレモビッチピーター          FC東京   20    3      35
# 5
# 本日(2020-10-31)の成績
# シーズン: 2020-21_regular
# 【アタック打数】ランキング(出場数1セット以上)
# ディビジョン: V1男子
# 1位 #袴谷亮介 (ジェイテクトSTINGS, 45本)
# 2位 #パダルクリスティアン (東レアローズ, 45本)
# 3位 #クレクバルトシュ (ウルフドッグス名古屋, 42本)
#
# attack_k
# アタック決定率
#               名前          チーム  背番号  出場数  アタック決定率
# 660         山内晶大  パナソニックパンサーズ   10    4     80.0
# 667         安永拓弥    JTサンダーズ広島    1    3     70.0
# 634  ムセルスキードミトリー   サントリーサンバーズ   13    3     68.8
# 629         柳田将洋   サントリーサンバーズ    8    3     68.8
# 603         出耒田敬      堺ブレイザーズ    7    3     66.7
#               名前          チーム  背番号  出場数  アタック決定率
# 660         山内晶大  パナソニックパンサーズ   10    4     80.0
# 667         安永拓弥    JTサンダーズ広島    1    3     70.0
# 634  ムセルスキードミトリー   サントリーサンバーズ   13    3     68.8
# 629         柳田将洋   サントリーサンバーズ    8    3     68.8
# 603         出耒田敬      堺ブレイザーズ    7    3     66.7
# 5
# 本日(2020-10-31)の成績
# シーズン: 2020-21_regular
# 【アタック決定率】ランキング(打数10本以上)
# ディビジョン: V1男子
# 1位 #山内晶大 (パナソニックパンサーズ, 80.0%)
# 2位 #安永拓弥 (JTサンダーズ広島, 70.0%)
# 3位 #ムセルスキードミトリー (サントリーサンバーズ, 68.8%)
#
# b_attack_k
# バックアタック決定率
#               名前         チーム  背番号  出場数 バックアタック決定率
# 595         高梨健太  ウルフドッグス名古屋   22    3       80.0
# 634  ムセルスキードミトリー  サントリーサンバーズ   13    3       77.8
# 567   プレモビッチピーター        FC東京   20    3       69.2
# 586     クレクバルトシュ  ウルフドッグス名古屋    3    3       58.3
# 671     エドガートーマス   JTサンダーズ広島    6    3       58.3
#               名前         チーム  背番号  出場数 バックアタック決定率
# 595         高梨健太  ウルフドッグス名古屋   22    3       80.0
# 634  ムセルスキードミトリー  サントリーサンバーズ   13    3       77.8
# 567   プレモビッチピーター        FC東京   20    3       69.2
# 586     クレクバルトシュ  ウルフドッグス名古屋    3    3       58.3
# 671     エドガートーマス   JTサンダーズ広島    6    3       58.3
# 5
# 本日(2020-10-31)の成績
# シーズン: 2020-21_regular
# 【バックアタック決定率】ランキング(打数5本以上)
# ディビジョン: V1男子
# 1位 #高梨健太 (ウルフドッグス名古屋, 80.0%)
# 2位 #ムセルスキードミトリー (サントリーサンバーズ, 77.8%)
# 3位 #プレモビッチピーター (FC東京, 69.2%)
#
# block
# ブロックセット平均
#           名前           チーム  背番号  出場数 ブロックセット平均
# 643     福山汰一  ジェイテクトSTINGS    4    4      1.25
# 668    小野寺太志     JTサンダーズ広島    2    3      1.00
# 661  クビアクミハウ   パナソニックパンサーズ   13    4      1.00
# 606     関田誠大       堺ブレイザーズ   11    3      1.00
# 565     武藤鉄也          FC東京   18    3      1.00
#           名前           チーム  背番号  出場数 ブロックセット平均
# 643     福山汰一  ジェイテクトSTINGS    4    4      1.25
# 668    小野寺太志     JTサンダーズ広島    2    3      1.00
# 661  クビアクミハウ   パナソニックパンサーズ   13    4      1.00
# 606     関田誠大       堺ブレイザーズ   11    3      1.00
# 565     武藤鉄也          FC東京   18    3      1.00
# 5
# 本日(2020-10-31)の成績
# シーズン: 2020-21_regular
# 【ブロックセット平均】ランキング(出場数2セット以上)
# ディビジョン: V1男子
# 1位 #福山汰一 (ジェイテクトSTINGS, 1.25本)
# 2位 #小野寺太志 (JTサンダーズ広島, 1.00本)
# 3位 #クビアクミハウ (パナソニックパンサーズ, 1.00本)
#
# surve_k
# サーブ得点
#              名前           チーム  背番号  出場数  サーブ得点
# 599        樋口裕希       堺ブレイザーズ    2    3      3
# 627        小野遥輝    サントリーサンバーズ    3    3      2
# 567  プレモビッチピーター          FC東京   20    3      2
# 648        袴谷亮介  ジェイテクトSTINGS   11    4      2
# 622        森崎健史    VC長野トライデンツ   16    3      1
#              名前           チーム  背番号  出場数  サーブ得点
# 599        樋口裕希       堺ブレイザーズ    2    3      3
# 627        小野遥輝    サントリーサンバーズ    3    3      2
# 567  プレモビッチピーター          FC東京   20    3      2
# 648        袴谷亮介  ジェイテクトSTINGS   11    4      2
# 622        森崎健史    VC長野トライデンツ   16    3      1
# 5
# 本日(2020-10-31)の成績
# シーズン: 2020-21_regular
# 【サーブ得点】ランキング(サーブ打数5本以上)
# ディビジョン: V1男子
# 1位 #樋口裕希 (堺ブレイザーズ, 3点)
# 2位 #小野遥輝 (サントリーサンバーズ, 2点)
# 3位 #プレモビッチピーター (FC東京, 2点)
# 4位 #袴谷亮介 (ジェイテクトSTINGS, 2点)
#
# surve_eff
# サーブ効果率
#        名前           チーム  背番号  出場数 サーブ効果率
# 585   山近哲    ウルフドッグス名古屋    2    3    9.4
# 581  井口直紀  大分三好ヴァイセアドラー   21    3    8.3
# 584  山田脩造    ウルフドッグス名古屋    1    3    8.3
# 648  袴谷亮介  ジェイテクトSTINGS   11    4    7.7
# 635  加藤久典    サントリーサンバーズ   14    2    7.1
#        名前           チーム  背番号  出場数 サーブ効果率
# 585   山近哲    ウルフドッグス名古屋    2    3    9.4
# 581  井口直紀  大分三好ヴァイセアドラー   21    3    8.3
# 584  山田脩造    ウルフドッグス名古屋    1    3    8.3
# 648  袴谷亮介  ジェイテクトSTINGS   11    4    7.7
# 635  加藤久典    サントリーサンバーズ   14    2    7.1
# 5
# 本日(2020-10-31)の成績
# シーズン: 2020-21_regular
# 【サーブ効果率】ランキング(サーブ打数5本以上)
# ディビジョン: V1男子
# 1位 #山近哲 (ウルフドッグス名古屋, 9.4%)
# 2位 #井口直紀 (大分三好ヴァイセアドラー, 8.3%)
# 3位 #山田脩造 (ウルフドッグス名古屋, 8.3%)
#
# cut
# サーブレシーブ成功率
#         名前          チーム  背番号  出場数 サーブレシーブ成功率
# 596   小川智大   ウルフドッグス名古屋   24    3       86.4
# 662   伊賀亮平  パナソニックパンサーズ   16    4       81.2
# 562  古賀太一郎         FC東京   10    3       75.0
# 673   武智洸史    JTサンダーズ広島    8    3       72.2
# 615   戸嵜嵩大   VC長野トライデンツ    7    3       67.4
#         名前          チーム  背番号  出場数 サーブレシーブ成功率
# 596   小川智大   ウルフドッグス名古屋   24    3       86.4
# 662   伊賀亮平  パナソニックパンサーズ   16    4       81.2
# 562  古賀太一郎         FC東京   10    3       75.0
# 673   武智洸史    JTサンダーズ広島    8    3       72.2
# 615   戸嵜嵩大   VC長野トライデンツ    7    3       67.4
# 5
# 本日(2020-10-31)の成績
# シーズン: 2020-21_regular
# 【サーブレシーブ成功率】ランキング(受数5本以上)
# ディビジョン: V1男子
# 1位 #小川智大 (ウルフドッグス名古屋, 86.4%)
# 2位 #伊賀亮平 (パナソニックパンサーズ, 81.2%)
# 3位 #古賀太一郎 (FC東京, 75.0%)
# 4位 #武智洸史 (JTサンダーズ広島, 72.2%)

# %%
daily_all = pd.read_csv('all/2020-21_regular/daily_all.csv',encoding='cp932')
daily_all.sort_values('総得点', ascending=False).head()
# Out:
#             試合日   月              チーム        相手チーム  背番号  リベロ          名前  出場数  \
# 150  2020-10-18  10          日立リヴァーレ  トヨタ車体クインシーズ   17  NaN  オクム大庭冬美ハウィ    5
# 189  2020-10-18  10         JTマーヴェラス     久光スプリングス   10  NaN   ドルーズアンドレア    4
# 267  2020-10-18  10  KUROBEアクアフェアリーズ   埼玉上尾メディックス    9  NaN        舛田紗淑    4
# 246  2020-10-18  10       NECレッドロケッツ      岡山シーガルズ   12  NaN        山内美咲    4
# 312  2020-10-24  10       埼玉上尾メディックス    ヴィクトリーナ姫路    9  NaN       内瀬戸真実    5
#
#      1  2  ... サーブ打数 サーブ得点 サーブ失点  サーブ効果  サーブ効果率  受数  サーブレシーブ成功・優  サーブレシーブ成功・良  \
# 150  ■  ■  ...    10     0     0      3     7.5   0            0            0
# 189  ■  ■  ...     8     1     1      4    21.9   0            0            0
# 267  ■  ■  ...    21     3     1      7    21.4  31           11           12
# 246  □  ■  ...    16     3     0      2    21.9  27           16            5
# 312  ■  ■  ...    17     0     0      5     7.4  31           10            7
#
#     サーブレシーブ成功率  総得点
# 150          -   40
# 189          -   27
# 267       54.8   25
# 246       68.5   25
# 312       43.5   23
#
# [5 rows x 35 columns]

# %%
yearly_all = pd.read_csv('all/{}/yearly_all.csv'.format(s_round),encoding='cp932')
n = 5
stats_list = ['total', 'at_attack','attack_k', 'b_attack_k', 'block', 'surve_k', 'surve_eff', 'cut']
# stats = np.random.choice(stats_list)
for stats in stats_list:
    print(stats)
    if stats == 'total':
        reg_judge = yearly_all['出場数']>=n
        column = '総得点'
        pattern = ['出場数{}セット'.format(n), 2]
    elif stats == 'at_attack':
        reg_judge = yearly_all['出場数']>=n
        column ='アタック打数'
        pattern = ['出場数{}セット'.format(n), 0]
    elif stats == 'attack_k':
        reg_judge = yearly_all['アタック打数']>=n*10
        column = 'アタック決定率'
        pattern = ['打数{}本'.format(n*10), 1]
    elif stats == 'b_attack_k':
        reg_judge = yearly_all['バックアタック打数']>=n*4
        column = 'バックアタック決定率'
        pattern = ['打数{}本'.format(n*4), 1]
    elif stats == 'block':
        reg_judge = yearly_all['出場数']>=n
        column = 'ブロックセット平均'
        pattern = ['出場数{}セット'.format(n), 0]
    elif stats == 'surve_k':
        reg_judge = yearly_all['サーブ打数']>=n*5
        column = 'サーブ得点'
        pattern = ['サーブ打数{}本'.format(n*5), 2]
    elif stats == 'surve_eff':
        reg_judge = yearly_all['サーブ打数']>=n*5
        column = 'サーブ効果率'
        pattern = ['サーブ打数{}本'.format(n*5), 1]
    else:
        reg_judge = yearly_all['受数']>=n*10
        column = 'サーブレシーブ成功率'
        pattern = ['受数{}本'.format(n*10), 1]
    print(column)

    for i in range(3):
        stats_df = yearly_all[reg_judge][['名前', 'チーム', '背番号', '出場数', column]]
        stats_df = stats_df.sort_values(column, ascending=False).head()
        print(stats_df)
        if len(stats_df) >= 3:
            break
    # try:
    # stats_df = stats_df.to_dict()
    print(stats_df)
    p = re.compile('[\u0000-\u007F]+')
    messages = '今シーズン({})通算成績\n'.format(season)
    messages += '【{0}】ランキング({1}以上)\n'.format(column, pattern[0])
    messages += 'ディビジョン: {}\n'.format(division)
    print(len(stats_df))
    for i in range(len(stats_df)):
        if pattern[1]==1:
            message = '{0}位 #{1} ({2}, {3}%)\n'.format(i+1, stats_df['名前'].iloc[i], stats_df['チーム'].iloc[i], stats_df[column].iloc[i])
        elif pattern[1]==2:
            message = '{0}位 #{1} ({2}, {3}点)\n'.format(i+1, stats_df['名前'].iloc[i], stats_df['チーム'].iloc[i], stats_df[column].iloc[i])
        else:
            message = '{0}位 #{1} ({2}, {3}本)\n'.format(i+1, stats_df['名前'].iloc[i], stats_df['チーム'].iloc[i], stats_df[column].iloc[i])
        m_len = messages + message
        m_len = messages + message
        e_len = len(''.join(p.findall(m_len)))
        tweet_len = len(m_len) - (e_len/2)
        # print(tweet_len)
        if tweet_len <= 140:
            messages += message
        else:
            break
    print(messages)
#     api.update_status(messages)
    # except:
    #     pass
# Out:
# total
# 総得点
#             名前              チーム  背番号  出場数  総得点
# 6    ソロカイテインドレ      トヨタ車体クインシーズ   13   17   71
# 11        上坂瑠子          日立リヴァーレ    1   13   66
# 169       金田修佳          岡山シーガルズ   18   15   65
# 129       田中瑞稀         JTマーヴェラス    6   13   59
# 10      リーシモーン  KUROBEアクアフェアリーズ   10    9   52
#             名前              チーム  背番号  出場数  総得点
# 6    ソロカイテインドレ      トヨタ車体クインシーズ   13   17   71
# 11        上坂瑠子          日立リヴァーレ    1   13   66
# 169       金田修佳          岡山シーガルズ   18   15   65
# 129       田中瑞稀         JTマーヴェラス    6   13   59
# 10      リーシモーン  KUROBEアクアフェアリーズ   10    9   52
# 5
# 今シーズン(2020-21_regular)通算成績
# 【総得点】ランキング(出場数5セット以上)
# ディビジョン: v1_w
# 1位 #ソロカイテインドレ (トヨタ車体クインシーズ, 71点)
# 2位 #上坂瑠子 (日立リヴァーレ, 66点)
# 3位 #金田修佳 (岡山シーガルズ, 65点)
# 4位 #田中瑞稀 (JTマーヴェラス, 59点)
#
# at_attack
# アタック打数
#             名前          チーム  背番号  出場数  アタック打数
# 6    ソロカイテインドレ  トヨタ車体クインシーズ   13   17     205
# 169       金田修佳      岡山シーガルズ   18   15     191
# 11        上坂瑠子      日立リヴァーレ    1   13     181
# 171      長内美和子      日立リヴァーレ   13   13     154
# 129       田中瑞稀     JTマーヴェラス    6   13     142
#             名前          チーム  背番号  出場数  アタック打数
# 6    ソロカイテインドレ  トヨタ車体クインシーズ   13   17     205
# 169       金田修佳      岡山シーガルズ   18   15     191
# 11        上坂瑠子      日立リヴァーレ    1   13     181
# 171      長内美和子      日立リヴァーレ   13   13     154
# 129       田中瑞稀     JTマーヴェラス    6   13     142
# 5
# 今シーズン(2020-21_regular)通算成績
# 【アタック打数】ランキング(出場数5セット以上)
# ディビジョン: v1_w
# 1位 #ソロカイテインドレ (トヨタ車体クインシーズ, 205本)
# 2位 #金田修佳 (岡山シーガルズ, 191本)
# 3位 #上坂瑠子 (日立リヴァーレ, 181本)
# 4位 #長内美和子 (日立リヴァーレ, 154本)
#
# attack_k
# アタック決定率
#               名前          チーム  背番号  出場数  アタック決定率
# 0    アキンラデウォフォルケ     久光スプリングス   16   11     56.7
# 7     ヌクジャンタットダオ     JTマーヴェラス    7   13     51.7
# 1     アコスタロスランディ   PFUブルーキャッツ   18    5     50.9
# 85           工藤嶺  デンソーエアリービーズ   21   10     46.7
# 122          渡邊彩  トヨタ車体クインシーズ    7   13     46.2
#               名前          チーム  背番号  出場数  アタック決定率
# 0    アキンラデウォフォルケ     久光スプリングス   16   11     56.7
# 7     ヌクジャンタットダオ     JTマーヴェラス    7   13     51.7
# 1     アコスタロスランディ   PFUブルーキャッツ   18    5     50.9
# 85           工藤嶺  デンソーエアリービーズ   21   10     46.7
# 122          渡邊彩  トヨタ車体クインシーズ    7   13     46.2
# 5
# 今シーズン(2020-21_regular)通算成績
# 【アタック決定率】ランキング(打数50本以上)
# ディビジョン: v1_w
# 1位 #アキンラデウォフォルケ (久光スプリングス, 56.7%)
# 2位 #ヌクジャンタットダオ (JTマーヴェラス, 51.7%)
# 3位 #アコスタロスランディ (PFUブルーキャッツ, 50.9%)
#
# b_attack_k
# バックアタック決定率
#             名前              チーム  背番号  出場数  バックアタック決定率
# 10      リーシモーン  KUROBEアクアフェアリーズ   10    9        56.5
# 85         工藤嶺      デンソーエアリービーズ   21   10        33.3
# 158       西川有喜         JTマーヴェラス   13   13        32.0
# 6    ソロカイテインドレ      トヨタ車体クインシーズ   13   17        22.7
#             名前              チーム  背番号  出場数  バックアタック決定率
# 10      リーシモーン  KUROBEアクアフェアリーズ   10    9        56.5
# 85         工藤嶺      デンソーエアリービーズ   21   10        33.3
# 158       西川有喜         JTマーヴェラス   13   13        32.0
# 6    ソロカイテインドレ      トヨタ車体クインシーズ   13   17        22.7
# 4
# 今シーズン(2020-21_regular)通算成績
# 【バックアタック決定率】ランキング(打数20本以上)
# ディビジョン: v1_w
# 1位 #リーシモーン (KUROBEアクアフェアリーズ, 56.5%)
# 2位 #工藤嶺 (デンソーエアリービーズ, 33.3%)
# 3位 #西川有喜 (JTマーヴェラス, 32.0%)
#
# block
# ブロックセット平均
#              名前              チーム  背番号  出場数  ブロックセット平均
# 26          付欣田          岡山シーガルズ   24    8       1.12
# 0   アキンラデウォフォルケ         久光スプリングス   16   11       1.00
# 5      ジョセフシャイナ       埼玉上尾メディックス   15    7       0.86
# 10       リーシモーン  KUROBEアクアフェアリーズ   10    9       0.78
# 7    ヌクジャンタットダオ         JTマーヴェラス    7   13       0.69
#              名前              チーム  背番号  出場数  ブロックセット平均
# 26          付欣田          岡山シーガルズ   24    8       1.12
# 0   アキンラデウォフォルケ         久光スプリングス   16   11       1.00
# 5      ジョセフシャイナ       埼玉上尾メディックス   15    7       0.86
# 10       リーシモーン  KUROBEアクアフェアリーズ   10    9       0.78
# 7    ヌクジャンタットダオ         JTマーヴェラス    7   13       0.69
# 5
# 今シーズン(2020-21_regular)通算成績
# 【ブロックセット平均】ランキング(出場数5セット以上)
# ディビジョン: v1_w
# 1位 #付欣田 (岡山シーガルズ, 1.12本)
# 2位 #アキンラデウォフォルケ (久光スプリングス, 1.0本)
# 3位 #ジョセフシャイナ (埼玉上尾メディックス, 0.86本)
#
# surve_k
# サーブ得点
#         名前         チーム  背番号  出場数  サーブ得点
# 75    山内美咲  NECレッドロケッツ   12   12      6
# 13    上野香織  NECレッドロケッツ    6   13      5
# 65   小川愛里奈      東レアローズ    8    9      4
# 60    安田美南  NECレッドロケッツ   14   10      4
# 169   金田修佳     岡山シーガルズ   18   15      4
#         名前         チーム  背番号  出場数  サーブ得点
# 75    山内美咲  NECレッドロケッツ   12   12      6
# 13    上野香織  NECレッドロケッツ    6   13      5
# 65   小川愛里奈      東レアローズ    8    9      4
# 60    安田美南  NECレッドロケッツ   14   10      4
# 169   金田修佳     岡山シーガルズ   18   15      4
# 5
# 今シーズン(2020-21_regular)通算成績
# 【サーブ得点】ランキング(サーブ打数25本以上)
# ディビジョン: v1_w
# 1位 #山内美咲 (NECレッドロケッツ, 6点)
# 2位 #上野香織 (NECレッドロケッツ, 5点)
# 3位 #小川愛里奈 (東レアローズ, 4点)
# 4位 #安田美南 (NECレッドロケッツ, 4点)
#
# surve_eff
# サーブ効果率
#         名前          チーム  背番号  出場数  サーブ効果率
# 158   西川有喜     JTマーヴェラス   13   13    18.9
# 75    山内美咲   NECレッドロケッツ   12   12    18.4
# 33    入澤まい      日立リヴァーレ   14   13    18.3
# 65   小川愛里奈       東レアローズ    8    9    17.6
# 80   山形理沙子  トヨタ車体クインシーズ   20   17    16.9
#         名前          チーム  背番号  出場数  サーブ効果率
# 158   西川有喜     JTマーヴェラス   13   13    18.9
# 75    山内美咲   NECレッドロケッツ   12   12    18.4
# 33    入澤まい      日立リヴァーレ   14   13    18.3
# 65   小川愛里奈       東レアローズ    8    9    17.6
# 80   山形理沙子  トヨタ車体クインシーズ   20   17    16.9
# 5
# 今シーズン(2020-21_regular)通算成績
# 【サーブ効果率】ランキング(サーブ打数25本以上)
# ディビジョン: v1_w
# 1位 #西川有喜 (JTマーヴェラス, 18.9%)
# 2位 #山内美咲 (NECレッドロケッツ, 18.4%)
# 3位 #入澤まい (日立リヴァーレ, 18.3%)
# 4位 #小川愛里奈 (東レアローズ, 17.6%)
#
# cut
# サーブレシーブ成功率
#               名前              チーム  背番号  出場数  サーブレシーブ成功率
# 169         金田修佳          岡山シーガルズ   18   15        72.3
# 11          上坂瑠子          日立リヴァーレ    1   13        66.4
# 147         舛田紗淑  KUROBEアクアフェアリーズ    9    8        64.7
# 8    ヒックマンジャスティス         JTマーヴェラス   14   12        64.0
# 55          大川愛海      トヨタ車体クインシーズ   22   11        62.1
#               名前              チーム  背番号  出場数  サーブレシーブ成功率
# 169         金田修佳          岡山シーガルズ   18   15        72.3
# 11          上坂瑠子          日立リヴァーレ    1   13        66.4
# 147         舛田紗淑  KUROBEアクアフェアリーズ    9    8        64.7
# 8    ヒックマンジャスティス         JTマーヴェラス   14   12        64.0
# 55          大川愛海      トヨタ車体クインシーズ   22   11        62.1
# 5
# 今シーズン(2020-21_regular)通算成績
# 【サーブレシーブ成功率】ランキング(受数50本以上)
# ディビジョン: v1_w
# 1位 #金田修佳 (岡山シーガルズ, 72.3%)
# 2位 #上坂瑠子 (日立リヴァーレ, 66.4%)
# 3位 #舛田紗淑 (KUROBEアクアフェアリーズ, 64.7%)
# 4位 #ヒックマンジャスティス (JTマーヴェラス, 64.0%)

# %%
os.chdir(division)
os.getcwd()
# Out:
# 'C:\\Users\\sasno\\Desktop\\MyPandas\\vleague\\v1_w'
