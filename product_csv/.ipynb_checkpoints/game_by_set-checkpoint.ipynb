# %%
from selenium import webdriver

import time
import numpy as np
import pandas as pd

from bs4 import BeautifulSoup
import urllib.request as req

import requests
import os
import glob
import datetime
import re

# %%
address = "autumn.vb.cats1014@docomo.ne.jp"
password = "1378fk1014"

# %%
options = webdriver.ChromeOptions()
headers = {"User-Agent": "Mozilla/5.0"}
prefs = {"download.default_directory" : "C:\\Users\\sasno\\Desktop\\Mypandas\\vleague"}
options.add_experimental_option("prefs", prefs)
options.add_argument("--headless")

# %%
# GoogleChromeを起動
browser = webdriver.Chrome(executable_path='C:\\Users\\sasno\\anaconda3\\lib\\site-packages\\chromedriver_binary\\chromedriver.exe', options=options)
browser.implicitly_wait(3)

# %%
browser.close()

# %%
# ログインするサイトへアクセス
url_login = "https://vleague.tv/signin"
browser.get(url_login)
time.sleep(3)
print("ログインページにアクセスしました")
# Out:
# ログインページにアクセスしました

# %%
# テキストボックス入力
element = browser.find_element_by_id('account-mail')
element.clear()
element.send_keys(address)
element = browser.find_element_by_id('account-pw')
element.clear()
element.send_keys(password)
print("フォームを送信")
# 入力したデータをクリック
browser_from = browser.find_element_by_class_name('btn_submit')
time.sleep(1)
browser_from.click()
print("情報を入力してログインボタンを押しました")
# ログインするサイトへアクセス
time.sleep(1)
url_login = 'https://vleague.tv/match'
browser.get(url_login)
time.sleep(3)
print("ログインページにアクセスしました")
# Out:
# フォームを送信
# 情報を入力してログインボタンを押しました
# ログインページにアクセスしました

# %%
os.chdir('C:\\Users\\sasno\\Desktop\\MyPandas\\vleague')
division = 'v1_m'
s_round = '2020-21_regular'
# game_set = 1
os.chdir('{}'.format(division))
print(os.getcwd())
# Scheduleからライブスコアを取得
# for文で回す
# 試合
# 177
def remove_csv(csvs):
    for csv in csvs:
        if os.path.exists(csv):
            os.remove(csv)
    print('既存のcsvを削除')

for game_num in range(1, 2):
#     try:
        browser.get(url_login)
        daily = browser.find_element_by_xpath('//*[@id="schedule"]/div/div[3]/div[{}]/div[2]/p[1]'.format(game_num)).text
        daily = daily.replace('.', '-')[:10]
        element = browser.find_element_by_xpath('//*[@id="schedule"]/div/div[3]/div[{}]/p/a'.format(game_num))
        element.click()
        time.sleep(1)
        element = browser.find_element_by_xpath('//*[@id="livescore"]/div[3]/div[1]/ul/li[2]')
        element.click()
        time.sleep(1)
        team = browser.find_elements_by_class_name('team_name')
        h_team = team[0].text
        a_team = team[1].text
        print(daily, h_team, a_team)
        game_sets = browser.find_element_by_class_name('history_set').text
        for game_set in range(1, game_sets.count('\n')+2):
            browser.execute_script("window.scrollTo(0, 0)")
            browser.execute_script("window.scrollTo(0, document.body.scrollHeight);")
            element = browser.find_element_by_xpath('//*[@id="livescore"]/div[3]/div[2]/ul/li[{}]'.format(game_set))
            element.click()
            time.sleep(1)
            historys = browser.find_elements_by_class_name('history_item')
            # print(len(historys))
            log_len = len(historys)
            text = ""

            log_lists = []
            home_p = 0
            away_p = 0
#             print(log_len)
            try:
                for i in range(1, log_len+1):
    #                     //*[@id="livescore"]/div[3]/div[2]/div/div[1]/div[1]
                    home_history = browser.find_element_by_xpath('//*[@id="livescore"]/div[3]/div[2]/div/div[{}]/div[1]'.format(str(i))).text
                #     print(home_history)
                    home_point = browser.find_element_by_xpath('//*[@id="livescore"]/div[3]/div[2]/div/div[{}]/div[2]'.format(str(i))).text
                    if home_point == '':
                        home_point = home_p
                    else:
                        home_p = int(home_point)
                    away_history = browser.find_element_by_xpath('//*[@id="livescore"]/div[3]/div[2]/div/div[{}]/div[5]'.format(str(i))).text
                    away_point = browser.find_element_by_xpath('//*[@id="livescore"]/div[3]/div[2]/div/div[{}]/div[4]'.format(str(i))).text
                    if away_point == '':
                        away_point = away_p
                    else:
                        away_p = int(away_point)
                #     print(home_point, away_point)
                    log_list = [home_p, away_p, home_history, away_history]
                #     print(log_list)
                    log_lists.append(log_list)
                    log_df = pd.DataFrame(data=log_lists)
            
    #             print(log_lists[-1])
                home_log = log_df[2].str.split(expand=True)
                home_log = home_log.mask(home_log.loc[:, 2].isnull()==True, home_log.shift(axis=1))
                # print(len(home_log.columns))
                if len(home_log.columns) == 3:
                    home_log[["交代番号", "交代選手"]] = None
                home_log.columns = ["状況", "番号", "選手", "交代番号", "交代選手"]
                # home_log
                away_log = log_df.loc[:, 3].str.split(expand=True)
                away_log = away_log.mask(away_log.loc[:, 2].isnull()==True, away_log.shift(axis=1))
                # print(len(away_log.columns))
                if len(away_log.columns) == 3:
                    away_log[["相手交代番号", "相手交代選手"]] = None
                away_log.columns = ["相手状況", "相手番号", "相手選手", "相手交代番号", "相手交代選手"]
                # away_log
                point = log_df[[0,1]]
                point.columns = ["得点", "失点"]
                # SettingWithCopyWarning: 後から修正
                point['+/-'] = point["得点"] - point["失点"]
                f = lambda x: 'Lead' if x > 0 else ('Tie' if x == 0 else 'Behind') 
                point['L-B'] = point['+/-'].map(f)
                # point
                away_point = point.reindex(["失点", "得点", '+/-', 'L-B'], axis=1)
                away_point['+/-'] = away_point['+/-'].map(lambda x: -x)
                away_point['L-B'] = away_point['+/-'].map(f)
                away_point.columns = ["得点", "失点", '+/-', 'L-B']
                # away_point
                home_game_log = pd.concat([point, home_log, away_log], axis=1)
                away_game_log = pd.concat([away_point, away_log, home_log], axis=1)
                away_game_log.columns = home_game_log.columns
            except:
                print('error_1')
                pass

            home_csv = '{}/{}/{}-livescore-{}set.csv'.format(h_team, s_round, daily, game_set)
            away_csv = '{}/{}/{}-livescore-{}set.csv'.format(a_team, s_round, daily, game_set)
            home_csv_2 = 'all/{}/{}-livescore-{}vs{}-{}set.csv'.format(s_round, daily, h_team, a_team, game_set)
            away_csv_2 = 'all/{}/{}-livescore-{}vs{}-{}set.csv'.format(s_round, daily, a_team, h_team, game_set)
#             remove_csv([home_csv, away_csv, home_csv_2, away_csv_2])
                        
            if(len(home_game_log) > 10):
                home_game_log.to_csv(home_csv, index=False)
                away_game_log.to_csv(away_csv, index=False)
                home_game_log.to_csv(home_csv_2, index=False)
                away_game_log.to_csv(away_csv_2, index=False)
                print('{}セット目csv作成成功'.format(game_set))
            else:
                print('データ無し')
            time.sleep(1)
            
#     except:
#         print('error_2')
#         time.sleep(1)
#         pass
# Out:
# C:\Users\sasno\Desktop\MyPandas\vleague\v1_m
# 2020-10-17 堺ブレイザーズ VC長野トライデンツ
# C:\Users\sasno\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:88: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# 1セット目csv作成成功
# C:\Users\sasno\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:88: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# 2セット目csv作成成功
# C:\Users\sasno\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:88: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# 3セット目csv作成成功
# C:\Users\sasno\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:88: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# 4セット目csv作成成功

# %%
home_csv = '{}/{}/{}-livescore-{}set.csv'.format(h_team, s_round, daily, game_set)
away_csv = '{}/{}/{}-livescore-{}set.csv'.format(a_team, s_round, daily, game_set)
os.path.exists(away_csv)
# Out:
# True

# %%
import warnings
from pandas.core.common import SettingWithCopyWarning

warnings.simplefilter(action="ignore", category=SettingWithCopyWarning)

# %%
os.chdir('C:\\Users\\sasno\\Desktop\\MyPandas\\vleague')
division = 'v1_w'
s_round = '2020-21_regular'
# game_set = 1
os.chdir('{}'.format(division))
print(os.getcwd())
# Scheduleからライブスコアを取得
# for文で回す
# 試合
def remove_csv(csvs):
    judge = False
    for csv in csvs:
        if os.path.exists(csv):
            os.remove(csv)
            judge = True
    if judge:
        print('既存のcsvを削除')

def click(path):
    element = browser.find_element_by_xpath(path)
    browser.implicitly_wait(3)
    element.click()
    time.sleep(1)
        
text = ''

def create_csv():
    browser.get(url_login)
    time.sleep(1)
    #         v1_w
    element = browser.find_element_by_xpath('//*[@id="schedule"]/div/div[1]/ul/li[4]')
    browser.implicitly_wait(3)
    element.click()
    time.sleep(1)
    element.click()

    daily = browser.find_element_by_xpath('//*[@id="schedule"]/div/div[3]/div[{}]/div[2]/p[1]'.format(game_num)).text
    daily = daily.replace('.', '-')[:10]
    click('//*[@id="schedule"]/div/div[3]/div[{}]/p/a'.format(game_num))
    click('//*[@id="livescore"]/div[3]/div[1]/ul/li[2]')
    team = browser.find_elements_by_class_name('team_name')
    h_team = team[0].text
    a_team = team[1].text
    print(game_num, daily, h_team, a_team)
    game_sets = browser.find_element_by_class_name('history_set').text

    for game_set in range(1, game_sets.count('\n')+2):
#         for game_set in range(2, 3):
        count = 0
        home_game_log = pd.DataFrame()
        while len(home_game_log) < 10 or count < 3:

            browser.execute_script("window.scrollTo(0, 0)")
            browser.execute_script("window.scrollTo(0, document.body.scrollHeight);")
            browser.implicitly_wait(3)
            element = browser.find_element_by_xpath('//*[@id="livescore"]/div[3]/div[2]/ul/li[{}]'.format(game_set))
            browser.implicitly_wait(3)
            element.click()
#             print(game_set)
            time.sleep(3)
            element.click()
            historys = browser.find_elements_by_class_name('history_item')
            # print(len(historys))
            log_len = len(historys)
            text = ""

            log_lists = []
            home_p = 0
            away_p = 0
#             print(log_len)
            try:
                count += 1
                log_df = pd.DataFrame()
                home_game_log = pd.DataFrame()
                away_game_log = pd.DataFrame()
                for i in range(1, log_len+1):
    #                     //*[@id="livescore"]/div[3]/div[2]/div/div[1]/div[1]
                    home_history = browser.find_element_by_xpath('//*[@id="livescore"]/div[3]/div[2]/div/div[{}]/div[1]'.format(str(i))).text
                #     print(home_history)
                    home_point = browser.find_element_by_xpath('//*[@id="livescore"]/div[3]/div[2]/div/div[{}]/div[2]'.format(str(i))).text
                    if home_point == '':
                        home_point = home_p
                    else:
                        home_p = int(home_point)
                    away_history = browser.find_element_by_xpath('//*[@id="livescore"]/div[3]/div[2]/div/div[{}]/div[5]'.format(str(i))).text
                    away_point = browser.find_element_by_xpath('//*[@id="livescore"]/div[3]/div[2]/div/div[{}]/div[4]'.format(str(i))).text
                    if away_point == '':
                        away_point = away_p
                    else:
                        away_p = int(away_point)
                #     print(home_point, away_point)
                    log_list = [home_p, away_p, home_history, away_history]
                #     print(log_list)
                    log_lists.append(log_list)
                log_df = pd.DataFrame(data=log_lists)

#             print(log_lists[-1])
                home_log = log_df[2].str.split(expand=True)
                home_log = home_log.mask(home_log.loc[:, 2].isnull()==True, home_log.shift(axis=1))
                # print(len(home_log.columns))
                if len(home_log.columns) == 3:
                    home_log[["交代番号", "交代選手"]] = None
                home_log.columns = ["状況", "番号", "選手", "交代番号", "交代選手"]
                # home_log
                away_log = log_df.loc[:, 3].str.split(expand=True)
                away_log = away_log.mask(away_log.loc[:, 2].isnull()==True, away_log.shift(axis=1))
                # print(len(away_log.columns))
                if len(away_log.columns) == 3:
                    away_log[["相手交代番号", "相手交代選手"]] = None
                away_log.columns = ["相手状況", "相手番号", "相手選手", "相手交代番号", "相手交代選手"]
                # away_log
                point = log_df[[0,1]]
                point.columns = ["得点", "失点"]
                # SettingWithCopyWarning: 後から修正
                point['+/-'] = point["得点"] - point["失点"]
                f = lambda x: 'Lead' if x > 0 else ('Tie' if x == 0 else 'Behind') 
                point['L-B'] = point['+/-'].map(f)
                # point
                away_point = point.reindex(["失点", "得点", '+/-', 'L-B'], axis=1)
                away_point['+/-'] = away_point['+/-'].map(lambda x: -x)
                away_point['L-B'] = away_point['+/-'].map(f)
                away_point.columns = ["得点", "失点", '+/-', 'L-B']
                # away_point
                home_game_log = pd.concat([point, home_log, away_log], axis=1)
                away_game_log = pd.concat([away_point, away_log, home_log], axis=1)
                away_game_log.columns = home_game_log.columns
            except:
                count += 1
                print('error_1')
                pass
            
        if count >= 3:
            text += '{}-{}set\n'.format(game_num, game_set)

        home_csv = '{}/{}/{}-livescore-{}set.csv'.format(h_team, s_round, daily, game_set)
        away_csv = '{}/{}/{}-livescore-{}set.csv'.format(a_team, s_round, daily, game_set)
        home_csv_2 = 'all/{}/{}-livescore-{}vs{}-{}set.csv'.format(s_round, daily, h_team, a_team, game_set)
        away_csv_2 = 'all/{}/{}-livescore-{}vs{}-{}set.csv'.format(s_round, daily, a_team, h_team, game_set)
#             remove_csv([home_csv, away_csv, home_csv_2, away_csv_2])

        if(len(home_game_log) > 10):
            home_game_log.to_csv(home_csv, index=False)
            away_game_log.to_csv(away_csv, index=False)
            home_game_log.to_csv(home_csv_2, index=False)
            away_game_log.to_csv(away_csv_2, index=False)
            print('{}セット目csv作成成功'.format(game_set))
        else:
            print('データ無し')
        time.sleep(1)

# //*[@id="schedule"]/div/div[3]/div[141]/p/a
for game_num in range(114, 115):
    try:
        create_csv()
    except:
        print('error_2 and retry')
        text += '{}\n'.format(game_num)
        time.sleep(1)
        create_csv()
        pass
print(text)
# Out:
# C:\Users\sasno\Desktop\MyPandas\vleague\v1_w
# 29 2020-11-07 埼玉上尾メディックス トヨタ車体クインシーズ
# 1セット目csv作成成功
# 2セット目csv作成成功
# 3セット目csv作成成功
# 4セット目csv作成成功

# %%
h_home = browser.find_elements_by_class_name('team_name')

# %%
game_sets = browser.find_element_by_class_name('history_set').text
game_sets.count('\n')
# Out:
# 3

# %%
# Scheduleからライブスコアを取得
# for文で回す
browser.get(url_login)
daily = browser.find_element_by_xpath('//*[@id="schedule"]/div/div[3]/div[1]/div[2]/p[1]').text
daily = daily.replace('.', '-')[:10]
print(daily)
element = browser.find_element_by_xpath('//*[@id="schedule"]/div/div[3]/div[2]/p/a')
element.click()
time.sleep(1)
element = browser.find_element_by_xpath('//*[@id="livescore"]/div[3]/div[1]/ul/li[2]')
element.click()
time.sleep(1)
# セットをクリック
browser.execute_script("window.scrollTo(0, document.body.scrollHeight);")
# 1セット目
element = browser.find_element_by_xpath('//*[@id="livescore"]/div[3]/div[2]/ul/li[1]')
element.click()
# Out:
# 2020-10-17

# %%
daily = daily.replace('.', '-')[:10]
daily
# Out:
# '2020-10-17'

# %%
# for文で回す
team = browser.find_elements_by_class_name('team_name')
h_team = team[0].text
a_team = team[1].text
historys = browser.find_elements_by_class_name('history_item')
# print(len(historys))
log_len = len(historys)
text = ""

log_lists = []
home_p = 0
away_p = 0
for i in range(1, log_len+1):
    home_history = browser.find_element_by_xpath('//*[@id="livescore"]/div[3]/div[2]/div/div[{}]/div[1]'.format(str(i))).text
#     print(home_history)
    home_point = browser.find_element_by_xpath('//*[@id="livescore"]/div[3]/div[2]/div/div[{}]/div[2]'.format(str(i))).text
    if home_point == '':
        home_point = home_p
    else:
        home_p = int(home_point)
    away_history = browser.find_element_by_xpath('//*[@id="livescore"]/div[3]/div[2]/div/div[{}]/div[5]'.format(str(i))).text
    away_point = browser.find_element_by_xpath('//*[@id="livescore"]/div[3]/div[2]/div/div[{}]/div[4]'.format(str(i))).text
    if away_point == '':
        away_point = away_p
    else:
        away_p = int(away_point)
#     print(home_point, away_point)
    log_list = [home_p, away_p, home_history, away_history]
#     print(log_list)
    log_lists.append(log_list)
    log_df = pd.DataFrame(data=log_lists)
print(log_lists[-1])
log_df
# Out:
# [25, 20, '得点', '']
#       0   1                           2                          3
# 0     0   0
# 1     0   0                                               サーブ 8 河東
# 2     0   0             レシーブ成功(良) 4 高野
# 3     0   0                       21 竹元
# 4     0   0                                                   7 戸嵜
# ..   ..  ..                         ...                        ...
# 205  24  20                                                     得点
# 206  24  20  メンバー交代: IN:7 出耒田 OUT:12 小池
# 207  24  20                              メンバー交代: IN:21 高澤 OUT:4 中村
# 208  24  20                                           サーブミス 21 高澤
# 209  25  20                          得点
#
# [210 rows x 4 columns]

# %%
# 出来ない
def log_processing(log_df):
    home_log = log_df.loc[:, 2].str.split(expand=True)
    home_log = home_log.mask(home_log.loc[:, 2].isnull()==True, home_log.shift(axis=1))
    home_log.columns = ["状況", "番号", "選手", "交代番号", "交代選手"]
    # home_log
    away_log = log_df.loc[:, 3].str.split(expand=True)
    away_log = away_log.mask(away_log.loc[:, 2].isnull()==True, away_log.shift(axis=1))
    away_log.columns = ["相手状況", "相手番号", "相手選手", "相手交代番号", "相手交代選手"]
    # away_log
    point = log_df[[0,1]]
    point.columns = ["得点", "失点"]
    # point
    game_log = pd.concat([point, home_log, away_log], axis=1)
    return game_log

# %%
home_log = log_df[2].str.split(expand=True)
home_log = home_log.mask(home_log.loc[:, 2].isnull()==True, home_log.shift(axis=1))
# print(len(home_log.columns))
if len(home_log.columns) == 3:
    home_log[["交代番号", "交代選手"]] = None
home_log.columns = ["状況", "番号", "選手", "交代番号", "交代選手"]
# home_log
away_log = log_df.loc[:, 3].str.split(expand=True)
away_log = away_log.mask(away_log.loc[:, 2].isnull()==True, away_log.shift(axis=1))
# print(len(away_log.columns))
if len(away_log.columns) == 3:
    away_log[["相手交代番号", "相手交代選手"]] = None
away_log.columns = ["相手状況", "相手番号", "相手選手", "相手交代番号", "相手交代選手"]
# away_log
point = log_df[[0,1]]
point.columns = ["得点", "失点"]
# SettingWithCopyWarning: 後から修正
point['+/-'] = point["得点"] - point["失点"]
f = lambda x: 'Lead' if x > 0 else ('Tie' if x == 0 else 'Behind') 
point['L-B'] = point['+/-'].map(f)
# point
away_point = point.reindex(["失点", "得点", '+/-', 'L-B'], axis=1)
away_point['+/-'] = away_point['+/-'].map(lambda x: -x)
away_point['L-B'] = away_point['+/-'].map(f)
away_point.columns = ["得点", "失点", '+/-', 'L-B']
# away_point
home_game_log = pd.concat([point, home_log, away_log], axis=1)
away_game_log = pd.concat([away_point, away_log, home_log], axis=1)
away_game_log.columns = home_game_log.columns
# home_game_log.to_csv('{}.csv'.format(h_team), index=False)
# away_game_log.to_csv('{}.csv'.format(a_team), index=False)
# home_game_log
away_game_log
# Out:
#      得点  失点  +/-     L-B       状況     番号    選手   交代番号  交代選手        相手状況  相手番号  \
# 0     0   0    0     Tie      NaN   None  None   None  None         NaN  None
# 1     0   0    0     Tie      サーブ      8    河東   None  None         NaN  None
# 2     0   0    0     Tie      NaN   None  None   None  None  レシーブ成功(良)     4
# 3     0   0    0     Tie      NaN   None  None   None  None         NaN    21
# 4     0   0    0     Tie      NaN      7    戸嵜   None  None         NaN  None
# ..   ..  ..  ...     ...      ...    ...   ...    ...   ...         ...   ...
# 205  20  24   -4  Behind      NaN     得点  None   None  None         NaN  None
# 206  20  24   -4  Behind      NaN   None  None   None  None     メンバー交代:  IN:7
# 207  20  24   -4  Behind  メンバー交代:  IN:21    高澤  OUT:4    中村         NaN  None
# 208  20  24   -4  Behind   サーブミス     21    高澤   None  None         NaN  None
# 209  20  25   -5  Behind      NaN   None  None   None  None         NaN    得点
#
#      相手選手  相手交代番号 相手交代選手
# 0    None    None   None
# 1    None    None   None
# 2      高野    None   None
# 3      竹元    None   None
# 4    None    None   None
# ..    ...     ...    ...
# 205  None    None   None
# 206   出耒田  OUT:12     小池
# 207  None    None   None
# 208  None    None   None
# 209  None    None   None
#
# [210 rows x 14 columns]

# %%
home_game_log
# Out:
#      得点  失点  +/-     L-B   状況    番号    選手  交代番号  交代選手        相手状況  相手番号  相手選手  \
# 0     0   0    0     Tie  NaN  None  None  None  None         NaN  None  None
# 1     0   0    0     Tie  サーブ    17    藪田  None  None              None  None
# 2     0   0    0     Tie       None  None  None  None  レシーブ成功(優)    12    石川
# 3     0   0    0     Tie       None  None  None  None     アタック成功:    12    石川
# 4     0   1   -1  Behind       None  None  None  None                得点  None
# ..   ..  ..  ...     ...  ...   ...   ...   ...   ...         ...   ...   ...
# 224  17  24   -7  Behind         得点  None  None  None              None  None
# 225  17  24   -7  Behind  サーブ    11    荒木  None  None              None  None
# 226  17  24   -7  Behind       None  None  None  None  レシーブ成功(良)     9    黒後
# 227  17  24   -7  Behind       None  None  None  None     アタック成功:     9    黒後
# 228  17  25   -8  Behind       None  None  None  None                得点  None
#
#     相手交代番号 相手交代選手  サーブ権
# 0     None   None   NaN
# 1     None   None  Home
# 2     None   None  Home
# 3     None   None  Home
# 4     None   None  Home
# ..     ...    ...   ...
# 224   None   None  Away
# 225   None   None  Home
# 226   None   None  Home
# 227   None   None  Home
# 228   None   None  Home
#
# [229 rows x 15 columns]

# %%
away_game_log.columns = home_game_log.columns
away_game_log
# Out:
#      得点  失点  +/-   L-B          状況    番号    選手  交代番号  交代選手 相手状況  相手番号  相手選手  \
# 0     0   0    0   Tie         NaN  None  None  None  None  NaN  None  None
# 1     0   0    0   Tie              None  None  None  None  サーブ    17    藪田
# 2     0   0    0   Tie  レシーブ成功(優)    12    石川  None  None       None  None
# 3     0   0    0   Tie     アタック成功:    12    石川  None  None       None  None
# 4     1   0    1  Lead                得点  None  None  None       None  None
# ..   ..  ..  ...   ...         ...   ...   ...   ...   ...  ...   ...   ...
# 224  24  17    7  Lead              None  None  None  None         得点  None
# 225  24  17    7  Lead              None  None  None  None  サーブ    11    荒木
# 226  24  17    7  Lead  レシーブ成功(良)     9    黒後  None  None       None  None
# 227  24  17    7  Lead     アタック成功:     9    黒後  None  None       None  None
# 228  25  17    8  Lead                得点  None  None  None       None  None
#
#     相手交代番号 相手交代選手  サーブ権
# 0     None   None   NaN
# 1     None   None  Home
# 2     None   None  Home
# 3     None   None  Home
# 4     None   None  Home
# ..     ...    ...   ...
# 224   None   None  Away
# 225   None   None  Home
# 226   None   None  Home
# 227   None   None  Home
# 228   None   None  Home
#
# [229 rows x 15 columns]

# %%
os.chdir('/Users/sasno/Desktop/MyPandas/vleague')
division = 'v1_w'
os.chdir(division)
print(os.getcwd())
s_round = '2020-21_regular'
h_team = '東レアローズ'
livescore_lists = glob.glob('all/{}/*-livescore-{}vs*'.format(s_round, h_team))
print(len(livescore_lists))
home_game_log = pd.read_csv(livescore_lists[1])
home_game_log.tail()
# Out:
# C:\Users\sasno\Desktop\MyPandas\vleague\v1_w
# 81
#      得点  失点  +/-   L-B       状況   番号   選手 交代番号 交代選手 相手状況 相手番号 相手選手 相手交代番号  \
# 212  24  18    6  Lead      NaN  NaN  NaN  NaN  NaN  サーブ    6   山口    NaN
# 213  24  18    6  Lead  レシーブ失敗    9   黒後  NaN  NaN  NaN  NaN  NaN    NaN
# 214  24  18    6  Lead      NaN    9   黒後  NaN  NaN  NaN  NaN  NaN    NaN
# 215  24  18    6  Lead  アタック成功:   12   石川  NaN  NaN  NaN  NaN  NaN    NaN
# 216  25  18    7  Lead      NaN   得点  NaN  NaN  NaN  NaN  NaN  NaN    NaN
#
#     相手交代選手
# 212    NaN
# 213    NaN
# 214    NaN
# 215    NaN
# 216    NaN

# %%
score = home_game_log[["得点", "失点", '+/-']]
score = score[~score.duplicated()]
score["経過"] = score["得点"] + score["失点"]
score.tail()
# Out:
#      得点  失点  +/-  経過
# 217  19  22   -3  41
# 223  19  23   -4  42
# 230  19  24   -5  43
# 235  20  24   -4  44
# 239  20  25   -5  45

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns

import plotly.offline
import plotly.express as px
import plotly.graph_objects as go
import plotly.subplots
import squarify

# %%
tips = sns.load_dataset("tips")

# %%
sns.set_palette('Blues')
ax = sns.barplot(x="経過", y='+/-', data=score, color='blue')
ax.axhline(0, color='red')
# Out:
# C:\Users\sasno\AppData\Roaming\Python\Python37\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning:
#
# Glyph 32076 missing from current font.
#
# C:\Users\sasno\AppData\Roaming\Python\Python37\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning:
#
# Glyph 36942 missing from current font.
#
# C:\Users\sasno\AppData\Roaming\Python\Python37\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning:
#
# Glyph 32076 missing from current font.
#
# C:\Users\sasno\AppData\Roaming\Python\Python37\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning:
#
# Glyph 36942 missing from current font.

# %%
plt.bar(score["経過"], score['+/-'], color='blue', width=1.0)
plt.ylabel('+/-')
plt.grid(True)

# %%
livescore_df = []
for livescore in livescore_lists:
    home_game_log = pd.read_csv(livescore)
    home_game_log.loc[home_game_log["状況"] == "サーブ", "サーブ権"] = 'Home'
    home_game_log.loc[home_game_log["相手状況"] == "サーブ", "サーブ権"] = 'Away'
#     home_game_log_2 = home_game_log[1:]
#     print(home_game_log_2)
    livescore_df.append(home_game_log)
home_game_log_2 = pd.concat(livescore_df).reset_index()
len(home_game_log_2)
# Out:
# 17840

# %%
home_game_log_2[home_game_log_2['状況'].str.contains('ブロ', na=False)]
# Out:
# Empty DataFrame
# Columns: [index, 得点, 失点, +/-, L-B, 状況, 番号, 選手, 交代番号, 交代選手, 相手状況, 相手番号, 相手選手, 相手交代番号, 相手交代選手, サーブ権]
# Index: []

# %%
right_to_serve = ''
player_log = pd.DataFrame(columns = ["アタック打数", "アタック成功", "アタック失敗", "アタック決定率", "アタック効果率",
                                 "ブロック成功", "サーブ受数", "サーブカット成功(優)", "サーブカット成功(良)", "サーブ打数"])
for i in range(len(home_game_log_2)):
    if pd.isnull(home_game_log_2.loc[i,"サーブ権"]):
        home_game_log_2.loc[i,"サーブ権"] = right_to_serve
    else:
        right_to_serve = home_game_log_2.loc[i,"サーブ権"]
#     アタック追加
    if pd.isnull(home_game_log_2.loc[i,"状況"]):
        if pd.isnull(home_game_log_2.loc[i,"選手"]) == False:
            home_game_log_2.loc[i, "状況"] = "アタック"
        else:
            home_game_log_2.loc[i, "状況"] = np.nan
    if pd.isnull(home_game_log_2.loc[i,"相手状況"]):
        if pd.isnull(home_game_log_2.loc[i,"相手選手"]) == False:
            home_game_log_2.loc[i, "相手状況"] = "アタック"
        else:
            home_game_log_2.loc[i, "相手状況"] = np.nan
#         print(right_to_serve) 
#     home_game_log_2.tail()
players = []
players = list(home_game_log_2.drop_duplicates(keep='first', subset=["選手"])["選手"].values)
players.remove(np.nan)
#     print(players)
for player in players:
    player_log.loc[player] = 0
    player_search = home_game_log_2[home_game_log_2["選手"]==player]
    player_attack = player_search[player_search["状況"].str.contains("アタック", na=False)]
    player_attack_a = len(player_attack)
    player_attack_k = len(player_attack[player_attack["状況"]=="アタック成功:"])
    player_attack_e = len(player_attack[player_attack["状況"]=="アタック失敗"])
    # player_attack_a
    player_log.loc[player, "アタック打数"] += player_attack_a
    player_log.loc[player, "アタック成功"] += player_attack_k
    player_log.loc[player, "アタック失敗"] += player_attack_e
    if player_attack_a > 0:
        player_attack_pct = round(player_attack_k * 100 / player_attack_a, 1)
        player_attack_eff = round((player_attack_k-player_attack_e) * 100 / player_attack_a, 1)
#         print(player, player_attack_pct, player_attack_eff)
    else:
        player_attack_pct = None
        player_attack_eff = None
    player_log.loc[player, "アタック決定率"] = player_attack_pct
    player_log.loc[player, "アタック効果率"] = player_attack_eff
    player_block = len(player_search[player_search["状況"].str.contains("ブロ", na=False)])
    player_log.loc[player, "ブロック成功"] += player_block
    player_receive = player_search[player_search["状況"].str.contains("レシーブ", na=False)]
    player_receive_a = len(player_receive)
    player_receive_great = len(player_receive[player_receive["状況"]=="レシーブ成功(優)"])
    player_receive_good = len(player_receive[player_receive["状況"]=="レシーブ成功(良)"])
    player_log.loc[player, "サーブ受数"] += player_receive_a
    player_log.loc[player, "サーブカット成功(優)"] += player_receive_great
    player_log.loc[player, "サーブカット成功(良)"] += player_receive_good
#     サーブでは反応しないためサーで検索
    player_serve = len(player_search[player_search["状況"].str.contains("サー", na=False)])
    player_log.loc[player, "サーブ打数"] = player_serve
player_log
# Out:
#     アタック打数 アタック成功 アタック失敗 アタック決定率 アタック効果率 ブロック成功 サーブ受数 サーブカット成功(優) サーブカット成功(良)  \
# 水杉       0      0      0    None    None      0   220         109          53
# 石川     759    318     46    41.9    35.8      0   551         265         124
# 黒後     673    285     25    42.3    38.6      0   483         214         130
# 大野     194     87     11    44.8    39.2      0     8           4           0
# クラン    959    409     38    42.6    38.7      0     3           1           2
# 井上     101     47      8    46.5    38.6      0     4           2           1
# 白井       1      1      0     100     100      0     0           0           0
# 関       24     13      0    54.2    54.2      0     3           0           1
# 中田      73     21      1    28.8    27.4      0    64          16          19
# 大崎       2      0      0       0       0      0     0           0           0
# 野呂      55     17      3    30.9    25.5      0    31          12           7
# 小川     203     95      5    46.8    44.3      0     4           2           2
# 中島       0      0      0    None    None      0    90          43          26
# 坂本       0      0      0    None    None      0     0           0           0
# 伊藤       0      0      0    None    None      0     0           0           0
#
#     サーブ打数
# 水杉      0
# 石川    354
# 黒後    250
# 大野    230
# クラン   309
# 井上    126
# 白井    108
# 関     270
# 中田     38
# 大崎     28
# 野呂     33
# 小川    140
# 中島      0
# 坂本      4
# 伊藤      7

# %%
all_log.tail()

# %%
home_game_log.loc[home_game_log["状況"] == "サーブ", "サーブ権"] = 'Home'
home_game_log.loc[home_game_log["相手状況"] == "サーブ", "サーブ権"] = 'Away'
home_game_log_2 = home_game_log[1:]
right_to_serve = ''
for i in range(1, len(home_game_log_2)+1):
    if pd.isnull(home_game_log_2.loc[i,"サーブ権"]):
        home_game_log_2.loc[i,"サーブ権"] = right_to_serve
    else:
        right_to_serve = home_game_log_2.loc[i,"サーブ権"]
#     アタック追加
    if pd.isnull(home_game_log_2.loc[i,"状況"]):
        if pd.isnull(home_game_log_2.loc[i,"選手"]) == False:
            home_game_log_2.loc[i, "状況"] = "アタック"
        else:
            home_game_log_2.loc[i, "状況"] = np.nan
    if pd.isnull(home_game_log_2.loc[i,"相手状況"]):
        if pd.isnull(home_game_log_2.loc[i,"相手選手"]) == False:
            home_game_log_2.loc[i, "相手状況"] = "アタック"
        else:
            home_game_log_2.loc[i, "相手状況"] = np.nan
#         print(right_to_serve)
home_game_log_2.tail()
# Out:
#      得点  失点  +/-   L-B       状況   番号   選手 交代番号 交代選手        相手状況 相手番号  相手選手  \
# 243  24  22    2  Lead      NaN  NaN  NaN  NaN  NaN  レシーブ成功(良)   11    目黒
# 244  24  22    2  Lead      NaN  NaN  NaN  NaN  NaN        アタック   10  ドルーズ
# 245  24  22    2  Lead      NaN  NaN  NaN  NaN  NaN        アタック    2     林
# 246  24  22    2  Lead  アタック成功:    7  クラン  NaN  NaN         NaN  NaN   NaN
# 247  25  22    3  Lead      NaN   得点  NaN  NaN  NaN         NaN  NaN   NaN
#
#     相手交代番号 相手交代選手  サーブ権
# 243    NaN    NaN  Home
# 244    NaN    NaN  Home
# 245    NaN    NaN  Home
# 246    NaN    NaN  Home
# 247    NaN    NaN  Home

# %%
away_game_log.loc[away_game_log["状況"] == "サーブ", "サーブ権"] = 'Home'
away_game_log.loc[away_game_log["相手状況"] == "サーブ", "サーブ権"] = 'Away'
away_game_log_2 = away_game_log[1:]
right_to_serve = ''
for i in range(1, len(away_game_log_2)+1):
    if pd.isnull(away_game_log_2.loc[i,"サーブ権"]):
        away_game_log_2.loc[i,"サーブ権"] = right_to_serve
    else:
        right_to_serve = away_game_log_2.loc[i,"サーブ権"]
#     アタック追加
    if pd.isnull(away_game_log_2.loc[i,"状況"]):
        if away_game_log_2.loc[i,"選手"]!=None:
            away_game_log_2.loc[i, "状況"] = "アタック"
        else:
            away_game_log_2.loc[i, "状況"] = np.nan
    if pd.isnull(away_game_log_2.loc[i,"相手状況"]):
        if away_game_log_2.loc[i,"相手選手"]!=None:
            away_game_log_2.loc[i, "相手状況"] = "アタック"
        else:
            away_game_log_2.loc[i, "相手状況"] = np.nan
#         print(right_to_serve) 
away_game_log_2.tail()
# Out:
#      得点  失点  +/-     L-B    状況    番号    選手  交代番号  交代選手        相手状況  相手番号  \
# 225  18  24   -6  Behind        None  None  None  None  レシーブ成功(良)    18
# 226  18  24   -6  Behind        None  None  None  None        アタック     6
# 227  18  24   -6  Behind  アタック    13    田中  None  None              None
# 228  18  24   -6  Behind        None  None  None  None     アタック成功:    18
# 229  18  25   -7  Behind        None  None  None  None                得点
#
#      相手選手 相手交代番号 相手交代選手  サーブ権
# 225    金田   None   None  Home
# 226    渡邊   None   None  Home
# 227  None   None   None  Home
# 228    金田   None   None  Home
# 229  None   None   None  Home

# %%
lead_home = home_game_log_2[home_game_log_2['+/-'] > 0]
lead_home.tail()
# Out:
#      得点  失点  +/-   L-B       状況   番号   選手 交代番号 交代選手        相手状況 相手番号  相手選手  \
# 243  24  22    2  Lead      NaN  NaN  NaN  NaN  NaN  レシーブ成功(良)   11    目黒
# 244  24  22    2  Lead      NaN  NaN  NaN  NaN  NaN        アタック   10  ドルーズ
# 245  24  22    2  Lead      NaN  NaN  NaN  NaN  NaN        アタック    2     林
# 246  24  22    2  Lead  アタック成功:    7  クラン  NaN  NaN         NaN  NaN   NaN
# 247  25  22    3  Lead      NaN   得点  NaN  NaN  NaN         NaN  NaN   NaN
#
#     相手交代番号 相手交代選手  サーブ権
# 243    NaN    NaN  Home
# 244    NaN    NaN  Home
# 245    NaN    NaN  Home
# 246    NaN    NaN  Home
# 247    NaN    NaN  Home

# %%
behind_home = home_game_log_2[home_game_log_2['+/-'] < 0]
behind_home.head()
# Out:
#     得点  失点  +/-     L-B       状況   番号   選手 交代番号 交代選手 相手状況 相手番号 相手選手 相手交代番号  \
# 4    0   1   -1  Behind      NaN  NaN  NaN  NaN  NaN  NaN   得点  NaN    NaN
# 5    0   1   -1  Behind      NaN  NaN  NaN  NaN  NaN  サーブ    8   籾井    NaN
# 6    0   1   -1  Behind  レシーブ失敗    9   黒後  NaN  NaN  NaN  NaN  NaN    NaN
# 7    0   1   -1  Behind  アタック成功:   12   石川  NaN  NaN  NaN  NaN  NaN    NaN
# 15   1   2   -1  Behind      NaN  NaN  NaN  NaN  NaN  NaN   得点  NaN    NaN
#
#    相手交代選手  サーブ権
# 4     NaN  Away
# 5     NaN  Away
# 6     NaN  Away
# 7     NaN  Away
# 15    NaN  Home

# %%
clutch_log = home_game_log_2[(home_game_log_2["得点"] >= 20) & (home_game_log_2["失点"] >= 20) & (abs(home_game_log_2['+/-']) <= 3)]
clutch_log.tail()
# Out:
#        index  得点  失点  +/-     L-B   状況   番号   選手 交代番号 交代選手        相手状況  \
# 17174    198  21  24   -3  Behind  NaN   得点  NaN  NaN  NaN         NaN
# 17175    199  21  24   -3  Behind  NaN  NaN  NaN  NaN  NaN         NaN
# 17176    200  21  24   -3  Behind  サーブ   10    関  NaN  NaN         NaN
# 17177    201  21  24   -3  Behind  NaN  NaN  NaN  NaN  NaN  レシーブ成功(良)
# 17178    202  21  24   -3  Behind  NaN  NaN  NaN  NaN  NaN     アタック成功:
#
#          相手番号  相手選手 相手交代番号 相手交代選手  サーブ権
# 17174     NaN   NaN    NaN    NaN   NaN
# 17175  タイムアウト   NaN    NaN    NaN   NaN
# 17176     NaN   NaN    NaN    NaN  Home
# 17177       2     林    NaN    NaN   NaN
# 17178      10  ドルーズ    NaN    NaN   NaN

# %%
players = list(home_game_log_2.drop_duplicates(keep='first', subset=["選手"])["選手"].values)
players.remove(np.nan)
players
# Out:
# ['石川', '黒後', '大野', 'クラン', '小川', '関', '中島', '伊藤', '中田']

# %%
player_log = pd.DataFrame(columns = ["アタック打数", "アタック成功", "アタック失敗", "アタック決定率", "アタック効果率",
                                     "ブロック成功", "サーブ受数", "サーブカット成功(優)", "サーブカット成功(良)", "サーブ打数"])
for player in players:
    player_search = clutch_log[clutch_log["選手"]==player]
    # player_search = home_away_2
    player_attack = player_search[player_search["状況"].str.contains("アタック", na=False)]
    player_attack_a = len(player_attack)
    player_attack_k = len(player_attack[player_attack["状況"]=="アタック成功:"])
    player_attack_e = len(player_attack[player_attack["状況"]=="アタック失敗"])
    # player_attack_a
    if player_attack_a > 0:
        player_attack_pct = round(player_attack_k * 100 / player_attack_a, 1)
        player_attack_eff = round((player_attack_k-player_attack_e) * 100 / player_attack_a, )
#         print(player, player_attack_pct, player_attack_eff)
    else:
        player_attack_pct = None
        player_attack_eff = None
    player_log.loc[player, "アタック打数"] = player_attack_a
    player_log.loc[player, "アタック成功"] = player_attack_k
    player_log.loc[player, "アタック失敗"] = player_attack_e
    player_log.loc[player, "アタック決定率"] = player_attack_pct
    player_log.loc[player, "アタック効果率"] = player_attack_eff
    player_block = len(player_search[player_search["状況"].str.contains("ブロック", na=False)])
    player_log.loc[player, "ブロック成功"] = player_block
    player_receive = player_search[player_search["状況"].str.contains("レシーブ", na=False)]
    player_receive_a = len(player_receive)
    player_receive_great = len(player_receive[player_receive["状況"]=="レシーブ成功(優)"])
    player_receive_good = len(player_receive[player_receive["状況"]=="レシーブ成功(良)"])
    player_log.loc[player, "サーブ受数"] = player_receive_a
    player_log.loc[player, "サーブカット成功(優)"] = player_receive_great
    player_log.loc[player, "サーブカット成功(良)"] = player_receive_good
#     サーブでは反応しないためサーで検索
    player_serve = len(player_search[player_search["状況"].str.contains("サー", na=False)])
    player_log.loc[player, "サーブ打数"] = player_serve
player_log
# Out:
#     アタック打数 アタック成功 アタック失敗 アタック決定率 アタック効果率 ブロック成功 サーブ受数 サーブカット成功(優) サーブカット成功(良)  \
# 水杉       0      0      0    None    None      0    10           3           3
# 石川      24     21      3    87.5      75      0    29          18           2
# 黒後      14     13      1    92.9      86      0    34          20           8
# 大野       1      1      0     100     100      0     0           0           0
# クラン     33     32      1      97      94      0     0           0           0
# 井上       1      1      0     100     100      0     0           0           0
# 白井       0      0      0    None    None      0     0           0           0
# 関        0      0      0    None    None      0     0           0           0
# 中田       1      1      0     100     100      0     4           1           0
# 大崎       0      0      0    None    None      0     0           0           0
# 野呂       0      0      0    None    None      0     2           1           0
# 中島       0      0      0    None    None      0     3           1           1
# 小川       3      3      0     100     100      0     0           0           0
# 伊藤       0      0      0    None    None      0     0           0           0
# 坂本       0      0      0    None    None      0     0           0           0
#
#     サーブ打数
# 水杉      0
# 石川     10
# 黒後     17
# 大野      1
# クラン    18
# 井上      3
# 白井      7
# 関      11
# 中田      5
# 大崎      5
# 野呂      2
# 中島      0
# 小川      5
# 伊藤      0
# 坂本      2

# %%
player_log = pd.DataFrame(columns = ["アタック打数", "アタック成功", "アタック失敗", "アタック決定率", "アタック効果率",
                                     "ブロック成功", "サーブ受数", "サーブカット成功(優)", "サーブカット成功(良)", "サーブ打数"])
for player in players:
    player_search = home_game_log_2[home_game_log_2["選手"]==player]
    # player_search = home_away_2
    player_attack = player_search[player_search["状況"].str.contains("アタック")]
    player_attack_a = len(player_attack)
    player_attack_k = len(player_attack[player_attack["状況"]=="アタック成功:"])
    player_attack_e = len(player_attack[player_attack["状況"]=="アタック失敗"])
    # player_attack_a
    if player_attack_a > 0:
        player_attack_pct = round(player_attack_k / player_attack_a, 2)
        player_attack_eff = round((player_attack_k-player_attack_e) / player_attack_a, 2)
#         print(player, player_attack_pct, player_attack_eff)
    else:
        player_attack_pct = None
        player_attack_eff = None
    player_log.loc[player, "アタック打数"] = player_attack_a
    player_log.loc[player, "アタック成功"] = player_attack_k
    player_log.loc[player, "アタック失敗"] = player_attack_e
    player_log.loc[player, "アタック決定率"] = player_attack_pct
    player_log.loc[player, "アタック効果率"] = player_attack_eff
    player_block = len(player_search[player_search["状況"].str.contains("ブロック")])
    player_log.loc[player, "ブロック成功"] = player_block
    player_receive = player_search[player_search["状況"].str.contains("レシーブ")]
    player_receive_a = len(player_receive)
    player_receive_great = len(player_receive[player_receive["状況"]=="レシーブ成功(優)"])
    player_receive_good = len(player_receive[player_receive["状況"]=="レシーブ成功(良)"])
    player_log.loc[player, "サーブ受数"] = player_receive_a
    player_log.loc[player, "サーブカット成功(優)"] = player_receive_great
    player_log.loc[player, "サーブカット成功(良)"] = player_receive_good
    player_serve = len(player_search[player_search["状況"].str.contains("サーブ")])
    player_log.loc[player, "サーブ打数"] = player_serve
player_log
# Out:
#     アタック打数 アタック成功 アタック失敗 アタック決定率 アタック効果率 ブロック成功 サーブ受数 サーブカット成功(優) サーブカット成功(良)  \
# 黒後       6      1      1    0.17       0      0    17           6           4
# 水杉       0      0      0    None    None      0     1           1           0
# 石川       5      0      0       0       0      0     2           1           0
# 大野       3      3      0       1       1      0     0           0           0
# クラン     11      5      0    0.45    0.45      0     0           0           0
# 井上       1      1      0       1       1      0     0           0           0
# 関        0      0      0    None    None      0     0           0           0
# 坂本       0      0      0    None    None      0     0           0           0
#
#     サーブ打数
# 黒後      6
# 水杉      0
# 石川      2
# 大野      2
# クラン     3
# 井上      2
# 関       1
# 坂本      1

# %%
player_block = player_search[player_search["状況"].str.contains("ブロック")]
player_block
# Out:
# Empty DataFrame
# Columns: [得点, 失点, +/-, L-B, 状況, 番号, 選手, 交代番号, 交代選手, 相手状況, 相手番号, 相手選手, 相手交代番号, 相手交代選手, サーブ権]
# Index: []

# %%
player_receive = len(player_search[player_search["状況"].str.contains("レシーブ")])
player_receive
# Out:
# 0

# %%
player_log = pd.DataFrame(columns = ["アタック打数", "アタック成功", "アタック失敗", "アタック決定率", "アタック効果率"])
player_log.loc[player, "アタック打数"] = player_attack_a
player_log.loc[player, "アタック成功"] = player_attack_k
player_log.loc[player, "アタック失敗"] = player_attack_e
player_log.loc[player, "アタック決定率"] = player_attack_pct
player_log.loc[player, "アタック効果率"] = player_attack_eff
player_log
# Out:
#    アタック打数 アタック成功 アタック失敗 アタック決定率 アタック効果率
# 村永      6      0      0       0       0

# %%
os.chdir('C:\\Users\\sasno\\Desktop\\MyPandas\\vleague')
division = 'v1_m'
s_round = '2020-21_regular'
# game_set = 1
os.chdir('{}'.format(division))
os.getcwd()
home_game_log.to_csv('{}/{}/{}-livescore-{}set.csv'.format(h_team, s_round, daily, game_set), index=False)
away_game_log.to_csv('{}/{}/{}-livescore-{}set.csv'.format(a_team, s_round, daily, game_set), index=False)

# %%
away_game_log
# Out:
#      得点  失点  +/-     L-B     相手状況   相手番号  相手選手 相手交代番号 相手交代選手          状況  \
# 0     0   0    0     Tie      NaN   None  None   None   None         NaN
# 1     0   0    0     Tie      サーブ      8    河東   None   None         NaN
# 2     0   0    0     Tie      NaN   None  None   None   None  レシーブ成功(良)
# 3     0   0    0     Tie      NaN   None  None   None   None         NaN
# 4     0   0    0     Tie      NaN      7    戸嵜   None   None         NaN
# ..   ..  ..  ...     ...      ...    ...   ...    ...    ...         ...
# 204  19  24   -5  Behind      NaN   None  None   None   None      サーブミス
# 205  20  24   -4  Behind      NaN     得点  None   None   None         NaN
# 206  20  24   -4  Behind      NaN   None  None   None   None     メンバー交代:
# 207  20  24   -4  Behind  メンバー交代:  IN:21    高澤  OUT:4     中村         NaN
# 208  20  24   -4  Behind   サーブミス     21    高澤   None   None         NaN
#
#        番号    選手    交代番号  交代選手
# 0    None  None    None  None
# 1    None  None    None  None
# 2       4    高野    None  None
# 3      21    竹元    None  None
# 4    None  None    None  None
# ..    ...   ...     ...   ...
# 204    12    小池    None  None
# 205  None  None    None  None
# 206  IN:7   出耒田  OUT:12    小池
# 207  None  None    None  None
# 208  None  None    None  None
#
# [209 rows x 14 columns]

# %%
away_point = point.reindex(["失点", "得点", '+/-', 'L-B'], axis=1)
away_point['+/-'] = -away_point['+/-']
away_point.loc[away_point['+/-'] > 0, 'L-B'] = 'Lead'
away_point.loc[away_point['+/-'] == 0, 'L-B'] = 'Tie'
away_point.loc[away_point['+/-'] < 0, 'L-B'] = 'Behind'
away_point.columns = ["得点", "失点", '+/-', 'L-B']
away_point
# Out:
#      得点  失点  +/-     L-B
# 0     0   0    0     Tie
# 1     0   0    0     Tie
# 2     0   0    0     Tie
# 3     0   0    0     Tie
# 4     0   0    0     Tie
# ..   ..  ..  ...     ...
# 204  19  24   -5  Behind
# 205  20  24   -4  Behind
# 206  20  24   -4  Behind
# 207  20  24   -4  Behind
# 208  20  24   -4  Behind
#
# [209 rows x 4 columns]

# %%
away_log.dropna(subset=[3])
# Out:
#            0      1   2       3   4
# 200  メンバー交代:  IN:21  永露  OUT:11  傳田
# 205  メンバー交代:  IN:11  傳田  OUT:21  永露

# %%
away_log
# Out:
#            0      1     2       3     4
# 0        NaN   None  None    None  None
# 1        サーブ     22    高梨    None  None
# 2        NaN   None  None    None  None
# 3        NaN   None  None    None  None
# 4        NaN   None  None    None  None
# ..       ...    ...   ...     ...   ...
# 203      NaN   None  None    None  None
# 204      NaN   None  None    None  None
# 205  メンバー交代:  IN:11    傳田  OUT:21    永露
# 206      NaN   None  None    None  None
# 207  レシーブ失敗     22    高梨    None  None
#
# [208 rows x 5 columns]

# %%
point = log_df[[0,1]]
point.columns = ["得点", "失点"]
# point.loc[:,'+/-'] = 0
point.loc[:,'+/-'] = point.loc[:,"得点"] - point.loc[:,"失点"]
point.loc[point['+/-'] > 0, 'L-B'] = 'Lead'
point.loc[point['+/-'] == 0, 'L-B'] = 'Tie'
point.loc[point['+/-'] < 0, 'L-B'] = 'Behind'
point
# Out:
#      得点  失点  +/-   L-B
# 0     0   0    0   Tie
# 1     0   0    0   Tie
# 2     0   0    0   Tie
# 3     0   0    0   Tie
# 4     0   0    0   Tie
# ..   ..  ..  ...   ...
# 204  24  19    5  Lead
# 205  24  20    4  Lead
# 206  24  20    4  Lead
# 207  24  20    4  Lead
# 208  24  20    4  Lead
#
# [209 rows x 4 columns]

# %%
home_away = pd.concat([point,home_log, away_log], axis=1)
home_away.tail(10)
# Out:
#      得点  失点  +/-   L-B          状況     番号    選手    交代番号  交代選手     相手状況   相手番号  \
# 198  23  21    2  Lead         NaN   None  None    None  None      NaN     得点
# 199  23  21    2  Lead     メンバー交代:  IN:10    藤中  OUT:20    西田      NaN   None
# 200  23  21    2  Lead         NaN   None  None    None  None  メンバー交代:  IN:21
# 201  23  21    2  Lead         NaN   None  None    None  None      サーブ     21
# 202  23  21    2  Lead  レシーブ成功(良)      1    鶴田    None  None      NaN   None
# 203  23  21    2  Lead     アタック成功:     19    栗山    None  None      NaN   None
# 204  24  21    3  Lead         NaN     得点  None    None  None      NaN   None
# 205  24  21    3  Lead         NaN   None  None    None  None  メンバー交代:  IN:11
# 206  24  21    3  Lead    サービスエース      3    小野    None  None      NaN   None
# 207  24  21    3  Lead         NaN   None  None    None  None  レシーブ失敗     22
#
#      相手選手  相手交代番号 相手交代選手
# 198  None    None   None
# 199  None    None   None
# 200    永露  OUT:11     傳田
# 201    永露    None   None
# 202  None    None   None
# 203  None    None   None
# 204  None    None   None
# 205    傳田  OUT:21     永露
# 206  None    None   None
# 207    高梨    None   None

# %%
home_away.loc[home_away["状況"] == "サーブ", "サーブ権"] = 'Home'
home_away.loc[home_away["相手状況"] == "サーブ", "サーブ権"] = 'Away'
home_away_2 = home_away[1:]
right_to_serve = ''
for i in range(1, len(home_away_2)+1):
    if pd.isnull(home_away_2.loc[i,"サーブ権"]):
        home_away_2.loc[i,"サーブ権"] = right_to_serve
    else:
        right_to_serve = home_away_2.loc[i,"サーブ権"]
#     アタック追加
    if pd.isnull(home_away_2.loc[i,"状況"]):
        if home_away_2.loc[i,"選手"]!=None:
            home_away_2.loc[i, "状況"] = "アタック"
        else:
            home_away_2.loc[i, "状況"] = ""
    if pd.isnull(home_away_2.loc[i,"相手状況"]):
        if home_away_2.loc[i,"相手選手"]!=None:
            home_away_2.loc[i, "相手状況"] = "アタック"
        else:
            home_away_2.loc[i, "相手状況"] = ""
#         print(right_to_serve) 
home_away_2.head(40)
# Out:
# C:\Users\sasno\AppData\Roaming\Python\Python37\site-packages\pandas\core\indexing.py:1765: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, value)
#     得点  失点  +/-   L-B          状況       番号    選手  交代番号  交代選手        相手状況  \
# 1    0   0    0   Tie                 None  None  None  None         サーブ
# 2    0   0    0   Tie  レシーブ成功(優)       10    藤中  None  None
# 3    0   0    0   Tie     アタック成功:       19    栗山  None  None
# 4    1   0    1  Lead                   得点  None  None  None
# 5    1   0    1  Lead         サーブ        8    柳田  None  None
# 6    1   0    1  Lead                 None  None  None  None     レシーブ失敗
# 7    1   0    1  Lead     アタック成功:       19    栗山  None  None
# 8    2   0    2  Lead                   得点  None  None  None
# 9    2   0    2  Lead         サーブ        8    柳田  None  None
# 10   2   0    2  Lead                 None  None  None  None  レシーブ成功(良)
# 11   2   0    2  Lead                 None  None  None  None     アタック成功:
# 12   2   1    1  Lead                 None  None  None  None
# 13   2   1    1  Lead                 None  None  None  None         サーブ
# 14   2   1    1  Lead  レシーブ成功(良)        1    鶴田  None  None
# 15   2   1    1  Lead     アタック成功:        8    柳田  None  None
# 16   2   1    1  Lead              チャレンジ成功  None  None  None
# 17   3   1    2  Lead                   得点  None  None  None
# 18   3   1    2  Lead         サーブ       12    塩田  None  None
# 19   3   1    2  Lead                 None  None  None  None  レシーブ成功(優)
# 20   3   1    2  Lead                 None  None  None  None     アタック成功:
# 21   3   2    1  Lead                 None  None  None  None
# 22   3   2    1  Lead                 None  None  None  None         サーブ
# 23   3   2    1  Lead  レシーブ成功(良)        8    柳田  None  None
# 24   3   2    1  Lead     アタック成功:        8    柳田  None  None
# 25   4   2    2  Lead                   得点  None  None  None
# 26   4   2    2  Lead         サーブ        9    大宅  None  None
# 27   4   2    2  Lead                 None  None  None  None  レシーブ成功(良)
# 28   4   2    2  Lead                 None  None  None  None     アタック成功:
# 29   4   3    1  Lead                 None  None  None  None
# 30   4   3    1  Lead                 None  None  None  None         サーブ
# 31   4   3    1  Lead     レシーブ失敗        1    鶴田  None  None
# 32   4   3    1  Lead        アタック       19    栗山  None  None
# 33   4   3    1  Lead                 None  None  None  None        アタック
# 34   4   3    1  Lead     アタック成功:       10    藤中  None  None
# 35   5   3    2  Lead                   得点  None  None  None
# 36   5   3    2  Lead         サーブ       10    藤中  None  None
# 37   5   3    2  Lead                 None  None  None  None  レシーブ成功(優)
# 38   5   3    2  Lead                 None  None  None  None        アタック
# 39   5   3    2  Lead     ブロック成功        8    柳田  None  None
# 40   6   3    3  Lead                   得点  None  None  None
#
#     相手番号  相手選手 相手交代番号 相手交代選手  サーブ権
# 1     22    高梨   None   None  Away
# 2   None  None   None   None  Away
# 3   None  None   None   None  Away
# 4   None  None   None   None  Away
# 5   None  None   None   None  Home
# 6     24    小川   None   None  Home
# 7   None  None   None   None  Home
# 8   None  None   None   None  Home
# 9   None  None   None   None  Home
# 10     1    山田   None   None  Home
# 11     1    山田   None   None  Home
# 12    得点  None   None   None  Home
# 13     6     近   None   None  Away
# 14  None  None   None   None  Away
# 15  None  None   None   None  Away
# 16  None  None   None   None  Away
# 17  None  None   None   None  Away
# 18  None  None   None   None  Home
# 19     1    山田   None   None  Home
# 20    11    傳田   None   None  Home
# 21    得点  None   None   None  Home
# 22     3   クレク   None   None  Away
# 23  None  None   None   None  Away
# 24  None  None   None   None  Away
# 25  None  None   None   None  Away
# 26  None  None   None   None  Home
# 27    22    高梨   None   None  Home
# 28     3   クレク   None   None  Home
# 29    得点  None   None   None  Home
# 30     1    山田   None   None  Away
# 31  None  None   None   None  Away
# 32  None  None   None   None  Away
# 33    22    高梨   None   None  Away
# 34  None  None   None   None  Away
# 35  None  None   None   None  Away
# 36  None  None   None   None  Home
# 37     1    山田   None   None  Home
# 38     3   クレク   None   None  Home
# 39  None  None   None   None  Home
# 40  None  None   None   None  Home

# %%
home_away_2.sort_values(["選手", "状況"])
# Out:
#      得点  失点  +/-   L-B        状況     番号    選手    交代番号  交代選手     相手状況   相手番号  \
# 172  20  18    2  Lead  サービスエース     15    喜入    None  None      NaN   None
# 175  21  18    3  Lead       サーブ     15    喜入    None  None      NaN   None
# 171  20  18    2  Lead   メンバー交代:  IN:15    喜入  OUT:12    塩田      NaN   None
# 53    7   5    2  Lead   アタック成功:     12    塩田    None  None      NaN   None
# 18    3   1    2  Lead       サーブ     12    塩田    None  None      NaN   None
# ..   ..  ..  ...   ...       ...    ...   ...     ...   ...      ...    ...
# 200  23  21    2  Lead       NaN   None  None    None  None  メンバー交代:  IN:21
# 201  23  21    2  Lead       NaN   None  None    None  None      サーブ     21
# 204  24  21    3  Lead       NaN     得点  None    None  None      NaN   None
# 205  24  21    3  Lead       NaN   None  None    None  None  メンバー交代:  IN:11
# 207  24  21    3  Lead       NaN   None  None    None  None  レシーブ失敗     22
#
#      相手選手  相手交代番号 相手交代選手  サーブ権
# 172  None    None   None  Away
# 175  None    None   None  Home
# 171  None    None   None  Away
# 53   None    None   None  Away
# 18   None    None   None  Home
# ..    ...     ...    ...   ...
# 200    永露  OUT:11     傳田  Home
# 201    永露    None   None  Away
# 204  None    None   None  Away
# 205    傳田  OUT:21     永露  Away
# 207    高梨    None   None  Away
#
# [207 rows x 15 columns]

# %%
player_search = home_away_2[home_away_2["相手選手"]=="クレク"]
# player_search = home_away_2
player_attack = player_search[player_search["相手状況"].str.contains("アタック")]
player_attack
# Out:
#      得点  失点  +/-   L-B 状況    番号    選手  交代番号  交代選手     相手状況 相手番号 相手選手 相手交代番号  \
# 28    4   2    2  Lead     None  None  None  None  アタック成功:    3  クレク   None
# 38    5   3    2  Lead     None  None  None  None     アタック    3  クレク   None
# 77   11   7    4  Lead     None  None  None  None  アタック成功:    3  クレク   None
# 101  14   9    5  Lead     None  None  None  None     アタック    3  クレク   None
# 120  16  11    5  Lead     None  None  None  None  アタック成功:    3  クレク   None
# 137  16  14    2  Lead     None  None  None  None     アタック    3  クレク   None
# 147  17  15    2  Lead     None  None  None  None  アタック成功:    3  クレク   None
# 159  19  16    3  Lead     None  None  None  None     アタック    3  クレク   None
# 162  19  16    3  Lead     None  None  None  None  アタック成功:    3  クレク   None
# 166  19  17    2  Lead     None  None  None  None     アタック    3  クレク   None
# 167  19  17    2  Lead     None  None  None  None  アタック成功:    3  クレク   None
# 177  21  18    3  Lead     None  None  None  None  アタック成功:    3  クレク   None
# 189  22  19    3  Lead     None  None  None  None  アタック成功:    3  クレク   None
#
#     相手交代選手  サーブ権
# 28    None  Home
# 38    None  Home
# 77    None  Home
# 101   None  Home
# 120   None  Home
# 137   None  Away
# 147   None  Away
# 159   None  Home
# 162   None  Home
# 166   None  Away
# 167   None  Away
# 177   None  Home
# 189   None  Home

# %%
player_sideout = player_attack[player_attack["サーブ権"]=='Away']
player_sideout
# Out:
#      得点  失点  +/-   L-B 状況    番号    選手  交代番号  交代選手     相手状況 相手番号 相手選手 相手交代番号  \
# 137  16  14    2  Lead     None  None  None  None     アタック    3  クレク   None
# 147  17  15    2  Lead     None  None  None  None  アタック成功:    3  クレク   None
# 166  19  17    2  Lead     None  None  None  None     アタック    3  クレク   None
# 167  19  17    2  Lead     None  None  None  None  アタック成功:    3  クレク   None
#
#     相手交代選手  サーブ権
# 137   None  Away
# 147   None  Away
# 166   None  Away
# 167   None  Away

# %%
player_break = player_attack[player_attack["サーブ権"]=='Home']
player_break
# Out:
#      得点  失点  +/-   L-B 状況    番号    選手  交代番号  交代選手     相手状況 相手番号 相手選手 相手交代番号  \
# 28    4   2    2  Lead     None  None  None  None  アタック成功:    3  クレク   None
# 38    5   3    2  Lead     None  None  None  None     アタック    3  クレク   None
# 77   11   7    4  Lead     None  None  None  None  アタック成功:    3  クレク   None
# 101  14   9    5  Lead     None  None  None  None     アタック    3  クレク   None
# 120  16  11    5  Lead     None  None  None  None  アタック成功:    3  クレク   None
# 159  19  16    3  Lead     None  None  None  None     アタック    3  クレク   None
# 162  19  16    3  Lead     None  None  None  None  アタック成功:    3  クレク   None
# 177  21  18    3  Lead     None  None  None  None  アタック成功:    3  クレク   None
# 189  22  19    3  Lead     None  None  None  None  アタック成功:    3  クレク   None
#
#     相手交代選手  サーブ権
# 28    None  Home
# 38    None  Home
# 77    None  Home
# 101   None  Home
# 120   None  Home
# 159   None  Home
# 162   None  Home
# 177   None  Home
# 189   None  Home

# %%
os.chdir('/Users/sasno/Desktop/MyPandas/vleague')
# os.chdir(division)
print(os.getcwd())
# Out:
# C:\Users\sasno\Desktop\MyPandas\vleague
